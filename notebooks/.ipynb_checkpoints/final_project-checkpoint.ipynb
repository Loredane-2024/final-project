# %%
import pandas as pd
import numpy as np
import arff
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.stats import chi2_contingency, ttest_ind
from statsmodels.stats.proportion import proportions_ztest
from sklearn.model_selection import train_test_split, GridSearchCV, RandomizedSearchCV
from sklearn.neighbors import KNeighborsClassifier
from sklearn.preprocessing import MinMaxScaler, StandardScaler
from sklearn.ensemble import BaggingClassifier, RandomForestClassifier,AdaBoostClassifier, GradientBoostingClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix, classification_report, confusion_matrix, roc_curve, auc
from scipy.stats import mannwhitneyu
from imblearn.over_sampling import SMOTE
from sklearn.linear_model import LogisticRegression
from sklearn.utils import resample
from sklearn.model_selection import cross_val_score

# %%
arff_data = arff.load(open("../data/raw/dataset_churn.arff", "r"))
arff_data
# Out:
# {'description': 'Content\nChurn for bank customers\nRowNumbercorresponds to the record (row) number and has no effect on the output.\nCustomerIdcontains random values and has no effect on customer leaving the bank.\nSurnamethe surname of a customer has no impact on their decision to leave the bank.\nCreditScorecan have an effect on customer churn, since a customer with a higher credit score is less likely to leave the bank.\nGeographya customers location can affect their decision to leave the bank.\nGenderits interesting to explore whether gender plays a role in a customer leaving the bank.\nAgethis is certainly relevant, since older customers are less likely to leave their bank than younger ones.\nTenurerefers to the number of years that the customer has been a client of the bank. Normally, older clients are more loyal and less likely to leave a bank.\nBalancealso a very good indicator of customer churn, as people with a higher balance in their accounts are less likely to leave the bank compared to those with lower balances.\nNumOfProductsrefers to the number of products that a customer has purchased through the bank.\nHasCrCarddenotes whether or not a customer has a credit card. This column is also relevant, since people with a credit card are less likely to leave the bank.\nIsActiveMemberactive customers are less likely to leave the bank.\nEstimatedSalaryas with balance, people with lower salaries are more likely to leave the bank compared to those with higher salaries.\nExitedwhether or not the customer left the bank.\n\nAcknowledgements\nAs we know, it is much more expensive to sign in a new client than keeping an existing one.\nIt is advantageous for banks to know what leads a client towards the decision to leave the company.\nChurn prevention allows companies to develop loyalty programs and retention campaigns to keep as many customers as possible.',
#  'relation': 'Churn-for-Bank-Customers',
#  'attributes': [('RowNumber', 'INTEGER'),
#   ('CustomerId', 'INTEGER'),
#   ('Surname', 'STRING'),
#   ('CreditScore', 'INTEGER'),
#   ('Geography', 'STRING'),
#   ('Gender', 'STRING'),
#   ('Age', 'INTEGER'),
#   ('Tenure', 'INTEGER'),
#   ('Balance', 'REAL'),
#   ('NumOfProducts', 'INTEGER'),
#   ('HasCrCard', 'INTEGER'),
#   ('IsActiveMember', 'INTEGER'),
#   ('EstimatedSalary', 'REAL'),
#   ('Exited', 'INTEGER')],
#  'data': [[1,
#    15634602,
#    'Hargrave',
#    619,
#    'France',
#    'Female',
#    42,
#    2,
#    0.0,
#    1,
#    1,
#    1,
#    101348.88,
#    1],
#   [2,
#    15647311,
#    'Hill',
#    608,
#    'Spain',
#    'Female',
#    41,
#    1,
#    83807.86,
#    1,
#    0,
#    1,
#    112542.58,
#    0],
#   [3,
#    15619304,
#    'Onio',
#    502,
#    'France',
#    'Female',
#    42,
#    8,
#    159660.8,
#    3,
#    1,
#    0,
#    113931.57,
#    1],
#   [4,
#    15701354,
#    'Boni',
#    699,
#    'France',
#    'Female',
#    39,
#    1,
#    0.0,
#    2,
#    0,
#    0,
#    93826.63,
#    0],
#   [5,
#    15737888,
#    'Mitchell',
#    850,
#    'Spain',
#    'Female',
#    43,
#    2,
#    125510.82,
#    1,
#    1,
#    1,
#    79084.1,
#    0],
#   [6,
#    15574012,
#    'Chu',
#    645,
#    'Spain',
#    'Male',
#    44,
#    8,
#    113755.78,
#    2,
#    1,
#    0,
#    149756.71,
#    1],
#   [7,
#    15592531,
#    'Bartlett',
#    822,
#    'France',
#    'Male',
#    50,
#    7,
#    0.0,
#    2,
#    1,
#    1,
#    10062.8,
#    0],
#   [8,
#    15656148,
#    'Obinna',
#    376,
#    'Germany',
#    'Female',
#    29,
#    4,
#    115046.74,
#    4,
#    1,
#    0,
#    119346.88,
#    1],
#   [9,
#    15792365,
#    'He',
#    501,
#    'France',
#    'Male',
#    44,
#    4,
#    142051.07,
#    2,
#    0,
#    1,
#    74940.5,
#    0],
#   [10,
#    15592389,
#    'H?',
#    684,
#    'France',
#    'Male',
#    27,
#    2,
#    134603.88,
#    1,
#    1,
#    1,
#    71725.73,
#    0],
#   [11,
#    15767821,
#    'Bearce',
#    528,
#    'France',
#    'Male',
#    31,
#    6,
#    102016.72,
#    2,
#    0,
#    0,
#    80181.12,
#    0],
#   [12,
#    15737173,
#    'Andrews',
#    497,
#    'Spain',
#    'Male',
#    24,
#    3,
#    0.0,
#    2,
#    1,
#    0,
#    76390.01,
#    0],
#   [13,
#    15632264,
#    'Kay',
#    476,
#    'France',
#    'Female',
#    34,
#    10,
#    0.0,
#    2,
#    1,
#    0,
#    26260.98,
#    0],
#   [14,
#    15691483,
#    'Chin',
#    549,
#    'France',
#    'Female',
#    25,
#    5,
#    0.0,
#    2,
#    0,
#    0,
#    190857.79,
#    0],
#   [15,
#    15600882,
#    'Scott',
#    635,
#    'Spain',
#    'Female',
#    35,
#    7,
#    0.0,
#    2,
#    1,
#    1,
#    65951.65,
#    0],
#   [16,
#    15643966,
#    'Goforth',
#    616,
#    'Germany',
#    'Male',
#    45,
#    3,
#    143129.41,
#    2,
#    0,
#    1,
#    64327.26,
#    0],
#   [17,
#    15737452,
#    'Romeo',
#    653,
#    'Germany',
#    'Male',
#    58,
#    1,
#    132602.88,
#    1,
#    1,
#    0,
#    5097.67,
#    1],
#   [18,
#    15788218,
#    'Henderson',
#    549,
#    'Spain',
#    'Female',
#    24,
#    9,
#    0.0,
#    2,
#    1,
#    1,
#    14406.41,
#    0],
#   [19,
#    15661507,
#    'Muldrow',
#    587,
#    'Spain',
#    'Male',
#    45,
#    6,
#    0.0,
#    1,
#    0,
#    0,
#    158684.81,
#    0],
#   [20,
#    15568982,
#    'Hao',
#    726,
#    'France',
#    'Female',
#    24,
#    6,
#    0.0,
#    2,
#    1,
#    1,
#    54724.03,
#    0],
#   [21,
#    15577657,
#    'McDonald',
#    732,
#    'France',
#    'Male',
#    41,
#    8,
#    0.0,
#    2,
#    1,
#    1,
#    170886.17,
#    0],
#   [22,
#    15597945,
#    'Dellucci',
#    636,
#    'Spain',
#    'Female',
#    32,
#    8,
#    0.0,
#    2,
#    1,
#    0,
#    138555.46,
#    0],
#   [23,
#    15699309,
#    'Gerasimov',
#    510,
#    'Spain',
#    'Female',
#    38,
#    4,
#    0.0,
#    1,
#    1,
#    0,
#    118913.53,
#    1],
#   [24,
#    15725737,
#    'Mosman',
#    669,
#    'France',
#    'Male',
#    46,
#    3,
#    0.0,
#    2,
#    0,
#    1,
#    8487.75,
#    0],
#   [25,
#    15625047,
#    'Yen',
#    846,
#    'France',
#    'Female',
#    38,
#    5,
#    0.0,
#    1,
#    1,
#    1,
#    187616.16,
#    0],
#   [26,
#    15738191,
#    'Maclean',
#    577,
#    'France',
#    'Male',
#    25,
#    3,
#    0.0,
#    2,
#    0,
#    1,
#    124508.29,
#    0],
#   [27,
#    15736816,
#    'Young',
#    756,
#    'Germany',
#    'Male',
#    36,
#    2,
#    136815.64,
#    1,
#    1,
#    1,
#    170041.95,
#    0],
#   [28,
#    15700772,
#    'Nebechi',
#    571,
#    'France',
#    'Male',
#    44,
#    9,
#    0.0,
#    2,
#    0,
#    0,
#    38433.35,
#    0],
#   [29,
#    15728693,
#    'McWilliams',
#    574,
#    'Germany',
#    'Female',
#    43,
#    3,
#    141349.43,
#    1,
#    1,
#    1,
#    100187.43,
#    0],
#   [30,
#    15656300,
#    'Lucciano',
#    411,
#    'France',
#    'Male',
#    29,
#    0,
#    59697.17,
#    2,
#    1,
#    1,
#    53483.21,
#    0],
#   [31,
#    15589475,
#    'Azikiwe',
#    591,
#    'Spain',
#    'Female',
#    39,
#    3,
#    0.0,
#    3,
#    1,
#    0,
#    140469.38,
#    1],
#   [32,
#    15706552,
#    'Odinakachukwu',
#    533,
#    'France',
#    'Male',
#    36,
#    7,
#    85311.7,
#    1,
#    0,
#    1,
#    156731.91,
#    0],
#   [33,
#    15750181,
#    'Sanderson',
#    553,
#    'Germany',
#    'Male',
#    41,
#    9,
#    110112.54,
#    2,
#    0,
#    0,
#    81898.81,
#    0],
#   [34,
#    15659428,
#    'Maggard',
#    520,
#    'Spain',
#    'Female',
#    42,
#    6,
#    0.0,
#    2,
#    1,
#    1,
#    34410.55,
#    0],
#   [35,
#    15732963,
#    'Clements',
#    722,
#    'Spain',
#    'Female',
#    29,
#    9,
#    0.0,
#    2,
#    1,
#    1,
#    142033.07,
#    0],
#   [36,
#    15794171,
#    'Lombardo',
#    475,
#    'France',
#    'Female',
#    45,
#    0,
#    134264.04,
#    1,
#    1,
#    0,
#    27822.99,
#    1],
#   [37,
#    15788448,
#    'Watson',
#    490,
#    'Spain',
#    'Male',
#    31,
#    3,
#    145260.23,
#    1,
#    0,
#    1,
#    114066.77,
#    0],
#   [38,
#    15729599,
#    'Lorenzo',
#    804,
#    'Spain',
#    'Male',
#    33,
#    7,
#    76548.6,
#    1,
#    0,
#    1,
#    98453.45,
#    0],
#   [39,
#    15717426,
#    'Armstrong',
#    850,
#    'France',
#    'Male',
#    36,
#    7,
#    0.0,
#    1,
#    1,
#    1,
#    40812.9,
#    0],
#   [40,
#    15585768,
#    'Cameron',
#    582,
#    'Germany',
#    'Male',
#    41,
#    6,
#    70349.48,
#    2,
#    0,
#    1,
#    178074.04,
#    0],
#   [41,
#    15619360,
#    'Hsiao',
#    472,
#    'Spain',
#    'Male',
#    40,
#    4,
#    0.0,
#    1,
#    1,
#    0,
#    70154.22,
#    0],
#   [42,
#    15738148,
#    'Clarke',
#    465,
#    'France',
#    'Female',
#    51,
#    8,
#    122522.32,
#    1,
#    0,
#    0,
#    181297.65,
#    1],
#   [43,
#    15687946,
#    'Osborne',
#    556,
#    'France',
#    'Female',
#    61,
#    2,
#    117419.35,
#    1,
#    1,
#    1,
#    94153.83,
#    0],
#   [44,
#    15755196,
#    'Lavine',
#    834,
#    'France',
#    'Female',
#    49,
#    2,
#    131394.56,
#    1,
#    0,
#    0,
#    194365.76,
#    1],
#   [45,
#    15684171,
#    'Bianchi',
#    660,
#    'Spain',
#    'Female',
#    61,
#    5,
#    155931.11,
#    1,
#    1,
#    1,
#    158338.39,
#    0],
#   [46,
#    15754849,
#    'Tyler',
#    776,
#    'Germany',
#    'Female',
#    32,
#    4,
#    109421.13,
#    2,
#    1,
#    1,
#    126517.46,
#    0],
#   [47,
#    15602280,
#    'Martin',
#    829,
#    'Germany',
#    'Female',
#    27,
#    9,
#    112045.67,
#    1,
#    1,
#    1,
#    119708.21,
#    1],
#   [48,
#    15771573,
#    'Okagbue',
#    637,
#    'Germany',
#    'Female',
#    39,
#    9,
#    137843.8,
#    1,
#    1,
#    1,
#    117622.8,
#    1],
#   [49,
#    15766205,
#    'Yin',
#    550,
#    'Germany',
#    'Male',
#    38,
#    2,
#    103391.38,
#    1,
#    0,
#    1,
#    90878.13,
#    0],
#   [50,
#    15771873,
#    'Buccho',
#    776,
#    'Germany',
#    'Female',
#    37,
#    2,
#    103769.22,
#    2,
#    1,
#    0,
#    194099.12,
#    0],
#   [51,
#    15616550,
#    'Chidiebele',
#    698,
#    'Germany',
#    'Male',
#    44,
#    10,
#    116363.37,
#    2,
#    1,
#    0,
#    198059.16,
#    0],
#   [52,
#    15768193,
#    'Trevisani',
#    585,
#    'Germany',
#    'Male',
#    36,
#    5,
#    146050.97,
#    2,
#    0,
#    0,
#    86424.57,
#    0],
#   [53,
#    15683553,
#    "O'Brien",
#    788,
#    'France',
#    'Female',
#    33,
#    5,
#    0.0,
#    2,
#    0,
#    0,
#    116978.19,
#    0],
#   [54,
#    15702298,
#    'Parkhill',
#    655,
#    'Germany',
#    'Male',
#    41,
#    8,
#    125561.97,
#    1,
#    0,
#    0,
#    164040.94,
#    1],
#   [55,
#    15569590,
#    'Yoo',
#    601,
#    'Germany',
#    'Male',
#    42,
#    1,
#    98495.72,
#    1,
#    1,
#    0,
#    40014.76,
#    1],
#   [56,
#    15760861,
#    'Phillipps',
#    619,
#    'France',
#    'Male',
#    43,
#    1,
#    125211.92,
#    1,
#    1,
#    1,
#    113410.49,
#    0],
#   [57,
#    15630053,
#    'Tsao',
#    656,
#    'France',
#    'Male',
#    45,
#    5,
#    127864.4,
#    1,
#    1,
#    0,
#    87107.57,
#    0],
#   [58,
#    15647091,
#    'Endrizzi',
#    725,
#    'Germany',
#    'Male',
#    19,
#    0,
#    75888.2,
#    1,
#    0,
#    0,
#    45613.75,
#    0],
#   [59,
#    15623944,
#    "T'ien",
#    511,
#    'Spain',
#    'Female',
#    66,
#    4,
#    0.0,
#    1,
#    1,
#    0,
#    1643.11,
#    1],
#   [60,
#    15804771,
#    'Velazquez',
#    614,
#    'France',
#    'Male',
#    51,
#    4,
#    40685.92,
#    1,
#    1,
#    1,
#    46775.28,
#    0],
#   [61,
#    15651280,
#    'Hunter',
#    742,
#    'Germany',
#    'Male',
#    35,
#    5,
#    136857.0,
#    1,
#    0,
#    0,
#    84509.57,
#    0],
#   [62,
#    15773469,
#    'Clark',
#    687,
#    'Germany',
#    'Female',
#    27,
#    9,
#    152328.88,
#    2,
#    0,
#    0,
#    126494.82,
#    0],
#   [63,
#    15702014,
#    'Jeffrey',
#    555,
#    'Spain',
#    'Male',
#    33,
#    1,
#    56084.69,
#    2,
#    0,
#    0,
#    178798.13,
#    0],
#   [64,
#    15751208,
#    'Pirozzi',
#    684,
#    'Spain',
#    'Male',
#    56,
#    8,
#    78707.16,
#    1,
#    1,
#    1,
#    99398.36,
#    0],
#   [65,
#    15592461,
#    'Jackson',
#    603,
#    'Germany',
#    'Male',
#    26,
#    4,
#    109166.37,
#    1,
#    1,
#    1,
#    92840.67,
#    0],
#   [66,
#    15789484,
#    'Hammond',
#    751,
#    'Germany',
#    'Female',
#    36,
#    6,
#    169831.46,
#    2,
#    1,
#    1,
#    27758.36,
#    0],
#   [67,
#    15696061,
#    'Brownless',
#    581,
#    'Germany',
#    'Female',
#    34,
#    1,
#    101633.04,
#    1,
#    1,
#    0,
#    110431.51,
#    0],
#   [68,
#    15641582,
#    'Chibugo',
#    735,
#    'Germany',
#    'Male',
#    43,
#    10,
#    123180.01,
#    2,
#    1,
#    1,
#    196673.28,
#    0],
#   [69,
#    15638424,
#    'Glauert',
#    661,
#    'Germany',
#    'Female',
#    35,
#    5,
#    150725.53,
#    2,
#    0,
#    1,
#    113656.85,
#    0],
#   [70,
#    15755648,
#    'Pisano',
#    675,
#    'France',
#    'Female',
#    21,
#    8,
#    98373.26,
#    1,
#    1,
#    0,
#    18203.0,
#    0],
#   [71,
#    15703793,
#    'Konovalova',
#    738,
#    'Germany',
#    'Male',
#    58,
#    2,
#    133745.44,
#    4,
#    1,
#    0,
#    28373.86,
#    1],
#   [72,
#    15620344,
#    'McKee',
#    813,
#    'France',
#    'Male',
#    29,
#    6,
#    0.0,
#    1,
#    1,
#    0,
#    33953.87,
#    0],
#   [73,
#    15812518,
#    'Palermo',
#    657,
#    'Spain',
#    'Female',
#    37,
#    0,
#    163607.18,
#    1,
#    0,
#    1,
#    44203.55,
#    0],
#   [74,
#    15779052,
#    'Ballard',
#    604,
#    'Germany',
#    'Female',
#    25,
#    5,
#    157780.84,
#    2,
#    1,
#    1,
#    58426.81,
#    0],
#   [75,
#    15770811,
#    'Wallace',
#    519,
#    'France',
#    'Male',
#    36,
#    9,
#    0.0,
#    2,
#    0,
#    1,
#    145562.4,
#    0],
#   [76,
#    15780961,
#    'Cavenagh',
#    735,
#    'France',
#    'Female',
#    21,
#    1,
#    178718.19,
#    2,
#    1,
#    0,
#    22388.0,
#    0],
#   [77,
#    15614049,
#    'Hu',
#    664,
#    'France',
#    'Male',
#    55,
#    8,
#    0.0,
#    2,
#    1,
#    1,
#    139161.64,
#    0],
#   [78,
#    15662085,
#    'Read',
#    678,
#    'France',
#    'Female',
#    32,
#    9,
#    0.0,
#    1,
#    1,
#    1,
#    148210.64,
#    0],
#   [79,
#    15575185,
#    'Bushell',
#    757,
#    'Spain',
#    'Male',
#    33,
#    5,
#    77253.22,
#    1,
#    0,
#    1,
#    194239.63,
#    0],
#   [80,
#    15803136,
#    'Postle',
#    416,
#    'Germany',
#    'Female',
#    41,
#    10,
#    122189.66,
#    2,
#    1,
#    0,
#    98301.61,
#    0],
#   [81,
#    15706021,
#    'Buley',
#    665,
#    'France',
#    'Female',
#    34,
#    1,
#    96645.54,
#    2,
#    0,
#    0,
#    171413.66,
#    0],
#   [82,
#    15663706,
#    'Leonard',
#    777,
#    'France',
#    'Female',
#    32,
#    2,
#    0.0,
#    1,
#    1,
#    0,
#    136458.19,
#    1],
#   [83,
#    15641732,
#    'Mills',
#    543,
#    'France',
#    'Female',
#    36,
#    3,
#    0.0,
#    2,
#    0,
#    0,
#    26019.59,
#    0],
#   [84,
#    15701164,
#    'Onyeorulu',
#    506,
#    'France',
#    'Female',
#    34,
#    4,
#    90307.62,
#    1,
#    1,
#    1,
#    159235.29,
#    0],
#   [85,
#    15738751,
#    'Beit',
#    493,
#    'France',
#    'Female',
#    46,
#    4,
#    0.0,
#    2,
#    1,
#    0,
#    1907.66,
#    0],
#   [86,
#    15805254,
#    'Ndukaku',
#    652,
#    'Spain',
#    'Female',
#    75,
#    10,
#    0.0,
#    2,
#    1,
#    1,
#    114675.75,
#    0],
#   [87,
#    15762418,
#    'Gant',
#    750,
#    'Spain',
#    'Male',
#    22,
#    3,
#    121681.82,
#    1,
#    1,
#    0,
#    128643.35,
#    1],
#   [88,
#    15625759,
#    'Rowley',
#    729,
#    'France',
#    'Male',
#    30,
#    9,
#    0.0,
#    2,
#    1,
#    0,
#    151869.35,
#    0],
#   [89,
#    15622897,
#    'Sharpe',
#    646,
#    'France',
#    'Female',
#    46,
#    4,
#    0.0,
#    3,
#    1,
#    0,
#    93251.42,
#    1],
#   [90,
#    15767954,
#    'Osborne',
#    635,
#    'Germany',
#    'Female',
#    28,
#    3,
#    81623.67,
#    2,
#    1,
#    1,
#    156791.36,
#    0],
#   [91,
#    15757535,
#    'Heap',
#    647,
#    'Spain',
#    'Female',
#    44,
#    5,
#    0.0,
#    3,
#    1,
#    1,
#    174205.22,
#    1],
#   [92,
#    15731511,
#    'Ritchie',
#    808,
#    'France',
#    'Male',
#    45,
#    7,
#    118626.55,
#    2,
#    1,
#    0,
#    147132.46,
#    0],
#   [93,
#    15809248,
#    'Cole',
#    524,
#    'France',
#    'Female',
#    36,
#    10,
#    0.0,
#    2,
#    1,
#    0,
#    109614.57,
#    0],
#   [94,
#    15640635,
#    'Capon',
#    769,
#    'France',
#    'Male',
#    29,
#    8,
#    0.0,
#    2,
#    1,
#    1,
#    172290.61,
#    0],
#   [95,
#    15676966,
#    'Capon',
#    730,
#    'Spain',
#    'Male',
#    42,
#    4,
#    0.0,
#    2,
#    0,
#    1,
#    85982.47,
#    0],
#   [96,
#    15699461,
#    'Fiorentini',
#    515,
#    'Spain',
#    'Male',
#    35,
#    10,
#    176273.95,
#    1,
#    0,
#    1,
#    121277.78,
#    0],
#   [97,
#    15738721,
#    'Graham',
#    773,
#    'Spain',
#    'Male',
#    41,
#    9,
#    102827.44,
#    1,
#    0,
#    1,
#    64595.25,
#    0],
#   [98,
#    15693683,
#    'Yuille',
#    814,
#    'Germany',
#    'Male',
#    29,
#    8,
#    97086.4,
#    2,
#    1,
#    1,
#    197276.13,
#    0],
#   [99,
#    15604348,
#    'Allard',
#    710,
#    'Spain',
#    'Male',
#    22,
#    8,
#    0.0,
#    2,
#    0,
#    0,
#    99645.04,
#    0],
#   [100,
#    15633059,
#    'Fanucci',
#    413,
#    'France',
#    'Male',
#    34,
#    9,
#    0.0,
#    2,
#    0,
#    0,
#    6534.18,
#    0],
#   [101,
#    15808582,
#    'Fu',
#    665,
#    'France',
#    'Female',
#    40,
#    6,
#    0.0,
#    1,
#    1,
#    1,
#    161848.03,
#    0],
#   [102,
#    15743192,
#    'Hung',
#    623,
#    'France',
#    'Female',
#    44,
#    6,
#    0.0,
#    2,
#    0,
#    0,
#    167162.43,
#    0],
#   [103,
#    15580146,
#    'Hung',
#    738,
#    'France',
#    'Male',
#    31,
#    9,
#    82674.15,
#    1,
#    1,
#    0,
#    41970.72,
#    0],
#   [104,
#    15776605,
#    'Bradley',
#    528,
#    'Spain',
#    'Male',
#    36,
#    7,
#    0.0,
#    2,
#    1,
#    0,
#    60536.56,
#    0],
#   [105,
#    15804919,
#    'Dunbabin',
#    670,
#    'Spain',
#    'Female',
#    65,
#    1,
#    0.0,
#    1,
#    1,
#    1,
#    177655.68,
#    1],
#   [106,
#    15613854,
#    'Mauldon',
#    622,
#    'Spain',
#    'Female',
#    46,
#    4,
#    107073.27,
#    2,
#    1,
#    1,
#    30984.59,
#    1],
#   [107,
#    15599195,
#    'Stiger',
#    582,
#    'Germany',
#    'Male',
#    32,
#    1,
#    88938.62,
#    1,
#    1,
#    1,
#    10054.53,
#    0],
#   [108,
#    15812878,
#    'Parsons',
#    785,
#    'Germany',
#    'Female',
#    36,
#    2,
#    99806.85,
#    1,
#    0,
#    1,
#    36976.52,
#    0],
#   [109,
#    15602312,
#    'Walkom',
#    605,
#    'Spain',
#    'Male',
#    33,
#    5,
#    150092.8,
#    1,
#    0,
#    0,
#    71862.79,
#    0],
#   [110,
#    15744689,
#    "T'ang",
#    479,
#    'Germany',
#    'Male',
#    35,
#    9,
#    92833.89,
#    1,
#    1,
#    0,
#    99449.86,
#    1],
#   [111,
#    15803526,
#    'Eremenko',
#    685,
#    'Germany',
#    'Male',
#    30,
#    3,
#    90536.81,
#    1,
#    0,
#    1,
#    63082.88,
#    0],
#   [112,
#    15665790,
#    'Rowntree',
#    538,
#    'Germany',
#    'Male',
#    39,
#    7,
#    108055.1,
#    2,
#    1,
#    0,
#    27231.26,
#    0],
#   [113,
#    15715951,
#    'Thorpe',
#    562,
#    'France',
#    'Male',
#    42,
#    2,
#    100238.35,
#    1,
#    0,
#    0,
#    86797.41,
#    0],
#   [114,
#    15591100,
#    'Chiemela',
#    675,
#    'Spain',
#    'Male',
#    36,
#    9,
#    106190.55,
#    1,
#    0,
#    1,
#    22994.32,
#    0],
#   [115,
#    15609618,
#    'Fanucci',
#    721,
#    'Germany',
#    'Male',
#    28,
#    9,
#    154475.54,
#    2,
#    0,
#    1,
#    101300.94,
#    1],
#   [116,
#    15675522,
#    'Ko',
#    628,
#    'Germany',
#    'Female',
#    30,
#    9,
#    132351.29,
#    2,
#    1,
#    1,
#    74169.13,
#    0],
#   [117,
#    15705512,
#    'Welch',
#    668,
#    'Germany',
#    'Female',
#    37,
#    6,
#    167864.4,
#    1,
#    1,
#    0,
#    115638.29,
#    0],
#   [118,
#    15698028,
#    'Duncan',
#    506,
#    'France',
#    'Female',
#    41,
#    1,
#    0.0,
#    2,
#    1,
#    0,
#    31766.3,
#    0],
#   [119,
#    15661670,
#    'Chidozie',
#    524,
#    'Germany',
#    'Female',
#    31,
#    8,
#    107818.63,
#    1,
#    1,
#    0,
#    199725.39,
#    1],
#   [120,
#    15600781,
#    'Wu',
#    699,
#    'Germany',
#    'Male',
#    34,
#    4,
#    185173.81,
#    2,
#    1,
#    0,
#    120834.48,
#    0],
#   [121,
#    15682472,
#    'Culbreth',
#    828,
#    'France',
#    'Male',
#    34,
#    8,
#    129433.34,
#    2,
#    0,
#    0,
#    38131.77,
#    0],
#   [122,
#    15580203,
#    'Kennedy',
#    674,
#    'Spain',
#    'Male',
#    39,
#    6,
#    120193.42,
#    1,
#    0,
#    0,
#    100130.95,
#    0],
#   [123,
#    15690673,
#    'Cameron',
#    656,
#    'France',
#    'Female',
#    39,
#    6,
#    0.0,
#    2,
#    1,
#    0,
#    141069.88,
#    0],
#   [124,
#    15760085,
#    'Calabresi',
#    684,
#    'Germany',
#    'Female',
#    48,
#    10,
#    126384.42,
#    1,
#    1,
#    1,
#    198129.36,
#    0],
#   [125,
#    15779659,
#    'Zetticci',
#    625,
#    'France',
#    'Female',
#    28,
#    3,
#    0.0,
#    1,
#    0,
#    0,
#    183646.41,
#    0],
#   [126,
#    15627360,
#    'Fuller',
#    432,
#    'France',
#    'Male',
#    42,
#    9,
#    152603.45,
#    1,
#    1,
#    0,
#    110265.24,
#    1],
#   [127,
#    15671137,
#    'MacDonald',
#    549,
#    'France',
#    'Female',
#    52,
#    1,
#    0.0,
#    1,
#    0,
#    1,
#    8636.05,
#    1],
#   [128,
#    15782688,
#    'Piccio',
#    625,
#    'Germany',
#    'Male',
#    56,
#    0,
#    148507.24,
#    1,
#    1,
#    0,
#    46824.08,
#    1],
#   [129,
#    15575492,
#    'Kennedy',
#    828,
#    'France',
#    'Female',
#    41,
#    7,
#    0.0,
#    2,
#    1,
#    0,
#    171378.77,
#    0],
#   [130,
#    15591607,
#    'Fernie',
#    770,
#    'France',
#    'Male',
#    24,
#    9,
#    101827.07,
#    1,
#    1,
#    0,
#    167256.35,
#    0],
#   [131,
#    15740404,
#    'He',
#    758,
#    'France',
#    'Female',
#    34,
#    3,
#    0.0,
#    2,
#    1,
#    1,
#    124226.16,
#    0],
#   [132,
#    15718369,
#    'Kaodilinakachukwu',
#    795,
#    'Germany',
#    'Female',
#    33,
#    9,
#    130862.43,
#    1,
#    1,
#    1,
#    114935.21,
#    0],
#   [133,
#    15677871,
#    'Cocci',
#    687,
#    'France',
#    'Male',
#    38,
#    9,
#    122570.87,
#    1,
#    1,
#    1,
#    35608.88,
#    0],
#   [134,
#    15642004,
#    'Alekseeva',
#    686,
#    'France',
#    'Male',
#    25,
#    1,
#    0.0,
#    2,
#    0,
#    1,
#    16459.37,
#    0],
#   [135,
#    15712543,
#    'Chinweike',
#    789,
#    'Germany',
#    'Male',
#    39,
#    7,
#    124828.46,
#    2,
#    1,
#    1,
#    124411.08,
#    0],
#   [136,
#    15584518,
#    'Arthur',
#    589,
#    'Germany',
#    'Female',
#    50,
#    5,
#    144895.05,
#    2,
#    1,
#    1,
#    34941.23,
#    0],
#   [137,
#    15802381,
#    'Li',
#    461,
#    'Germany',
#    'Female',
#    34,
#    5,
#    63663.93,
#    1,
#    0,
#    1,
#    167784.28,
#    0],
#   [138,
#    15610156,
#    'Ma',
#    637,
#    'France',
#    'Male',
#    40,
#    2,
#    133463.1,
#    1,
#    0,
#    1,
#    93165.34,
#    0],
#   [139,
#    15594408,
#    'Chia',
#    584,
#    'Spain',
#    'Female',
#    48,
#    2,
#    213146.2,
#    1,
#    1,
#    0,
#    75161.25,
#    1],
#   [140,
#    15640905,
#    'Vasin',
#    579,
#    'Spain',
#    'Female',
#    35,
#    1,
#    129490.36,
#    2,
#    0,
#    1,
#    8590.83,
#    1],
#   [141,
#    15698932,
#    'Groves',
#    756,
#    'Germany',
#    'Male',
#    44,
#    10,
#    137452.09,
#    1,
#    1,
#    0,
#    189543.9,
#    0],
#   [142,
#    15724944,
#    'Tien',
#    663,
#    'France',
#    'Male',
#    34,
#    7,
#    0.0,
#    2,
#    1,
#    1,
#    180427.24,
#    0],
#   [143,
#    15628145,
#    'Forwood',
#    682,
#    'France',
#    'Female',
#    43,
#    5,
#    125851.93,
#    1,
#    1,
#    1,
#    193318.33,
#    0],
#   [144,
#    15713483,
#    'Greeves',
#    793,
#    'Spain',
#    'Male',
#    52,
#    2,
#    0.0,
#    1,
#    1,
#    0,
#    159123.82,
#    1],
#   [145,
#    15612350,
#    'Taylor',
#    691,
#    'France',
#    'Female',
#    31,
#    5,
#    40915.55,
#    1,
#    1,
#    0,
#    126213.84,
#    1],
#   [146,
#    15800703,
#    'Madukwe',
#    485,
#    'Spain',
#    'Female',
#    21,
#    5,
#    113157.22,
#    1,
#    1,
#    1,
#    54141.5,
#    0],
#   [147,
#    15705707,
#    'Bennelong',
#    635,
#    'Spain',
#    'Female',
#    29,
#    8,
#    138296.94,
#    2,
#    1,
#    0,
#    141075.51,
#    0],
#   [148,
#    15754105,
#    'Olisanugo',
#    650,
#    'France',
#    'Male',
#    37,
#    5,
#    106967.18,
#    1,
#    0,
#    0,
#    24495.03,
#    0],
#   [149,
#    15703264,
#    'Chukwufumnanya',
#    735,
#    'France',
#    'Male',
#    44,
#    9,
#    120681.63,
#    1,
#    1,
#    0,
#    74836.34,
#    0],
#   [150,
#    15794413,
#    'Harris',
#    416,
#    'France',
#    'Male',
#    32,
#    0,
#    0.0,
#    2,
#    0,
#    1,
#    878.87,
#    0],
#   [151,
#    15650237,
#    'Morgan',
#    754,
#    'Spain',
#    'Female',
#    32,
#    7,
#    0.0,
#    2,
#    1,
#    0,
#    89520.75,
#    0],
#   [152,
#    15759618,
#    'Alexeeva',
#    535,
#    'France',
#    'Female',
#    48,
#    9,
#    0.0,
#    1,
#    1,
#    0,
#    149892.79,
#    1],
#   [153,
#    15811589,
#    'Metcalfe',
#    716,
#    'Spain',
#    'Male',
#    42,
#    8,
#    0.0,
#    2,
#    1,
#    0,
#    180800.42,
#    0],
#   [154,
#    15689044,
#    'Humphries',
#    539,
#    'France',
#    'Male',
#    37,
#    2,
#    127609.59,
#    1,
#    1,
#    0,
#    98646.22,
#    0],
#   [155,
#    15709368,
#    'Milne',
#    614,
#    'France',
#    'Female',
#    43,
#    6,
#    0.0,
#    2,
#    1,
#    1,
#    109041.53,
#    0],
#   [156,
#    15679145,
#    'Chou',
#    706,
#    'Spain',
#    'Male',
#    57,
#    7,
#    0.0,
#    1,
#    1,
#    0,
#    17941.16,
#    1],
#   [157,
#    15655007,
#    'Li',
#    758,
#    'France',
#    'Female',
#    33,
#    7,
#    0.0,
#    2,
#    0,
#    0,
#    82996.47,
#    0],
#   [158,
#    15623595,
#    'Clayton',
#    586,
#    'Spain',
#    'Female',
#    28,
#    2,
#    0.0,
#    2,
#    1,
#    1,
#    92067.35,
#    0],
#   [159,
#    15589975,
#    'Maclean',
#    646,
#    'France',
#    'Female',
#    73,
#    6,
#    97259.25,
#    1,
#    0,
#    1,
#    104719.66,
#    0],
#   [160,
#    15804017,
#    'Chigolum',
#    631,
#    'Germany',
#    'Female',
#    33,
#    4,
#    123246.7,
#    1,
#    0,
#    0,
#    112687.57,
#    0],
#   [161,
#    15692132,
#    'Wilkinson',
#    717,
#    'Spain',
#    'Female',
#    22,
#    6,
#    101060.25,
#    1,
#    0,
#    1,
#    84699.56,
#    0],
#   [162,
#    15641122,
#    'Wei',
#    684,
#    'France',
#    'Male',
#    30,
#    2,
#    0.0,
#    2,
#    1,
#    0,
#    83473.82,
#    0],
#   [163,
#    15630910,
#    'Treacy',
#    800,
#    'France',
#    'Female',
#    49,
#    7,
#    108007.36,
#    1,
#    0,
#    0,
#    47125.11,
#    0],
#   [164,
#    15680772,
#    'Hu',
#    721,
#    'Spain',
#    'Female',
#    36,
#    2,
#    0.0,
#    2,
#    1,
#    1,
#    106977.8,
#    0],
#   [165,
#    15658929,
#    'Taverner',
#    683,
#    'Spain',
#    'Male',
#    29,
#    0,
#    133702.89,
#    1,
#    1,
#    0,
#    55582.54,
#    1],
#   [166,
#    15585388,
#    'Sherman',
#    660,
#    'Germany',
#    'Male',
#    31,
#    9,
#    125189.75,
#    2,
#    1,
#    1,
#    139874.43,
#    0],
#   [167,
#    15724623,
#    'Taubman',
#    704,
#    'Germany',
#    'Female',
#    24,
#    7,
#    113034.22,
#    1,
#    1,
#    0,
#    162503.48,
#    1],
#   [168,
#    15588537,
#    'Robinson',
#    615,
#    'Spain',
#    'Female',
#    41,
#    9,
#    109013.23,
#    1,
#    1,
#    0,
#    196499.96,
#    0],
#   [169,
#    15574692,
#    'Pinto',
#    667,
#    'Spain',
#    'Female',
#    39,
#    2,
#    0.0,
#    2,
#    1,
#    0,
#    40721.24,
#    1],
#   [170,
#    15611325,
#    'Wood',
#    682,
#    'Germany',
#    'Male',
#    24,
#    9,
#    57929.81,
#    2,
#    0,
#    0,
#    53134.3,
#    0],
#   [171,
#    15587562,
#    'Hawkins',
#    484,
#    'France',
#    'Female',
#    29,
#    4,
#    130114.39,
#    1,
#    1,
#    0,
#    164017.89,
#    0],
#   [172,
#    15613172,
#    'Sun',
#    628,
#    'Germany',
#    'Male',
#    27,
#    5,
#    95826.49,
#    2,
#    1,
#    0,
#    155996.96,
#    0],
#   [173,
#    15651022,
#    'Yost',
#    480,
#    'Germany',
#    'Male',
#    44,
#    10,
#    129608.57,
#    1,
#    1,
#    0,
#    5472.7,
#    1],
#   [174,
#    15586310,
#    'Ting',
#    578,
#    'France',
#    'Male',
#    30,
#    4,
#    169462.09,
#    1,
#    1,
#    0,
#    112187.11,
#    0],
#   [175,
#    15625524,
#    'Rowe',
#    512,
#    'France',
#    'Male',
#    40,
#    5,
#    0.0,
#    2,
#    1,
#    1,
#    146457.83,
#    0],
#   [176,
#    15755209,
#    'Fu',
#    484,
#    'Spain',
#    'Female',
#    35,
#    7,
#    133868.21,
#    1,
#    1,
#    1,
#    27286.1,
#    0],
#   [177,
#    15645248,
#    'Ho',
#    510,
#    'France',
#    'Female',
#    30,
#    0,
#    0.0,
#    2,
#    1,
#    1,
#    130553.47,
#    0],
#   [178,
#    15790355,
#    'Okechukwu',
#    606,
#    'Germany',
#    'Male',
#    36,
#    5,
#    190479.48,
#    2,
#    0,
#    0,
#    179351.89,
#    0],
#   [179,
#    15762615,
#    'Campbell',
#    597,
#    'Spain',
#    'Female',
#    40,
#    8,
#    101993.12,
#    1,
#    0,
#    1,
#    94774.12,
#    0],
#   [180,
#    15625426,
#    'Ashbolt',
#    754,
#    'Germany',
#    'Female',
#    55,
#    3,
#    161608.81,
#    1,
#    1,
#    0,
#    8080.85,
#    1],
#   [181,
#    15716334,
#    'Rozier',
#    850,
#    'Spain',
#    'Female',
#    45,
#    2,
#    122311.21,
#    1,
#    1,
#    1,
#    19482.5,
#    0],
#   [182,
#    15789669,
#    'Hsia',
#    510,
#    'France',
#    'Male',
#    65,
#    2,
#    0.0,
#    2,
#    1,
#    1,
#    48071.61,
#    0],
#   [183,
#    15621075,
#    'Ogbonnaya',
#    778,
#    'Germany',
#    'Female',
#    45,
#    1,
#    162150.42,
#    2,
#    1,
#    0,
#    174531.27,
#    0],
#   [184,
#    15810845,
#    "T'ang",
#    636,
#    'France',
#    'Male',
#    42,
#    2,
#    0.0,
#    2,
#    1,
#    1,
#    55470.78,
#    0],
#   [185,
#    15719377,
#    'Cocci',
#    804,
#    'France',
#    'Female',
#    50,
#    4,
#    0.0,
#    1,
#    1,
#    1,
#    8546.87,
#    1],
#   [186,
#    15654506,
#    'Chang',
#    514,
#    'France',
#    'Male',
#    32,
#    8,
#    0.0,
#    2,
#    1,
#    0,
#    95857.18,
#    0],
#   [187,
#    15771977,
#    "T'ao",
#    730,
#    'France',
#    'Female',
#    39,
#    1,
#    99010.67,
#    1,
#    1,
#    0,
#    194945.8,
#    0],
#   [188,
#    15708710,
#    'Ford',
#    525,
#    'Spain',
#    'Female',
#    37,
#    0,
#    0.0,
#    1,
#    0,
#    1,
#    131521.72,
#    0],
#   [189,
#    15726676,
#    'Marshall',
#    616,
#    'Spain',
#    'Male',
#    30,
#    5,
#    0.0,
#    2,
#    0,
#    1,
#    196108.51,
#    0],
#   [190,
#    15587421,
#    'Tsai',
#    687,
#    'Germany',
#    'Female',
#    34,
#    7,
#    111388.18,
#    2,
#    1,
#    0,
#    148564.76,
#    0],
#   [191,
#    15726931,
#    'Onwumelu',
#    715,
#    'France',
#    'Female',
#    41,
#    8,
#    56214.85,
#    2,
#    0,
#    0,
#    92982.61,
#    1],
#   [192,
#    15771086,
#    'Graham',
#    512,
#    'France',
#    'Female',
#    36,
#    3,
#    84327.77,
#    2,
#    1,
#    0,
#    17675.36,
#    0],
#   [193,
#    15756850,
#    'Golovanov',
#    479,
#    'France',
#    'Male',
#    40,
#    1,
#    0.0,
#    2,
#    0,
#    0,
#    114996.43,
#    0],
#   [194,
#    15702741,
#    'Potts',
#    601,
#    'France',
#    'Male',
#    32,
#    8,
#    93012.89,
#    1,
#    1,
#    0,
#    86957.42,
#    0],
#   [195,
#    15679200,
#    'Crawford',
#    580,
#    'Spain',
#    'Male',
#    29,
#    9,
#    61710.44,
#    2,
#    1,
#    0,
#    128077.8,
#    0],
#   [196,
#    15594815,
#    'Aleshire',
#    807,
#    'France',
#    'Male',
#    35,
#    3,
#    174790.15,
#    1,
#    1,
#    1,
#    600.36,
#    0],
#   [197,
#    15635905,
#    'Moran',
#    616,
#    'Spain',
#    'Female',
#    32,
#    6,
#    0.0,
#    2,
#    1,
#    1,
#    43001.46,
#    0],
#   [198,
#    15777892,
#    'Samsonova',
#    721,
#    'Germany',
#    'Male',
#    37,
#    3,
#    107720.64,
#    1,
#    1,
#    1,
#    158591.12,
#    0],
#   [199,
#    15656176,
#    'Jenkins',
#    501,
#    'France',
#    'Male',
#    57,
#    10,
#    0.0,
#    2,
#    1,
#    1,
#    47847.19,
#    0],
#   [200,
#    15811127,
#    'Volkov',
#    521,
#    'France',
#    'Male',
#    35,
#    6,
#    96423.84,
#    1,
#    1,
#    0,
#    10488.44,
#    0],
#   [201,
#    15604482,
#    'Chiemezie',
#    850,
#    'Spain',
#    'Male',
#    30,
#    2,
#    141040.01,
#    1,
#    1,
#    1,
#    5978.2,
#    0],
#   [202,
#    15622911,
#    'Jude',
#    759,
#    'France',
#    'Male',
#    42,
#    4,
#    105420.18,
#    1,
#    0,
#    1,
#    121409.06,
#    0],
#   [203,
#    15600974,
#    'He',
#    516,
#    'Spain',
#    'Male',
#    50,
#    5,
#    0.0,
#    1,
#    0,
#    1,
#    146145.93,
#    1],
#   [204,
#    15727868,
#    'Onuora',
#    711,
#    'France',
#    'Female',
#    38,
#    2,
#    129022.06,
#    2,
#    1,
#    1,
#    14374.86,
#    1],
#   [205,
#    15627801,
#    'Ginikanwa',
#    512,
#    'Spain',
#    'Male',
#    33,
#    3,
#    176666.62,
#    1,
#    1,
#    0,
#    94670.77,
#    0],
#   [206,
#    15773039,
#    'Ku',
#    550,
#    'France',
#    'Male',
#    37,
#    3,
#    0.0,
#    1,
#    1,
#    1,
#    179670.31,
#    0],
#   [207,
#    15755262,
#    'McDonald',
#    608,
#    'Spain',
#    'Female',
#    41,
#    3,
#    89763.84,
#    1,
#    0,
#    0,
#    199304.74,
#    1],
#   [208,
#    15679531,
#    'Collins',
#    618,
#    'France',
#    'Male',
#    34,
#    5,
#    134954.53,
#    1,
#    1,
#    1,
#    151954.39,
#    0],
#   [209,
#    15684181,
#    'Hackett',
#    643,
#    'France',
#    'Male',
#    45,
#    5,
#    0.0,
#    1,
#    1,
#    0,
#    142513.5,
#    1],
#   [210,
#    15612087,
#    'Dike',
#    671,
#    'France',
#    'Male',
#    45,
#    2,
#    106376.85,
#    1,
#    0,
#    1,
#    158264.62,
#    0],
#   [211,
#    15752047,
#    'Trevisano',
#    689,
#    'Germany',
#    'Male',
#    33,
#    2,
#    161814.64,
#    2,
#    1,
#    0,
#    169381.9,
#    0],
#   [212,
#    15624592,
#    'Tan',
#    603,
#    'France',
#    'Male',
#    31,
#    8,
#    0.0,
#    2,
#    1,
#    1,
#    169915.02,
#    0],
#   [213,
#    15573152,
#    'Glassman',
#    620,
#    'France',
#    'Female',
#    41,
#    9,
#    0.0,
#    2,
#    0,
#    0,
#    88852.47,
#    0],
#   [214,
#    15594917,
#    'Miller',
#    676,
#    'France',
#    'Female',
#    34,
#    1,
#    63095.01,
#    1,
#    1,
#    1,
#    40645.81,
#    0],
#   [215,
#    15785542,
#    'Kornilova',
#    572,
#    'Germany',
#    'Male',
#    26,
#    4,
#    118287.01,
#    2,
#    0,
#    0,
#    60427.3,
#    0],
#   [216,
#    15723488,
#    'Watson',
#    668,
#    'Germany',
#    'Male',
#    47,
#    7,
#    106854.21,
#    1,
#    0,
#    1,
#    157959.02,
#    1],
#   [217,
#    15680920,
#    'Marchesi',
#    695,
#    'France',
#    'Male',
#    46,
#    7,
#    49512.55,
#    1,
#    1,
#    0,
#    133007.34,
#    0],
#   [218,
#    15786308,
#    'Millar',
#    730,
#    'Spain',
#    'Female',
#    33,
#    9,
#    0.0,
#    2,
#    0,
#    0,
#    176576.62,
#    0],
#   [219,
#    15659366,
#    'Shih',
#    807,
#    'France',
#    'Male',
#    43,
#    1,
#    105799.32,
#    2,
#    1,
#    0,
#    34888.04,
#    1],
#   [220,
#    15774854,
#    'Fuller',
#    592,
#    'France',
#    'Male',
#    54,
#    8,
#    0.0,
#    1,
#    1,
#    1,
#    28737.71,
#    1],
#   [221,
#    15725311,
#    'Hay',
#    726,
#    'France',
#    'Female',
#    31,
#    9,
#    114722.05,
#    2,
#    1,
#    1,
#    98178.57,
#    0],
#   [222,
#    15787155,
#    'Yang',
#    514,
#    'Spain',
#    'Male',
#    30,
#    7,
#    0.0,
#    1,
#    0,
#    1,
#    125010.24,
#    0],
#   [223,
#    15727829,
#    'McIntyre',
#    567,
#    'France',
#    'Male',
#    42,
#    2,
#    0.0,
#    2,
#    1,
#    1,
#    167984.61,
#    0],
#   [224,
#    15733247,
#    'Stevenson',
#    850,
#    'France',
#    'Male',
#    33,
#    10,
#    0.0,
#    1,
#    1,
#    0,
#    4861.72,
#    1],
#   [225,
#    15568748,
#    'Poole',
#    671,
#    'Germany',
#    'Male',
#    45,
#    6,
#    99564.22,
#    1,
#    1,
#    1,
#    108872.45,
#    1],
#   [226,
#    15699029,
#    'Bagley',
#    670,
#    'France',
#    'Male',
#    37,
#    4,
#    170557.91,
#    2,
#    1,
#    0,
#    198252.88,
#    0],
#   [227,
#    15774393,
#    "Ch'ien",
#    694,
#    'France',
#    'Female',
#    30,
#    9,
#    0.0,
#    2,
#    1,
#    1,
#    26960.31,
#    0],
#   [228,
#    15676895,
#    'Cattaneo',
#    547,
#    'Germany',
#    'Female',
#    39,
#    6,
#    74596.15,
#    3,
#    1,
#    1,
#    85746.52,
#    1],
#   [229,
#    15637753,
#    "O'Sullivan",
#    751,
#    'Germany',
#    'Male',
#    50,
#    2,
#    96888.39,
#    1,
#    1,
#    0,
#    77206.25,
#    1],
#   [230,
#    15605461,
#    'Lucas',
#    594,
#    'Germany',
#    'Female',
#    29,
#    3,
#    130830.22,
#    1,
#    1,
#    0,
#    61048.53,
#    0],
#   [231,
#    15808473,
#    'Ringrose',
#    673,
#    'France',
#    'Male',
#    72,
#    1,
#    0.0,
#    2,
#    0,
#    1,
#    111981.19,
#    0],
#   [232,
#    15627000,
#    'Freeman',
#    610,
#    'France',
#    'Male',
#    40,
#    0,
#    0.0,
#    2,
#    1,
#    0,
#    62232.6,
#    0],
#   [233,
#    15787174,
#    'Sergeyev',
#    512,
#    'France',
#    'Female',
#    37,
#    1,
#    0.0,
#    2,
#    0,
#    1,
#    156105.03,
#    0],
#   [234,
#    15723886,
#    'Fiore',
#    767,
#    'Germany',
#    'Male',
#    20,
#    3,
#    119714.25,
#    2,
#    0,
#    1,
#    150135.38,
#    0],
#   [235,
#    15704769,
#    'Smith',
#    585,
#    'France',
#    'Female',
#    67,
#    5,
#    113978.97,
#    2,
#    0,
#    1,
#    93146.11,
#    0],
#   [236,
#    15772896,
#    'Dumetochukwu',
#    763,
#    'Germany',
#    'Male',
#    42,
#    6,
#    100160.75,
#    1,
#    1,
#    0,
#    33462.94,
#    1],
#   [237,
#    15711540,
#    'Pacheco',
#    712,
#    'France',
#    'Female',
#    29,
#    2,
#    0.0,
#    1,
#    1,
#    1,
#    144375.0,
#    0],
#   [238,
#    15764866,
#    'Synnot',
#    539,
#    'Germany',
#    'Female',
#    43,
#    3,
#    116220.5,
#    3,
#    1,
#    0,
#    55803.96,
#    1],
#   [239,
#    15794056,
#    'Johnston',
#    668,
#    'France',
#    'Female',
#    46,
#    2,
#    0.0,
#    3,
#    1,
#    0,
#    89048.46,
#    1],
#   [240,
#    15795149,
#    'Stevens',
#    703,
#    'France',
#    'Male',
#    28,
#    2,
#    81173.83,
#    2,
#    0,
#    1,
#    162812.16,
#    0],
#   [241,
#    15812009,
#    'Grant',
#    662,
#    'Spain',
#    'Male',
#    38,
#    4,
#    0.0,
#    2,
#    1,
#    0,
#    136259.65,
#    0],
#   [242,
#    15651001,
#    'Tsao',
#    725,
#    'Germany',
#    'Female',
#    39,
#    5,
#    116803.8,
#    1,
#    1,
#    0,
#    124052.97,
#    0],
#   [243,
#    15813844,
#    'Barnes',
#    703,
#    'France',
#    'Male',
#    37,
#    8,
#    105961.68,
#    2,
#    0,
#    1,
#    74158.8,
#    0],
#   [244,
#    15596175,
#    'McIntosh',
#    659,
#    'Germany',
#    'Male',
#    67,
#    6,
#    117411.6,
#    1,
#    1,
#    1,
#    45071.09,
#    1],
#   [245,
#    15576269,
#    'Madison',
#    523,
#    'Spain',
#    'Male',
#    34,
#    7,
#    0.0,
#    2,
#    1,
#    0,
#    62030.06,
#    0],
#   [246,
#    15797219,
#    'Ifesinachi',
#    635,
#    'France',
#    'Female',
#    40,
#    10,
#    123497.58,
#    1,
#    1,
#    0,
#    131953.23,
#    1],
#   [247,
#    15685500,
#    'Glazkov',
#    772,
#    'Germany',
#    'Male',
#    26,
#    7,
#    152400.51,
#    2,
#    1,
#    0,
#    79414.0,
#    0],
#   [248,
#    15599792,
#    'Dimauro',
#    545,
#    'France',
#    'Female',
#    26,
#    1,
#    0.0,
#    2,
#    1,
#    1,
#    199638.56,
#    0],
#   [249,
#    15657566,
#    'Wieck',
#    634,
#    'Germany',
#    'Male',
#    24,
#    8,
#    103097.85,
#    1,
#    1,
#    1,
#    157577.29,
#    0],
#   [250,
#    15772423,
#    'Liao',
#    739,
#    'Germany',
#    'Male',
#    54,
#    8,
#    126418.14,
#    1,
#    1,
#    0,
#    134420.75,
#    1],
#   [251,
#    15628112,
#    'Hughes',
#    771,
#    'Germany',
#    'Female',
#    36,
#    5,
#    77846.9,
#    1,
#    0,
#    0,
#    99805.99,
#    0],
#   [252,
#    15753754,
#    'Morrison',
#    587,
#    'Spain',
#    'Female',
#    34,
#    1,
#    0.0,
#    2,
#    1,
#    1,
#    97932.68,
#    0],
#   [253,
#    15793726,
#    'Matveyeva',
#    681,
#    'France',
#    'Female',
#    79,
#    0,
#    0.0,
#    2,
#    0,
#    1,
#    170968.99,
#    0],
#   [254,
#    15694717,
#    'Ku',
#    544,
#    'Germany',
#    'Male',
#    37,
#    2,
#    79731.91,
#    1,
#    1,
#    1,
#    57558.95,
#    0],
#   [255,
#    15665834,
#    'Cheatham',
#    696,
#    'Spain',
#    'Male',
#    28,
#    8,
#    0.0,
#    1,
#    0,
#    0,
#    176713.47,
#    0],
#   [256,
#    15765297,
#    'Yao',
#    766,
#    'Spain',
#    'Male',
#    41,
#    0,
#    0.0,
#    2,
#    0,
#    1,
#    34283.23,
#    0],
#   [257,
#    15636684,
#    'Kirkland',
#    727,
#    'France',
#    'Male',
#    34,
#    10,
#    0.0,
#    2,
#    1,
#    1,
#    198637.34,
#    0],
#   [258,
#    15592979,
#    'Rose',
#    671,
#    'Germany',
#    'Female',
#    34,
#    6,
#    37266.67,
#    2,
#    0,
#    0,
#    156917.12,
#    0],
#   [259,
#    15750803,
#    'Jess',
#    693,
#    'France',
#    'Female',
#    30,
#    6,
#    127992.25,
#    1,
#    1,
#    1,
#    50457.2,
#    0],
#   [260,
#    15607178,
#    'Welch',
#    850,
#    'Germany',
#    'Male',
#    38,
#    3,
#    54901.01,
#    1,
#    1,
#    1,
#    140075.55,
#    0],
#   [261,
#    15713853,
#    'Ifeajuna',
#    732,
#    'Germany',
#    'Male',
#    42,
#    9,
#    108748.08,
#    2,
#    1,
#    1,
#    65323.11,
#    0],
#   [262,
#    15673481,
#    'Morton',
#    726,
#    'Spain',
#    'Female',
#    48,
#    6,
#    99906.19,
#    1,
#    1,
#    0,
#    64323.24,
#    0],
#   [263,
#    15686776,
#    'Rossi',
#    557,
#    'France',
#    'Female',
#    32,
#    6,
#    184686.41,
#    2,
#    1,
#    0,
#    14956.44,
#    0],
#   [264,
#    15673693,
#    'Reppert',
#    682,
#    'France',
#    'Female',
#    26,
#    0,
#    110654.02,
#    1,
#    0,
#    1,
#    111879.21,
#    0],
#   [265,
#    15700696,
#    'Kang',
#    738,
#    'Spain',
#    'Male',
#    31,
#    9,
#    79019.8,
#    1,
#    1,
#    1,
#    18606.23,
#    0],
#   [266,
#    15813163,
#    "Ch'iu",
#    531,
#    'Spain',
#    'Female',
#    36,
#    9,
#    99240.51,
#    1,
#    1,
#    0,
#    123137.01,
#    0],
#   [267,
#    15653857,
#    'Wallis',
#    498,
#    'France',
#    'Male',
#    34,
#    2,
#    0.0,
#    2,
#    1,
#    1,
#    148528.24,
#    0],
#   [268,
#    15777076,
#    'Clark',
#    651,
#    'France',
#    'Male',
#    36,
#    7,
#    0.0,
#    2,
#    1,
#    0,
#    13898.31,
#    0],
#   [269,
#    15717398,
#    'Fielding',
#    549,
#    'Spain',
#    'Female',
#    39,
#    7,
#    0.0,
#    1,
#    0,
#    0,
#    81259.25,
#    1],
#   [270,
#    15799217,
#    'Zetticci',
#    791,
#    'Germany',
#    'Female',
#    35,
#    7,
#    52436.2,
#    1,
#    1,
#    0,
#    161051.75,
#    0],
#   [271,
#    15787071,
#    'Dulhunty',
#    650,
#    'Spain',
#    'Male',
#    41,
#    9,
#    0.0,
#    2,
#    0,
#    1,
#    191599.67,
#    0],
#   [272,
#    15619955,
#    'Bevington',
#    733,
#    'Germany',
#    'Male',
#    34,
#    3,
#    100337.96,
#    3,
#    1,
#    0,
#    48559.19,
#    1],
#   [273,
#    15796505,
#    'Boyle',
#    811,
#    'Germany',
#    'Female',
#    34,
#    1,
#    149297.19,
#    2,
#    1,
#    1,
#    186339.74,
#    0],
#   [274,
#    15725166,
#    'Newton',
#    707,
#    'France',
#    'Male',
#    30,
#    8,
#    0.0,
#    2,
#    1,
#    0,
#    33159.37,
#    0],
#   [275,
#    15800116,
#    'Bowman',
#    712,
#    'Germany',
#    'Male',
#    28,
#    4,
#    145605.44,
#    1,
#    0,
#    1,
#    93883.53,
#    0],
#   [276,
#    15758685,
#    'Dubinina',
#    706,
#    'Spain',
#    'Female',
#    37,
#    7,
#    0.0,
#    2,
#    1,
#    1,
#    110899.3,
#    0],
#   [277,
#    15694456,
#    'Toscani',
#    756,
#    'France',
#    'Male',
#    62,
#    3,
#    0.0,
#    1,
#    1,
#    1,
#    11199.04,
#    1],
#   [278,
#    15767339,
#    'Chiazagomekpere',
#    777,
#    'France',
#    'Female',
#    53,
#    10,
#    0.0,
#    2,
#    1,
#    0,
#    189992.97,
#    0],
#   [279,
#    15683562,
#    'Allen',
#    646,
#    'France',
#    'Male',
#    35,
#    6,
#    84026.86,
#    1,
#    0,
#    1,
#    164255.69,
#    0],
#   [280,
#    15782210,
#    "K'ung",
#    714,
#    'France',
#    'Male',
#    46,
#    1,
#    0.0,
#    1,
#    1,
#    0,
#    152167.79,
#    1],
#   [281,
#    15668893,
#    'Wilsmore',
#    782,
#    'France',
#    'Male',
#    39,
#    8,
#    0.0,
#    2,
#    1,
#    1,
#    33949.67,
#    0],
#   [282,
#    15669169,
#    'Hargreaves',
#    775,
#    'Spain',
#    'Male',
#    29,
#    10,
#    0.0,
#    2,
#    1,
#    1,
#    68143.93,
#    0],
#   [283,
#    15643024,
#    'Huang',
#    479,
#    'Germany',
#    'Male',
#    35,
#    4,
#    138718.92,
#    1,
#    1,
#    1,
#    47251.79,
#    1],
#   [284,
#    15699389,
#    "Ch'ien",
#    807,
#    'France',
#    'Male',
#    42,
#    7,
#    118274.71,
#    1,
#    1,
#    1,
#    25885.72,
#    0],
#   [285,
#    15708608,
#    'Wallwork',
#    799,
#    'France',
#    'Female',
#    22,
#    8,
#    174185.98,
#    2,
#    0,
#    1,
#    192633.85,
#    0],
#   [286,
#    15626144,
#    'Chu',
#    675,
#    'France',
#    'Male',
#    40,
#    7,
#    113208.86,
#    2,
#    1,
#    0,
#    34577.36,
#    0],
#   [287,
#    15573112,
#    'Kang',
#    602,
#    'Spain',
#    'Male',
#    29,
#    5,
#    103907.28,
#    1,
#    1,
#    0,
#    161229.84,
#    0],
#   [288,
#    15790678,
#    'Davidson',
#    475,
#    'France',
#    'Female',
#    32,
#    8,
#    119023.28,
#    1,
#    1,
#    0,
#    100816.29,
#    0],
#   [289,
#    15727556,
#    "O'Donnell",
#    744,
#    'Spain',
#    'Female',
#    26,
#    5,
#    166297.89,
#    1,
#    1,
#    1,
#    181694.44,
#    0],
#   [290,
#    15697307,
#    'Nnachetam',
#    588,
#    'Spain',
#    'Male',
#    34,
#    10,
#    0.0,
#    2,
#    1,
#    0,
#    79078.91,
#    0],
#   [291,
#    15652266,
#    'Chidiebele',
#    703,
#    'Germany',
#    'Male',
#    42,
#    9,
#    63227.0,
#    1,
#    0,
#    1,
#    137316.32,
#    0],
#   [292,
#    15607098,
#    'Ahmed',
#    747,
#    'Spain',
#    'Female',
#    41,
#    5,
#    94521.17,
#    2,
#    1,
#    0,
#    194926.86,
#    0],
#   [293,
#    15655774,
#    'Booth',
#    583,
#    'France',
#    'Male',
#    27,
#    7,
#    0.0,
#    2,
#    1,
#    0,
#    51285.49,
#    0],
#   [294,
#    15590241,
#    'Chuang',
#    750,
#    'Spain',
#    'Female',
#    34,
#    9,
#    112822.26,
#    1,
#    0,
#    0,
#    150401.53,
#    1],
#   [295,
#    15785819,
#    'Shao',
#    681,
#    'France',
#    'Male',
#    38,
#    3,
#    0.0,
#    2,
#    1,
#    1,
#    112491.96,
#    0],
#   [296,
#    15723654,
#    'Tsao',
#    773,
#    'France',
#    'Male',
#    25,
#    2,
#    135903.33,
#    1,
#    1,
#    0,
#    73656.38,
#    0],
#   [297,
#    15774510,
#    'Tien',
#    714,
#    'France',
#    'Female',
#    31,
#    4,
#    125169.26,
#    1,
#    1,
#    1,
#    106636.89,
#    0],
#   [298,
#    15684173,
#    'Chang',
#    687,
#    'Spain',
#    'Female',
#    44,
#    7,
#    0.0,
#    3,
#    1,
#    0,
#    155853.52,
#    1],
#   [299,
#    15650068,
#    'Johnson',
#    511,
#    'France',
#    'Male',
#    58,
#    0,
#    149117.31,
#    1,
#    1,
#    1,
#    162599.51,
#    0],
#   [300,
#    15811490,
#    'French',
#    627,
#    'France',
#    'Male',
#    33,
#    5,
#    0.0,
#    2,
#    1,
#    1,
#    103737.82,
#    0],
#   [301,
#    15803976,
#    'Efremov',
#    694,
#    'France',
#    'Female',
#    31,
#    10,
#    0.0,
#    2,
#    1,
#    0,
#    160990.27,
#    0],
#   [302,
#    15682541,
#    'Hartley',
#    616,
#    'Spain',
#    'Female',
#    36,
#    6,
#    132311.71,
#    1,
#    0,
#    0,
#    15462.84,
#    0],
#   [303,
#    15695699,
#    'Calabrese',
#    687,
#    'France',
#    'Male',
#    35,
#    8,
#    0.0,
#    2,
#    1,
#    0,
#    10334.05,
#    0],
#   [304,
#    15624188,
#    'Chiu',
#    712,
#    'France',
#    'Female',
#    33,
#    6,
#    0.0,
#    2,
#    1,
#    1,
#    190686.16,
#    0],
#   [305,
#    15812191,
#    'Brennan',
#    553,
#    'France',
#    'Male',
#    33,
#    4,
#    118082.89,
#    1,
#    0,
#    0,
#    94440.45,
#    0],
#   [306,
#    15636673,
#    'Onwuatuegwu',
#    667,
#    'France',
#    'Male',
#    31,
#    1,
#    119266.69,
#    1,
#    1,
#    1,
#    28257.63,
#    0],
#   [307,
#    15594898,
#    'Hewitt',
#    731,
#    'France',
#    'Male',
#    43,
#    2,
#    0.0,
#    1,
#    1,
#    1,
#    170034.95,
#    1],
#   [308,
#    15660211,
#    'Shih',
#    629,
#    'Germany',
#    'Male',
#    35,
#    7,
#    156847.29,
#    2,
#    1,
#    0,
#    31824.29,
#    0],
#   [309,
#    15773972,
#    'Balashov',
#    614,
#    'France',
#    'Male',
#    50,
#    4,
#    137104.47,
#    1,
#    1,
#    0,
#    127166.49,
#    1],
#   [310,
#    15746726,
#    'Doyle',
#    438,
#    'Germany',
#    'Male',
#    31,
#    8,
#    78398.69,
#    1,
#    1,
#    0,
#    44937.01,
#    0],
#   [311,
#    15712287,
#    'Pokrovskii',
#    652,
#    'France',
#    'Female',
#    80,
#    4,
#    0.0,
#    2,
#    1,
#    1,
#    188603.07,
#    0],
#   [312,
#    15702919,
#    'Collins',
#    729,
#    'Germany',
#    'Male',
#    30,
#    6,
#    63669.42,
#    1,
#    1,
#    0,
#    145111.37,
#    0],
#   [313,
#    15674398,
#    'Russo',
#    642,
#    'France',
#    'Male',
#    38,
#    3,
#    0.0,
#    2,
#    0,
#    0,
#    171463.83,
#    0],
#   [314,
#    15797960,
#    'Skinner',
#    806,
#    'Germany',
#    'Female',
#    59,
#    0,
#    135296.33,
#    1,
#    1,
#    0,
#    182822.5,
#    0],
#   [315,
#    15631868,
#    'Robertson',
#    744,
#    'Spain',
#    'Male',
#    36,
#    2,
#    153804.44,
#    1,
#    1,
#    1,
#    87213.33,
#    0],
#   [316,
#    15581539,
#    'Atkinson',
#    474,
#    'Spain',
#    'Male',
#    37,
#    3,
#    0.0,
#    2,
#    0,
#    0,
#    57175.32,
#    0],
#   [317,
#    15662736,
#    'Doyle',
#    559,
#    'France',
#    'Male',
#    49,
#    2,
#    147069.78,
#    1,
#    1,
#    0,
#    120540.83,
#    1],
#   [318,
#    15666252,
#    'Ritchie',
#    706,
#    'Spain',
#    'Male',
#    42,
#    9,
#    0.0,
#    2,
#    1,
#    1,
#    28714.34,
#    0],
#   [319,
#    15677512,
#    'McEncroe',
#    628,
#    'Spain',
#    'Female',
#    22,
#    3,
#    0.0,
#    1,
#    1,
#    0,
#    85426.28,
#    0],
#   [320,
#    15626114,
#    'Pearson',
#    429,
#    'France',
#    'Male',
#    24,
#    4,
#    95741.75,
#    1,
#    1,
#    0,
#    46170.75,
#    0],
#   [321,
#    15810834,
#    'Gordon',
#    525,
#    'Spain',
#    'Female',
#    57,
#    2,
#    145965.33,
#    1,
#    1,
#    1,
#    64448.36,
#    0],
#   [322,
#    15678910,
#    "Ts'ai",
#    680,
#    'France',
#    'Female',
#    30,
#    8,
#    141441.75,
#    1,
#    1,
#    1,
#    16278.97,
#    0],
#   [323,
#    15694408,
#    'Lung',
#    749,
#    'France',
#    'Male',
#    40,
#    1,
#    139290.41,
#    1,
#    1,
#    0,
#    182855.42,
#    1],
#   [324,
#    15585215,
#    'Yuan',
#    763,
#    'France',
#    'Female',
#    31,
#    4,
#    0.0,
#    2,
#    0,
#    0,
#    50404.72,
#    0],
#   [325,
#    15682757,
#    'Pardey',
#    734,
#    'France',
#    'Male',
#    30,
#    3,
#    0.0,
#    2,
#    1,
#    0,
#    107640.25,
#    0],
#   [326,
#    15736601,
#    'Tai',
#    716,
#    'France',
#    'Male',
#    35,
#    4,
#    144428.87,
#    1,
#    1,
#    0,
#    134132.65,
#    0],
#   [327,
#    15601848,
#    'Scott',
#    594,
#    'France',
#    'Male',
#    35,
#    2,
#    0.0,
#    2,
#    1,
#    0,
#    103480.69,
#    0],
#   [328,
#    15736008,
#    'Hunter',
#    644,
#    'France',
#    'Female',
#    46,
#    9,
#    95441.27,
#    1,
#    1,
#    0,
#    108761.05,
#    1],
#   [329,
#    15669064,
#    'Mazzanti',
#    671,
#    'Germany',
#    'Male',
#    35,
#    1,
#    144848.74,
#    1,
#    1,
#    1,
#    179012.3,
#    0],
#   [330,
#    15624528,
#    'L?',
#    664,
#    'Germany',
#    'Male',
#    26,
#    7,
#    116244.14,
#    2,
#    1,
#    1,
#    95145.14,
#    0],
#   [331,
#    15598493,
#    'Beach',
#    656,
#    'France',
#    'Male',
#    50,
#    7,
#    0.0,
#    2,
#    0,
#    1,
#    72143.44,
#    0],
#   [332,
#    15601274,
#    'Hsieh',
#    667,
#    'Spain',
#    'Female',
#    40,
#    1,
#    146502.07,
#    1,
#    1,
#    0,
#    19162.89,
#    0],
#   [333,
#    15702669,
#    'Faulkner',
#    663,
#    'Germany',
#    'Male',
#    44,
#    2,
#    117028.6,
#    2,
#    0,
#    1,
#    144680.18,
#    0],
#   [334,
#    15728669,
#    'Knowles',
#    584,
#    'Germany',
#    'Female',
#    30,
#    8,
#    112013.81,
#    1,
#    1,
#    0,
#    177772.03,
#    1],
#   [335,
#    15742668,
#    'Day',
#    626,
#    'Spain',
#    'Female',
#    37,
#    6,
#    108269.37,
#    1,
#    1,
#    0,
#    5597.94,
#    0],
#   [336,
#    15697441,
#    'Hsueh',
#    485,
#    'France',
#    'Male',
#    29,
#    7,
#    182123.79,
#    1,
#    1,
#    0,
#    116828.51,
#    1],
#   [337,
#    15740476,
#    'Tsao',
#    659,
#    'Germany',
#    'Female',
#    32,
#    3,
#    150923.74,
#    2,
#    0,
#    1,
#    174652.51,
#    0],
#   [338,
#    15648064,
#    'Kennedy',
#    649,
#    'France',
#    'Male',
#    33,
#    2,
#    0.0,
#    2,
#    1,
#    0,
#    2010.98,
#    0],
#   [339,
#    15636624,
#    'Nwabugwu',
#    805,
#    'Spain',
#    'Female',
#    39,
#    5,
#    165272.13,
#    1,
#    1,
#    0,
#    14109.85,
#    1],
#   [340,
#    15807923,
#    'Young',
#    716,
#    'Germany',
#    'Female',
#    39,
#    10,
#    115301.31,
#    1,
#    1,
#    0,
#    43527.4,
#    1],
#   [341,
#    15745844,
#    'Kerr',
#    642,
#    'Germany',
#    'Female',
#    40,
#    6,
#    129502.49,
#    2,
#    0,
#    1,
#    86099.23,
#    1],
#   [342,
#    15786170,
#    'Tien',
#    659,
#    'France',
#    'Male',
#    31,
#    4,
#    118342.26,
#    1,
#    0,
#    0,
#    161574.19,
#    0],
#   [343,
#    15681081,
#    'Marrero',
#    545,
#    'Spain',
#    'Female',
#    47,
#    5,
#    0.0,
#    2,
#    1,
#    1,
#    38970.14,
#    0],
#   [344,
#    15684484,
#    'White',
#    543,
#    'France',
#    'Male',
#    22,
#    8,
#    0.0,
#    2,
#    0,
#    0,
#    127587.22,
#    0],
#   [345,
#    15785869,
#    'Pisano',
#    718,
#    'France',
#    'Female',
#    25,
#    7,
#    0.0,
#    2,
#    1,
#    0,
#    30380.12,
#    0],
#   [346,
#    15763859,
#    'Brown',
#    840,
#    'France',
#    'Female',
#    43,
#    7,
#    0.0,
#    2,
#    1,
#    0,
#    90908.95,
#    0],
#   [347,
#    15658935,
#    'Freeman',
#    630,
#    'Germany',
#    'Female',
#    34,
#    9,
#    106937.05,
#    2,
#    1,
#    0,
#    138275.01,
#    0],
#   [348,
#    15747358,
#    'Russell',
#    643,
#    'Germany',
#    'Male',
#    59,
#    3,
#    170331.37,
#    1,
#    1,
#    1,
#    32171.79,
#    0],
#   [349,
#    15735203,
#    'Seleznyov',
#    654,
#    'Germany',
#    'Female',
#    32,
#    1,
#    114510.85,
#    1,
#    1,
#    1,
#    126143.23,
#    0],
#   [350,
#    15576256,
#    'Yusupova',
#    582,
#    'France',
#    'Male',
#    39,
#    5,
#    0.0,
#    2,
#    1,
#    1,
#    129892.93,
#    0],
#   [351,
#    15659420,
#    'Foley',
#    659,
#    'Spain',
#    'Male',
#    32,
#    3,
#    107594.11,
#    2,
#    1,
#    1,
#    102416.84,
#    0],
#   [352,
#    15593365,
#    'Shih',
#    762,
#    'Spain',
#    'Male',
#    39,
#    2,
# ...
#    'Bednall',
#    652,
#    'Spain',
#    'Female',
#    42,
#    4,
#    0.0,
#    2,
#    1,
#    1,
#    38152.01,
#    0],
#   [879,
#    15656333,
#    'Jen',
#    574,
#    'France',
#    'Female',
#    33,
#    3,
#    134348.57,
#    1,
#    1,
#    0,
#    63163.99,
#    0],
#   [880,
#    15697497,
#    'She',
#    518,
#    'France',
#    'Female',
#    45,
#    9,
#    105525.65,
#    2,
#    1,
#    1,
#    73418.29,
#    0],
#   [881,
#    15585362,
#    'Simmons',
#    749,
#    'France',
#    'Female',
#    60,
#    6,
#    0.0,
#    1,
#    1,
#    0,
#    17978.68,
#    1],
#   [882,
#    15571928,
#    'Fraser',
#    679,
#    'France',
#    'Female',
#    43,
#    4,
#    0.0,
#    3,
#    1,
#    0,
#    115136.51,
#    1],
#   [883,
#    15785519,
#    'May',
#    565,
#    'France',
#    'Male',
#    36,
#    6,
#    106192.1,
#    1,
#    1,
#    0,
#    149575.59,
#    0],
#   [884,
#    15743007,
#    'Seabrook',
#    643,
#    'France',
#    'Female',
#    45,
#    4,
#    45144.43,
#    1,
#    1,
#    0,
#    60917.24,
#    1],
#   [885,
#    15777211,
#    'Herrera',
#    515,
#    'France',
#    'Male',
#    65,
#    7,
#    92113.61,
#    1,
#    1,
#    1,
#    142548.33,
#    0],
#   [886,
#    15721935,
#    'Kincaid',
#    521,
#    'France',
#    'Male',
#    25,
#    7,
#    0.0,
#    2,
#    1,
#    1,
#    157878.67,
#    0],
#   [887,
#    15591711,
#    'Sleeman',
#    739,
#    'Spain',
#    'Male',
#    38,
#    0,
#    128366.44,
#    1,
#    1,
#    0,
#    12796.43,
#    0],
#   [888,
#    15625021,
#    'Hung',
#    585,
#    'France',
#    'Male',
#    42,
#    2,
#    0.0,
#    2,
#    1,
#    1,
#    18657.77,
#    0],
#   [889,
#    15702968,
#    'Artemieva',
#    733,
#    'Germany',
#    'Male',
#    74,
#    3,
#    106545.53,
#    1,
#    1,
#    1,
#    134589.58,
#    0],
#   [890,
#    15600462,
#    'Barwell',
#    542,
#    'France',
#    'Female',
#    43,
#    8,
#    145618.37,
#    1,
#    0,
#    1,
#    10350.74,
#    0],
#   [891,
#    15768104,
#    'Wright',
#    788,
#    'Spain',
#    'Male',
#    37,
#    8,
#    141541.25,
#    1,
#    0,
#    0,
#    66013.27,
#    0],
#   [892,
#    15780140,
#    'Bellucci',
#    435,
#    'Germany',
#    'Male',
#    32,
#    2,
#    57017.06,
#    2,
#    1,
#    1,
#    5907.11,
#    0],
#   [893,
#    15585255,
#    'Moore',
#    577,
#    'France',
#    'Male',
#    42,
#    9,
#    0.0,
#    1,
#    1,
#    0,
#    74077.91,
#    0],
#   [894,
#    15772781,
#    'Ball',
#    703,
#    'France',
#    'Female',
#    51,
#    3,
#    0.0,
#    3,
#    1,
#    1,
#    77294.56,
#    1],
#   [895,
#    15669987,
#    'Sung',
#    728,
#    'Germany',
#    'Female',
#    35,
#    8,
#    125884.95,
#    2,
#    1,
#    0,
#    54359.02,
#    1],
#   [896,
#    15697000,
#    'Mello',
#    728,
#    'Germany',
#    'Male',
#    32,
#    5,
#    61825.5,
#    1,
#    1,
#    1,
#    156124.93,
#    0],
#   [897,
#    15733119,
#    'Mistry',
#    718,
#    'France',
#    'Male',
#    35,
#    8,
#    0.0,
#    2,
#    1,
#    0,
#    94820.85,
#    0],
#   [898,
#    15782390,
#    "T'ien",
#    621,
#    'France',
#    'Female',
#    40,
#    6,
#    0.0,
#    1,
#    1,
#    0,
#    155155.25,
#    0],
#   [899,
#    15654700,
#    'Fallaci',
#    523,
#    'France',
#    'Female',
#    40,
#    2,
#    102967.41,
#    1,
#    1,
#    0,
#    128702.1,
#    1],
#   [900,
#    15632210,
#    'Hill',
#    657,
#    'Germany',
#    'Male',
#    25,
#    2,
#    171770.55,
#    1,
#    1,
#    0,
#    22745.5,
#    0],
#   [901,
#    15642041,
#    'Burns',
#    727,
#    'Germany',
#    'Male',
#    40,
#    1,
#    93051.64,
#    2,
#    1,
#    0,
#    71865.31,
#    1],
#   [902,
#    15709737,
#    'Hunter',
#    643,
#    'France',
#    'Male',
#    36,
#    7,
#    161064.64,
#    2,
#    0,
#    1,
#    84294.82,
#    0],
#   [903,
#    15792388,
#    'Li',
#    645,
#    'France',
#    'Female',
#    48,
#    7,
#    90612.34,
#    1,
#    1,
#    1,
#    149139.13,
#    0],
#   [904,
#    15786014,
#    'Ku',
#    568,
#    'France',
#    'Male',
#    28,
#    5,
#    145105.64,
#    2,
#    1,
#    0,
#    185489.11,
#    0],
#   [905,
#    15794580,
#    "Ch'en",
#    599,
#    'France',
#    'Male',
#    58,
#    4,
#    0.0,
#    1,
#    0,
#    0,
#    176407.15,
#    1],
#   [906,
#    15675964,
#    'Chukwukadibia',
#    672,
#    'France',
#    'Female',
#    45,
#    9,
#    0.0,
#    1,
#    1,
#    1,
#    92027.69,
#    1],
#   [907,
#    15814275,
#    'Zikoranachidimma',
#    685,
#    'France',
#    'Male',
#    33,
#    6,
#    174912.72,
#    1,
#    1,
#    1,
#    43932.54,
#    0],
#   [908,
#    15724848,
#    'Oluchukwu',
#    516,
#    'France',
#    'Female',
#    46,
#    1,
#    104947.72,
#    1,
#    1,
#    0,
#    115789.25,
#    1],
#   [909,
#    15754713,
#    'Rivera',
#    685,
#    'Spain',
#    'Male',
#    31,
#    10,
#    135213.71,
#    1,
#    1,
#    1,
#    125777.28,
#    0],
#   [910,
#    15693814,
#    'Niu',
#    806,
#    'Spain',
#    'Male',
#    25,
#    7,
#    0.0,
#    2,
#    1,
#    0,
#    18461.9,
#    0],
#   [911,
#    15599660,
#    'Bennett',
#    604,
#    'France',
#    'Male',
#    36,
#    6,
#    116229.85,
#    2,
#    1,
#    1,
#    79633.38,
#    0],
#   [912,
#    15746490,
#    'Wollstonecraft',
#    648,
#    'Spain',
#    'Female',
#    53,
#    6,
#    111201.41,
#    1,
#    1,
#    1,
#    121542.29,
#    0],
#   [913,
#    15566091,
#    'Thomsen',
#    545,
#    'Spain',
#    'Female',
#    32,
#    4,
#    0.0,
#    1,
#    1,
#    0,
#    94739.2,
#    0],
#   [914,
#    15655961,
#    'Palermo',
#    756,
#    'Germany',
#    'Male',
#    27,
#    1,
#    131899.0,
#    1,
#    1,
#    0,
#    93302.29,
#    0],
#   [915,
#    15710404,
#    'Chinwendu',
#    569,
#    'France',
#    'Male',
#    35,
#    10,
#    124525.52,
#    1,
#    1,
#    1,
#    193793.78,
#    0],
#   [916,
#    15775625,
#    'McKenzie',
#    596,
#    'France',
#    'Male',
#    47,
#    6,
#    0.0,
#    1,
#    1,
#    0,
#    74835.65,
#    0],
#   [917,
#    15792328,
#    'James',
#    475,
#    'France',
#    'Male',
#    39,
#    6,
#    0.0,
#    1,
#    1,
#    1,
#    56999.9,
#    1],
#   [918,
#    15719856,
#    'Lamb',
#    646,
#    'France',
#    'Female',
#    45,
#    3,
#    47134.75,
#    1,
#    1,
#    1,
#    57236.44,
#    0],
#   [919,
#    15593773,
#    'Olejuru',
#    784,
#    'Spain',
#    'Male',
#    35,
#    3,
#    0.0,
#    2,
#    0,
#    0,
#    81483.64,
#    0],
#   [920,
#    15733114,
#    'Hay',
#    552,
#    'Spain',
#    'Male',
#    45,
#    9,
#    0.0,
#    2,
#    1,
#    0,
#    26752.56,
#    0],
#   [921,
#    15797748,
#    'Lu',
#    729,
#    'France',
#    'Male',
#    44,
#    5,
#    0.0,
#    2,
#    0,
#    1,
#    9200.54,
#    0],
#   [922,
#    15743411,
#    'Chiawuotu',
#    609,
#    'Spain',
#    'Male',
#    61,
#    1,
#    0.0,
#    1,
#    1,
#    0,
#    22447.85,
#    1],
#   [923,
#    15753337,
#    'Yeates',
#    555,
#    'France',
#    'Male',
#    51,
#    5,
#    0.0,
#    3,
#    1,
#    0,
#    189122.89,
#    1],
#   [924,
#    15601026,
#    'Gallagher',
#    572,
#    'Germany',
#    'Female',
#    19,
#    1,
#    138657.08,
#    1,
#    1,
#    1,
#    16161.82,
#    0],
#   [925,
#    15658485,
#    'Heath',
#    785,
#    'France',
#    'Female',
#    34,
#    9,
#    70302.48,
#    1,
#    1,
#    1,
#    68600.36,
#    0],
#   [926,
#    15636731,
#    "Ts'ai",
#    714,
#    'Germany',
#    'Female',
#    36,
#    1,
#    101609.01,
#    2,
#    1,
#    1,
#    447.73,
#    0],
#   [927,
#    15628303,
#    'Thurgood',
#    738,
#    'Spain',
#    'Male',
#    35,
#    3,
#    0.0,
#    1,
#    1,
#    1,
#    15650.73,
#    0],
#   [928,
#    15633461,
#    'Pai',
#    639,
#    'Germany',
#    'Male',
#    38,
#    5,
#    130170.82,
#    1,
#    1,
#    1,
#    149599.62,
#    0],
#   [929,
#    15677135,
#    'Lorenzo',
#    520,
#    'Germany',
#    'Male',
#    61,
#    8,
#    133802.29,
#    2,
#    1,
#    1,
#    90304.01,
#    0],
#   [930,
#    15590876,
#    'Knupp',
#    764,
#    'France',
#    'Female',
#    24,
#    7,
#    106234.02,
#    1,
#    0,
#    0,
#    115676.38,
#    0],
#   [931,
#    15790782,
#    'Baryshnikov',
#    661,
#    'Spain',
#    'Male',
#    39,
#    6,
#    132628.98,
#    1,
#    0,
#    0,
#    38812.67,
#    0],
#   [932,
#    15700476,
#    'Azubuike',
#    564,
#    'Germany',
#    'Male',
#    41,
#    9,
#    103522.75,
#    2,
#    1,
#    1,
#    34338.21,
#    0],
#   [933,
#    15634141,
#    'Shephard',
#    708,
#    'Germany',
#    'Female',
#    42,
#    8,
#    192390.52,
#    2,
#    1,
#    0,
#    823.36,
#    0],
#   [934,
#    15737795,
#    'Scott',
#    512,
#    'Spain',
#    'Male',
#    36,
#    1,
#    0.0,
#    1,
#    0,
#    1,
#    135482.26,
#    1],
#   [935,
#    15790299,
#    'Williamson',
#    592,
#    'Spain',
#    'Male',
#    37,
#    9,
#    0.0,
#    3,
#    1,
#    1,
#    10656.89,
#    0],
#   [936,
#    15675316,
#    'Avdeeva',
#    619,
#    'France',
#    'Female',
#    38,
#    3,
#    0.0,
#    2,
#    0,
#    1,
#    116467.35,
#    0],
#   [937,
#    15613630,
#    'Tang',
#    775,
#    'France',
#    'Male',
#    52,
#    8,
#    109922.61,
#    1,
#    1,
#    1,
#    96823.32,
#    1],
#   [938,
#    15662100,
#    'Hsu',
#    850,
#    'Germany',
#    'Female',
#    44,
#    5,
#    128605.32,
#    1,
#    0,
#    1,
#    171096.2,
#    0],
#   [939,
#    15668032,
#    'Buchanan',
#    577,
#    'France',
#    'Female',
#    37,
#    4,
#    0.0,
#    1,
#    1,
#    1,
#    79881.39,
#    0],
#   [940,
#    15599289,
#    'Yeh',
#    724,
#    'France',
#    'Female',
#    37,
#    10,
#    68598.56,
#    1,
#    1,
#    0,
#    157862.82,
#    0],
#   [941,
#    15754084,
#    'Palazzi',
#    710,
#    'Spain',
#    'Male',
#    35,
#    1,
#    106518.52,
#    1,
#    1,
#    1,
#    127951.81,
#    0],
#   [942,
#    15676521,
#    'Y?an',
#    696,
#    'France',
#    'Female',
#    31,
#    8,
#    0.0,
#    2,
#    0,
#    0,
#    191074.11,
#    0],
#   [943,
#    15804586,
#    'Lin',
#    376,
#    'France',
#    'Female',
#    46,
#    6,
#    0.0,
#    1,
#    1,
#    0,
#    157333.69,
#    1],
#   [944,
#    15781465,
#    'Schofield',
#    675,
#    'Germany',
#    'Female',
#    29,
#    8,
#    121326.42,
#    1,
#    1,
#    0,
#    133457.52,
#    0],
#   [945,
#    15729362,
#    'Lombardi',
#    745,
#    'France',
#    'Male',
#    36,
#    8,
#    67226.37,
#    1,
#    1,
#    0,
#    130789.6,
#    0],
#   [946,
#    15709295,
#    'Wall',
#    697,
#    'Spain',
#    'Female',
#    25,
#    5,
#    82931.85,
#    2,
#    1,
#    1,
#    128373.88,
#    0],
#   [947,
#    15745324,
#    'Milani',
#    599,
#    'Spain',
#    'Female',
#    39,
#    4,
#    0.0,
#    1,
#    1,
#    0,
#    194273.2,
#    1],
#   [948,
#    15741336,
#    'Ejimofor',
#    715,
#    'France',
#    'Female',
#    38,
#    5,
#    118590.41,
#    1,
#    1,
#    1,
#    5684.17,
#    1],
#   [949,
#    15783659,
#    'Blackburn',
#    659,
#    'France',
#    'Male',
#    67,
#    4,
#    145981.87,
#    1,
#    1,
#    1,
#    131043.2,
#    0],
#   [950,
#    15620981,
#    'Wickham',
#    684,
#    'France',
#    'Female',
#    48,
#    3,
#    73309.38,
#    1,
#    0,
#    0,
#    21228.34,
#    1],
#   [951,
#    15630328,
#    'Bird',
#    635,
#    'France',
#    'Female',
#    48,
#    8,
#    130796.33,
#    2,
#    1,
#    1,
#    43250.3,
#    0],
#   [952,
#    15785899,
#    "Ch'en",
#    789,
#    'Germany',
#    'Male',
#    33,
#    8,
#    151607.56,
#    1,
#    1,
#    0,
#    4389.4,
#    0],
#   [953,
#    15606149,
#    'Wood',
#    571,
#    'Germany',
#    'Female',
#    66,
#    9,
#    111577.01,
#    1,
#    0,
#    1,
#    189271.9,
#    0],
#   [954,
#    15671139,
#    'Brizendine',
#    694,
#    'Spain',
#    'Male',
#    39,
#    0,
#    107042.74,
#    1,
#    1,
#    1,
#    102284.2,
#    0],
#   [955,
#    15660429,
#    "Ch'in",
#    665,
#    'Spain',
#    'Female',
#    42,
#    2,
#    156371.61,
#    2,
#    0,
#    1,
#    156774.94,
#    1],
#   [956,
#    15571002,
#    'Yusupov',
#    706,
#    'France',
#    'Female',
#    44,
#    4,
#    129605.99,
#    1,
#    0,
#    0,
#    69865.49,
#    0],
#   [957,
#    15631681,
#    'Jibunoh',
#    807,
#    'Spain',
#    'Female',
#    43,
#    0,
#    0.0,
#    2,
#    0,
#    1,
#    85523.24,
#    0],
#   [958,
#    15731522,
#    "Ts'ui",
#    771,
#    'Spain',
#    'Female',
#    67,
#    8,
#    0.0,
#    2,
#    1,
#    1,
#    51219.8,
#    0],
#   [959,
#    15619529,
#    'Ndukaku',
#    531,
#    'Spain',
#    'Male',
#    27,
#    8,
#    132576.25,
#    1,
#    0,
#    0,
#    7222.92,
#    0],
#   [960,
#    15628034,
#    'Wilder',
#    629,
#    'France',
#    'Female',
#    37,
#    6,
#    129101.3,
#    1,
#    1,
#    1,
#    23971.33,
#    0],
#   [961,
#    15686164,
#    'Maclean',
#    850,
#    'Germany',
#    'Female',
#    31,
#    1,
#    108822.4,
#    1,
#    1,
#    1,
#    132173.31,
#    0],
#   [962,
#    15582797,
#    "Ch'iu",
#    685,
#    'Spain',
#    'Male',
#    35,
#    4,
#    137948.51,
#    1,
#    1,
#    0,
#    113639.64,
#    0],
#   [963,
#    15753831,
#    'Cox',
#    642,
#    'Spain',
#    'Male',
#    32,
#    7,
#    100433.8,
#    1,
#    1,
#    1,
#    39768.59,
#    0],
#   [964,
#    15731815,
#    'Nepean',
#    529,
#    'Spain',
#    'Male',
#    63,
#    4,
#    96134.11,
#    3,
#    1,
#    0,
#    108732.96,
#    1],
#   [965,
#    15580956,
#    'McNess',
#    683,
#    'Germany',
#    'Female',
#    43,
#    4,
#    115888.04,
#    1,
#    1,
#    1,
#    117349.19,
#    1],
#   [966,
#    15602084,
#    'Coles',
#    663,
#    'France',
#    'Female',
#    42,
#    5,
#    124626.07,
#    1,
#    1,
#    1,
#    78004.5,
#    0],
#   [967,
#    15589805,
#    'Benson',
#    563,
#    'France',
#    'Female',
#    34,
#    6,
#    139810.34,
#    1,
#    1,
#    1,
#    152417.79,
#    0],
#   [968,
#    15720893,
#    'Gilbert',
#    637,
#    'Spain',
#    'Female',
#    34,
#    9,
#    0.0,
#    2,
#    0,
#    0,
#    26057.08,
#    0],
#   [969,
#    15641009,
#    'Wilhelm',
#    544,
#    'France',
#    'Male',
#    37,
#    3,
#    84496.71,
#    1,
#    0,
#    0,
#    79972.09,
#    0],
#   [970,
#    15605926,
#    'Sinclair',
#    649,
#    'Germany',
#    'Male',
#    70,
#    9,
#    116854.71,
#    2,
#    0,
#    1,
#    107125.79,
#    0],
#   [971,
#    15805955,
#    'L?',
#    638,
#    'France',
#    'Female',
#    48,
#    10,
#    138333.03,
#    1,
#    1,
#    1,
#    47679.14,
#    0],
#   [972,
#    15801488,
#    'Buckner',
#    723,
#    'France',
#    'Male',
#    25,
#    3,
#    0.0,
#    2,
#    1,
#    1,
#    134509.47,
#    0],
#   [973,
#    15605918,
#    'Padovesi',
#    635,
#    'Germany',
#    'Male',
#    43,
#    5,
#    78992.75,
#    2,
#    0,
#    0,
#    153265.31,
#    0],
#   [974,
#    15779711,
#    'Gray',
#    750,
#    'Spain',
#    'Female',
#    38,
#    7,
#    97257.41,
#    2,
#    0,
#    1,
#    179883.04,
#    0],
#   [975,
#    15705620,
#    'Lu',
#    730,
#    'France',
#    'Male',
#    34,
#    5,
#    122453.37,
#    2,
#    1,
#    0,
#    138882.98,
#    0],
#   [976,
#    15685357,
#    'Wright',
#    750,
#    'Spain',
#    'Female',
#    36,
#    8,
#    112940.07,
#    1,
#    0,
#    1,
#    9855.81,
#    0],
#   [977,
#    15570060,
#    'Palerma',
#    586,
#    'France',
#    'Female',
#    43,
#    8,
#    132558.26,
#    1,
#    1,
#    0,
#    67046.83,
#    1],
#   [978,
#    15582616,
#    'Y?an',
#    520,
#    'France',
#    'Female',
#    38,
#    4,
#    0.0,
#    2,
#    1,
#    0,
#    56388.63,
#    0],
#   [979,
#    15799515,
#    'Wei',
#    652,
#    'France',
#    'Female',
#    48,
#    8,
#    133297.24,
#    1,
#    1,
#    0,
#    77764.37,
#    0],
#   [980,
#    15642937,
#    'Padovesi',
#    550,
#    'France',
#    'Female',
#    46,
#    7,
#    0.0,
#    2,
#    1,
#    0,
#    130590.35,
#    0],
#   [981,
#    15624729,
#    'Tsao',
#    594,
#    'France',
#    'Male',
#    27,
#    0,
#    197041.8,
#    1,
#    0,
#    0,
#    151912.49,
#    0],
#   [982,
#    15566156,
#    'Franklin',
#    749,
#    'Germany',
#    'Female',
#    44,
#    0,
#    71497.79,
#    2,
#    0,
#    0,
#    151083.8,
#    0],
#   [983,
#    15792360,
#    'Clark',
#    668,
#    'France',
#    'Male',
#    32,
#    7,
#    0.0,
#    2,
#    1,
#    1,
#    777.37,
#    0],
#   [984,
#    15807008,
#    'McGregor',
#    614,
#    'Germany',
#    'Female',
#    35,
#    6,
#    128100.28,
#    1,
#    0,
#    0,
#    69454.24,
#    1],
#   [985,
#    15704770,
#    'Pan',
#    773,
#    'France',
#    'Male',
#    25,
#    1,
#    124532.78,
#    2,
#    0,
#    1,
#    11723.57,
#    0],
#   [986,
#    15756475,
#    'Kenniff',
#    551,
#    'Germany',
#    'Male',
#    31,
#    9,
#    82293.82,
#    2,
#    1,
#    1,
#    91565.25,
#    0],
#   [987,
#    15655339,
#    'Spencer',
#    566,
#    'France',
#    'Male',
#    36,
#    1,
#    142120.91,
#    1,
#    1,
#    0,
#    79616.37,
#    0],
#   [988,
#    15613749,
#    'Lees',
#    569,
#    'Spain',
#    'Male',
#    34,
#    0,
#    151839.26,
#    1,
#    1,
#    0,
#    102299.81,
#    1],
#   [989,
#    15664521,
#    'David',
#    659,
#    'Spain',
#    'Male',
#    31,
#    7,
#    149620.88,
#    2,
#    1,
#    1,
#    104533.51,
#    0],
#   [990,
#    15681206,
#    'Hsing',
#    722,
#    'France',
#    'Female',
#    49,
#    3,
#    168197.66,
#    1,
#    1,
#    0,
#    140765.57,
#    1],
#   [991,
#    15745527,
#    'Burke',
#    655,
#    'France',
#    'Male',
#    37,
#    5,
#    93147.0,
#    2,
#    1,
#    0,
#    66214.13,
#    0],
#   [992,
#    15806926,
#    'Watson',
#    615,
#    'France',
#    'Female',
#    35,
#    2,
#    97440.02,
#    2,
#    1,
#    1,
#    139816.1,
#    0],
#   [993,
#    15724563,
#    'Hawkins',
#    752,
#    'Germany',
#    'Female',
#    42,
#    3,
#    65046.08,
#    2,
#    0,
#    1,
#    140139.28,
#    0],
#   [994,
#    15782899,
#    'Ginn',
#    661,
#    'Spain',
#    'Female',
#    28,
#    7,
#    95357.49,
#    1,
#    0,
#    0,
#    102297.15,
#    0],
#   [995,
#    15623521,
#    'Sozonov',
#    838,
#    'Spain',
#    'Male',
#    43,
#    9,
#    123105.88,
#    2,
#    1,
#    0,
#    145765.83,
#    0],
#   [996,
#    15810218,
#    'Sun',
#    610,
#    'Spain',
#    'Male',
#    29,
#    9,
#    0.0,
#    3,
#    0,
#    1,
#    83912.24,
#    0],
#   [997,
#    15645621,
#    'Hunter',
#    811,
#    'Spain',
#    'Male',
#    44,
#    3,
#    0.0,
#    2,
#    0,
#    1,
#    78439.73,
#    0],
#   [998,
#    15608114,
#    'Manfrin',
#    587,
#    'Spain',
#    'Male',
#    62,
#    7,
#    121286.27,
#    1,
#    0,
#    1,
#    6776.92,
#    0],
#   [999,
#    15659557,
#    'Artamonova',
#    811,
#    'Germany',
#    'Female',
#    28,
#    4,
#    167738.82,
#    2,
#    1,
#    1,
#    9903.42,
#    0],
#   [1000,
#    15787772,
#    'Hansen',
#    759,
#    'France',
#    'Female',
#    38,
#    1,
#    104091.29,
#    1,
#    0,
#    0,
#    91561.91,
#    0],
#   ...]}

# %%
# Convert the ARFF data to a pandas DataFrame
df = pd.DataFrame(arff_data["data"], columns=[attr[0] for attr in arff_data["attributes"]])

df.head()
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0          1    15634602  Hargrave          619    France  Female   42
# 1          2    15647311      Hill          608     Spain  Female   41
# 2          3    15619304      Onio          502    France  Female   42
# 3          4    15701354      Boni          699    France  Female   39
# 4          5    15737888  Mitchell          850     Spain  Female   43
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2       0.00              1          1               1
# 1       1   83807.86              1          0               1
# 2       8  159660.80              3          1               0
# 3       1       0.00              2          0               0
# 4       2  125510.82              1          1               1
#
#    EstimatedSalary  Exited
# 0        101348.88       1
# 1        112542.58       0
# 2        113931.57       1
# 3         93826.63       0
# 4         79084.10       0

# %%
df.shape
# Out:
# (10000, 14)

# %%
df.dtypes
# Out:
# RowNumber            int64
# CustomerId           int64
# Surname             object
# CreditScore          int64
# Geography           object
# Gender              object
# Age                  int64
# Tenure               int64
# Balance            float64
# NumOfProducts        int64
# HasCrCard            int64
# IsActiveMember       int64
# EstimatedSalary    float64
# Exited               int64
# dtype: object

# %%
df.isna().sum()
# Out:
# RowNumber          0
# CustomerId         0
# Surname            0
# CreditScore        0
# Geography          0
# Gender             0
# Age                0
# Tenure             0
# Balance            0
# NumOfProducts      0
# HasCrCard          0
# IsActiveMember     0
# EstimatedSalary    0
# Exited             0
# dtype: int64

# %%
df["CustomerId"].nunique()
# Out:
# 10000

# %%
#df.to_csv("../data/raw/dataset_churn.csv", index=True)

# %%
df_churn = df.drop(["RowNumber", "CustomerId", "Surname"], axis=1)
df_churn
# Out:
#       CreditScore Geography  Gender  Age  Tenure    Balance  NumOfProducts  \
# 0             619    France  Female   42       2       0.00              1
# 1             608     Spain  Female   41       1   83807.86              1
# 2             502    France  Female   42       8  159660.80              3
# 3             699    France  Female   39       1       0.00              2
# 4             850     Spain  Female   43       2  125510.82              1
# ...           ...       ...     ...  ...     ...        ...            ...
# 9995          771    France    Male   39       5       0.00              2
# 9996          516    France    Male   35      10   57369.61              1
# 9997          709    France  Female   36       7       0.00              1
# 9998          772   Germany    Male   42       3   75075.31              2
# 9999          792    France  Female   28       4  130142.79              1
#
#       HasCrCard  IsActiveMember  EstimatedSalary  Exited
# 0             1               1        101348.88       1
# 1             0               1        112542.58       0
# 2             1               0        113931.57       1
# 3             0               0         93826.63       0
# 4             1               1         79084.10       0
# ...         ...             ...              ...     ...
# 9995          1               0         96270.64       0
# 9996          1               1        101699.77       0
# 9997          0               1         42085.58       1
# 9998          1               0         92888.52       1
# 9999          1               0         38190.78       0
#
# [10000 rows x 11 columns]

# %%
df_churn.describe()
# Out:
#         CreditScore           Age        Tenure        Balance  NumOfProducts  \
# count  10000.000000  10000.000000  10000.000000   10000.000000   10000.000000
# mean     650.528800     38.921800      5.012800   76485.889288       1.530200
# std       96.653299     10.487806      2.892174   62397.405202       0.581654
# min      350.000000     18.000000      0.000000       0.000000       1.000000
# 25%      584.000000     32.000000      3.000000       0.000000       1.000000
# 50%      652.000000     37.000000      5.000000   97198.540000       1.000000
# 75%      718.000000     44.000000      7.000000  127644.240000       2.000000
# max      850.000000     92.000000     10.000000  250898.090000       4.000000
#
#          HasCrCard  IsActiveMember  EstimatedSalary        Exited
# count  10000.00000    10000.000000     10000.000000  10000.000000
# mean       0.70550        0.515100    100090.239881      0.203700
# std        0.45584        0.499797     57510.492818      0.402769
# min        0.00000        0.000000        11.580000      0.000000
# 25%        0.00000        0.000000     51002.110000      0.000000
# 50%        1.00000        1.000000    100193.915000      0.000000
# 75%        1.00000        1.000000    149388.247500      0.000000
# max        1.00000        1.000000    199992.480000      1.000000

# %%
# Calculate churn rate
total_customers = df_churn.shape[0]
churned_customers = df_churn[df_churn["Exited"] == 1].shape[0]

# Churn rate calculation
churn_rate = (churned_customers / total_customers) * 100
churn_rate
# Out:
# 20.369999999999997

# %% [markdown]
# ### General Analysis

# %%
#custom_palette = ["#dc9526", "#0c2054"]

# General Analysis
plt.figure(figsize=(15,5))

# Age Distribution 
plt.subplot(1,4,1)
sns.histplot(df_churn["Age"], bins=30, kde=True, color="#f4a261")
plt.title("Age Distribution")
#plt.xlabel("Age")

# Tenure Distribution
plt.subplot(1,4, 2)
sns.histplot(df_churn["Tenure"], bins=30, kde=True, color="#f4a261")
plt.title("Tenure Distribution")
#plt.xlabel("Balance")

# Balance Distribution 
plt.subplot(1,4, 3)
sns.histplot(df_churn["Balance"], bins=30, kde=True, color="#f4a261")
plt.title("Balance Distribution")
#plt.xlabel("Balance")

# Churn Rate 
plt.subplot(1,4,4)
sns.countplot(x="Exited", data=df_churn, hue= "Exited", legend= False, palette="Oranges")
plt.title("Churn Rate")
#plt.xlabel("Exited")



# Show the plots
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Analysis Churn Rates

# %%
#Checking the values
df_new = df_churn.groupby("Geography")["Exited"].value_counts().unstack(fill_value=0)
df_new["Total"] = df_new[0] + df_new[1]
df_new["Percentage_Exited"] = df_new[1] / df_new["Total"] * 100

print(df_new)
# Out:
# Exited        0    1  Total  Percentage_Exited
# Geography
# France     4204  810   5014          16.154767
# Germany    1695  814   2509          32.443204
# Spain      2064  413   2477          16.673395

# %%
#Checking values
df_churn["Geography"].value_counts()
# Out:
# Geography
# France     5014
# Germany    2509
# Spain      2477
# Name: count, dtype: int64

# %%
# Calculate the churn rate by Gender, IsActiveMember and Geography
churn_rate_by_gender = df_churn.groupby("Gender")["Exited"].apply(lambda x: (x.sum() / x.count()) * 100)
churn_rate_by_active = df_churn.groupby("IsActiveMember")["Exited"].apply(lambda x: (x.sum() / x.count()) * 100)
churn_rate_by_geography = df_churn.groupby("Geography")["Exited"].apply(lambda x: (x.sum() / x.count()) * 100)
churn_rate_by_tenure = df_churn.groupby("Tenure")["Exited"].apply(lambda x: (x.sum() / x.count()) * 100)

plt.figure(figsize=(14, 6))

# Churn rate by Gender
plt.subplot(1, 4, 1)
sns.barplot(x=churn_rate_by_gender.index, y=churn_rate_by_gender.values, hue= churn_rate_by_gender.index, legend= False, palette="Oranges")
plt.title("Churn Rate by Gender")
plt.ylabel("Churn Rate (%)")

# Churn rate by IsActiveMember
plt.subplot(1, 4, 2)
sns.barplot(x=churn_rate_by_active.index, y=churn_rate_by_active.values, hue= churn_rate_by_active.index, legend= False, palette="Oranges")
plt.title("Churn Rate by Active Membership")
plt.ylabel("Churn Rate (%)")

# Churn rate by Geography
plt.subplot(1, 4, 3)
sns.barplot(x=churn_rate_by_geography.index, y=churn_rate_by_geography.values, hue=churn_rate_by_geography.index, legend= False, palette="Oranges")
plt.title("Churn Rate by Geography")
plt.ylabel("Churn Rate (%)")

# Churn rate by Tenure
plt.subplot(1, 4, 4)
sns.barplot(x=churn_rate_by_tenure.index, y=churn_rate_by_tenure.values, hue=churn_rate_by_tenure.index, legend= False, palette="Oranges")
plt.title("Churn Rate by Tenure")
plt.ylabel("Churn Rate (%)")

plt.tight_layout()
plt.show()

# %%
# Datasets to csv files for Tableau
churn_rate_gender_df = churn_rate_by_gender.reset_index(name="Churn Rate by Gender")
churn_rate_active_df = churn_rate_by_active.reset_index(name="Churn Rate by Active Membership")
churn_rate_geography_df = churn_rate_by_geography.reset_index(name="Churn Rate by Geography")
churn_rate_tenure_df = churn_rate_by_tenure.reset_index(name="Churn Rate by Tenure")

churn_rate_gender_df.to_csv("../data/clean/churn_rate_by_gender.csv", index=False)
churn_rate_active_df.to_csv("../data/clean/churn_rate_by_active_membership.csv", index=False)
churn_rate_geography_df.to_csv("../data/clean//churn_rate_by_geography.csv", index=False)
churn_rate_tenure_df.to_csv("../data/clean/churn_rate_by_tenure.csv", index=False)

# %%
fig, axes = plt.subplots(1, 2, figsize=(10,5))

# Relationship between Age and Exited
sns.boxplot(x="Exited", y="Age", data=df_churn, ax=axes[0], hue="Exited", legend= False, palette="Oranges")
axes[0].set_title("Age vs Exited")

# Relationship between Balance and Exited
sns.boxplot(x="Exited", y="Balance", data=df_churn, ax=axes[1], hue="Exited", legend= False,palette="Oranges")
axes[1].set_title("Balance vs Exited")

plt.tight_layout()
plt.show()

# %%
sns.set_palette("Oranges")

# Distribution of Balance by Geography
plt.figure(figsize=(10, 6))
sns.boxplot(x="Geography", y="Balance", data=df_churn,hue= "Geography", legend= False, palette="Oranges")
plt.title("Distribution of Balance by Geography")
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Hypothesis testing

# %% [markdown]
# #### H0 = Active members are equally or more likely to churn compared to inactive members

# %%
# Both columns ("Exited " and "IsActiveMember") are categorical, then it is necessary to use Chi-square test

chi2_active, p_active, _, _ = chi2_contingency(pd.crosstab(df_churn["IsActiveMember"], df_churn["Exited"]))

print(f"Chi-Square Statistic: {chi2_active:.2f}")
print(f"p-value: {p_active:.2e}")

alpha = 0.05

if p_active < alpha:
    print("Reject H0. There is a significant difference between active and inactive members regarding churn.")
else:
    print("Fail to reject H0. No significant difference between active and inactive members regarding churn.")
# Out:
# Chi-Square Statistic: 242.99
# p-value: 8.79e-55
# Reject H0. There is a significant difference between active and inactive members regarding churn.

# %%
churned_inactive = df_churn[(df_churn["IsActiveMember"] == 0) & (df_churn["Exited"] == 1)].shape[0]#.count() # number of inactive members
total_inactive = df_churn[df_churn["IsActiveMember"] == 0].shape[0] # total numbers of inactive members

churned_active = df_churn[(df_churn["IsActiveMember"] == 1) & (df_churn["Exited"] == 1)].shape[0]
total_active = df_churn[df_churn["IsActiveMember"] == 1].shape[0]

# One-sided z-test for proportions
count = [churned_inactive, churned_active]
totals = [total_inactive, total_active]

z_stat, p_value = proportions_ztest(count, totals, alternative="larger")

print(f"z-statistic: {z_stat:.2f}")
print(f"p-value: {p_value:.2e}")

alpha = 0.05

if p_value < alpha:
    print("Reject H0. Active members are significantly less likely to churn than inactive members.")
else:
    print("Fail to reject H0. There is no significant difference in churn rates between active and inactive members.")
# Out:
# z-statistic: 15.61
# p-value: 2.98e-55
# Reject H0. Active members are significantly less likely to churn than inactive members.

# %%
# Checking results for Churn rate per Active member
churn_rates = df_churn.groupby("IsActiveMember")["Exited"].mean()
churn_rates
# Out:
# IsActiveMember
# 0    0.268509
# 1    0.142691
# Name: Exited, dtype: float64

# %% [markdown]
# #### H0 = Customers with higher balances are equally likely or more likely to churn compared to those with lower balances

# %%
balance_churned = df_churn[df_churn["Exited"] == 1]["Balance"]
balance_not_churned = df_churn[df_churn["Exited"] == 0]["Balance"]

# Independent two sample ttest 
t_stat_balance, p_value_balance = ttest_ind(balance_churned, balance_not_churned, alternative="greater", equal_var=False) # equal_var=False: in case of different variances

print(f"t-statistic: {t_stat_balance:.2f}")
print(f"p-value: {p_value_balance:.2e}")

alpha = 0.05

if p_value_balance < alpha:
    print("Reject H0: Customers with higher balances are less likely to churn compared to those with lower balances.") 
else:
    print("Fail to reject H0: There is no statistically significant evidence that customers with higher balances are less likely to churn.")
# Out:
# t-statistic: 12.47
# p-value: 3.16e-35
# Reject H0: Customers with higher balances are less likely to churn compared to those with lower balances.

# %%
# Ho : mean_balance_churned - mean_balance_not_churned <= 0
# H1: mean_balance_churned - mean_balance_not_churned > 0

#mean_balance_churned = balance_churned.mean()
#mean_balance_not_churned = balance_not_churned.mean()

#print(f"Mean balance for churned customers: {mean_balance_churned}")
#print(f"Mean balance for non-churned customers: {mean_balance_not_churned}")

#if mean_balance_churned > mean_balance_not_churned:
#    print("Churned customers tend to have higher balances on average.")
#else:
#    print("Non-churned customers tend to have higher balances on average.")

# %% [markdown]
# ### H0 = Older customers are equally or less likely to churn compared to younger customers

# %%
age_churned = df_churn[df_churn["Exited"] == 1]["Age"]
age_not_churned = df_churn[df_churn["Exited"] == 0]["Age"]

# Independent two sample ttest 
t_age, p_age = ttest_ind(age_churned, age_not_churned, alternative="greater", equal_var=False) # equal_var=False : in case of different variances

print(f"t-statistic: {t_age:.2f}")
print(f"p-value: {p_age:.2e}")

alpha = 0.05

if p_age < alpha:
    print("Reject H0. Older customers are significantly more likely to churn.")
else:
    print("Fail to reject H0. Age does not significantly affect churn.")
# Out:
# t-statistic: 30.42
# p-value: 2.36e-179
# Reject H0. Older customers are significantly more likely to churn.

# %%
mean_age_churned = age_churned.mean()
mean_age_not_churned = age_not_churned.mean()

print(f"Mean age for churned customers: {mean_age_churned}")
print(f"Mean age for non-churned customers: {mean_age_not_churned}")

#if mean_balance_churned > mean_balance_not_churned:
#    print("Churned customers tend to have higher age on average.")
#else:
#    print("Non-churned customers tend to have higher age on average.")
# Out:
# Mean age for churned customers: 44.8379970544919
# Mean age for non-churned customers: 37.40838879819164

# %%
# Check for outliers using boxplot 
plt.figure(figsize=(10, 6))

plt.boxplot([age_churned, age_not_churned])
plt.title("Age (Churned vs Not Churned)")
plt.grid(True)

plt.show()

# Check for outliers using IQR 
# Calculate IQR for churned customers
q1_churned, q3_churned = np.percentile(age_churned, [25, 75])
iqr_churned = q3_churned - q1_churned
lower_bound_churned = q1_churned - 1.5 * iqr_churned
upper_bound_churned = q3_churned + 1.5 * iqr_churned

# Calculate IQR for not churned customers
q1_not_churned, q3_not_churned = np.percentile(age_not_churned, [25, 75])
iqr_not_churned = q3_not_churned - q1_not_churned
lower_bound_not_churned = q1_not_churned - 1.5 * iqr_not_churned
upper_bound_not_churned = q3_not_churned + 1.5 * iqr_not_churned

# Identify outliers in both groups
outliers_churned = age_churned[(age_churned < lower_bound_churned) | (age_churned > upper_bound_churned)]
outliers_not_churned = age_not_churned[(age_not_churned < lower_bound_not_churned) | (age_not_churned > upper_bound_not_churned)]

outliers_churned, outliers_not_churned
# Out:
# (1410    73
#  2141    18
#  2553    71
#  3110    74
#  3317    71
#  3531    84
#  5664    71
#  6581    71
#  7058    71
#  7499    71
#  9555    72
#  9572    18
#  9646    71
#  Name: Age, dtype: int64,
#  42      61
#  44      61
#  85      75
#  158     73
#  181     65
#          ..
#  9897    61
#  9909    58
#  9936    77
#  9939    57
#  9979    58
#  Name: Age, Length: 486, dtype: int64)

# %%
# Remove outliers 
age_churned_no_outliers = age_churned[(age_churned >= lower_bound_churned) & (age_churned <= upper_bound_churned)]
age_not_churned_no_outliers = age_not_churned[(age_not_churned >= lower_bound_not_churned) & (age_not_churned <= upper_bound_not_churned)]

t_stat_no_outliers, p_value_no_outliers = ttest_ind(age_churned_no_outliers, age_not_churned_no_outliers, alternative="greater", equal_var=False)

# Mann-Whitney U test
mannwhitney_stat, mannwhitney_p_value = mannwhitneyu(age_churned, age_not_churned, alternative="greater")

(t_stat_no_outliers, p_value_no_outliers), (mannwhitney_stat, mannwhitney_p_value)
# Out:
# ((np.float64(40.18290221634959), np.float64(8.040859732461101e-277)),
#  (np.float64(11874649.5), np.float64(1.6052007159685838e-230)))

# %%
# Both methods confirm that older customers are significantly more likely to churn compared to younger customers.

# %% [markdown]
# ### H0 = There is no significant difference in churn rates across different geographical regions

# %%
contingency_table_geo = pd.crosstab(df_churn["Geography"], df_churn["Exited"])
chi2_geo, p_geo, _, _ = chi2_contingency(contingency_table_geo)

print(f"Chi-Square Statistic: {chi2_geo:.2f}")
print(f"p-value: {p_geo:.5f}")


alpha = 0.05
if p_geo < alpha:
    print("Reject H0. Churn rates vary significantly by geography.")
else:
    print("Fail to reject H0. There is no significant difference in churn rates by geography.")
# Out:
# Chi-Square Statistic: 301.26
# p-value: 0.00000
# Reject H0. Churn rates vary significantly by geography.

# %%
german_customers = df_churn[df_churn["Geography"] == "Germany"]

# Churn rate by age 
age_churn_germany = german_customers.groupby("Exited")["Age"].mean()

# Churn rate by balance 
balance_churn_germany = german_customers.groupby("Exited")["Balance"].mean()

# Churn rate by number of products 
products_churn_germany = german_customers.groupby("Exited")["NumOfProducts"].mean()

# Churn rate by activity status 
activity_churn_germany = german_customers.groupby("Exited")["IsActiveMember"].mean()

# Churn rate by gender 
gender_churn_germany = german_customers.groupby(["Exited", "Gender"]).size().unstack().apply(lambda x: x / x.sum() * 100, axis=1)

germany_churn_analysis = {
    "Attribute": ["Average Age", "Average Balance", "Average Number of Products", "Activity (IsActiveMember)"],
    "Non-Churned (0)": [age_churn_germany[0], balance_churn_germany[0], products_churn_germany[0], activity_churn_germany[0]],
    "Churned (1)": [age_churn_germany[1], balance_churn_germany[1], products_churn_germany[1], activity_churn_germany[1]]
}

churn_analysis_df = pd.DataFrame(germany_churn_analysis)
print("Churn Analysis for Germany:")
display(churn_analysis_df)

print("\nChurn Rate by Gender for Germany (%):")
display(gender_churn_germany)
# Out:
# Churn Analysis for Germany:
#                     Attribute  Non-Churned (0)    Churned (1)
# 0                 Average Age        37.311504      44.894349
# 1             Average Balance    119427.106696  120361.075590
# 2  Average Number of Products         1.551032       1.454545
# 3   Activity (IsActiveMember)         0.561652       0.363636
# Churn Rate by Gender for Germany (%):
# Gender     Female       Male
# Exited
# 0       43.952802  56.047198
# 1       55.036855  44.963145

# %%
#gender_churn_germany = pd.DataFrame()

#gender_churn_germany.to_csv("../data/clean/gender_churn_germany.csv", index=False)

#churn_analysis_df.to_csv("../data/clean/german_churn_analysis_df.csv", index=False)

# %%
# Encoding categorical columns
df_encoded = pd.get_dummies(df_churn, columns=["Geography", "Gender"])

correlation_matrix_encoded = df_encoded.corr()

# Plotting the heatmap of the correlation matrix with encoded columns
plt.figure(figsize=(12, 10))
sns.heatmap(correlation_matrix_encoded, annot=True, cmap="Oranges", fmt=".2f", linewidths=0.5)

plt.tight_layout()
plt.show()

# %%
sns.pairplot(df_encoded, y_vars=["Exited"], x_vars=df_encoded.columns[:-1], kind="scatter");

# %%
features = df_encoded.drop(columns = ["Exited"])
target = df_encoded["Exited"]

# %%
X_train, X_test, y_train, y_test = train_test_split(features, target, test_size=0.20, random_state=0)

# %% [markdown]
# ### KNN Classifier

# %%
knn = KNeighborsClassifier(n_neighbors=10)

# %%
knn.fit(X_train, y_train)
# Out:
# KNeighborsClassifier(n_neighbors=10)

# %%
pred = knn.predict(X_test)
pred
# Out:
# array([0, 0, 0, ..., 0, 0, 0])

# %%
y_test.values
# Out:
# array([0, 1, 0, ..., 0, 0, 0])

# %%
print(f"The accuracy of the model is {knn.score(X_test, y_test)*100: .2f}%")
# Out:
# The accuracy of the model is  79.35%

# %% [markdown]
# ### Normalization

# %%
normalizer = MinMaxScaler()

# %%
normalizer.fit(X_train)
# Out:
# MinMaxScaler()

# %%
X_train_norm = normalizer.transform(X_train)

X_test_norm = normalizer.transform(X_test)

# %%
X_train_norm = pd.DataFrame(X_train_norm, columns=X_train.columns, index=X_train.index ) # Here index is used keep the rows with the same index as in the df
X_train_norm.head()
# Out:
#       CreditScore       Age  Tenure   Balance  NumOfProducts  HasCrCard  \
# 7389        0.634  0.228571     0.5  0.000000       0.333333        1.0
# 9275        0.154  0.342857     0.1  0.317473       0.000000        1.0
# 2995        0.370  0.157143     0.2  0.471364       0.000000        1.0
# 5316        0.608  0.314286     0.5  0.443327       0.000000        1.0
# 356         1.000  0.557143     0.8  0.531808       0.333333        1.0
#
#       IsActiveMember  EstimatedSalary  Geography_France  Geography_Germany  \
# 7389             0.0         0.819174               0.0                0.0
# 9275             1.0         0.285459               0.0                1.0
# 2995             0.0         0.928185               1.0                0.0
# 5316             0.0         0.868110               0.0                0.0
# 356              1.0         0.661498               0.0                0.0
#
#       Geography_Spain  Gender_Female  Gender_Male
# 7389              1.0            1.0          0.0
# 9275              0.0            0.0          1.0
# 2995              0.0            1.0          0.0
# 5316              1.0            0.0          1.0
# 356               1.0            1.0          0.0

# %%
X_test_norm = pd.DataFrame(X_test_norm, columns=X_test.columns, index=X_test.index)
X_test_norm.head()
# Out:
#       CreditScore       Age  Tenure   Balance  NumOfProducts  HasCrCard  \
# 9394        0.494  0.242857     0.8  0.549949       0.000000        1.0
# 898         0.346  0.314286     0.2  0.431933       0.000000        1.0
# 2398        0.712  0.342857     0.8  0.400133       0.000000        1.0
# 5906        0.876  0.200000     0.4  0.470157       0.000000        0.0
# 2343        0.712  0.285714     0.5  0.683907       0.333333        1.0
#
#       IsActiveMember  EstimatedSalary  Geography_France  Geography_Germany  \
# 9394             1.0         0.964298               0.0                1.0
# 898              0.0         0.643514               1.0                0.0
# 2398             1.0         0.378640               0.0                0.0
# 5906             0.0         0.446828               1.0                0.0
# 2343             1.0         0.678318               0.0                1.0
#
#       Geography_Spain  Gender_Female  Gender_Male
# 9394              0.0            1.0          0.0
# 898               0.0            1.0          0.0
# 2398              1.0            1.0          0.0
# 5906              0.0            0.0          1.0
# 2343              0.0            0.0          1.0

# %%
knn = KNeighborsClassifier(n_neighbors=10)

# %%
knn.fit(X_train_norm, y_train)
# Out:
# KNeighborsClassifier(n_neighbors=10)

# %%
print(f"The accuracy of the model is {knn.score(X_test_norm, y_test)*100: .2f}%")
# Out:
# The accuracy of the model is  81.90%

# %% [markdown]
# ### StandardScaler

# %%
scaler = StandardScaler()

# %%
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %%
X_train_scaled_df = pd.DataFrame(X_train_scaled, columns=X_train.columns, index=X_train.index)
X_test_scaled_df = pd.DataFrame(X_test_scaled, columns=X_test.columns, index=X_test.index)

# %%
X_train_scaled_df.columns
# Out:
# Index(['CreditScore', 'Age', 'Tenure', 'Balance', 'NumOfProducts', 'HasCrCard',
#        'IsActiveMember', 'EstimatedSalary', 'Geography_France',
#        'Geography_Germany', 'Geography_Spain', 'Gender_Female', 'Gender_Male'],
#       dtype='object')

# %%
X_train_scaled_df.head()
# Out:
#       CreditScore       Age    Tenure   Balance  NumOfProducts  HasCrCard  \
# 7389     0.169582 -0.464608  0.006661 -1.215717       0.809503   0.642595
# 9275    -2.304559  0.301026 -1.377440 -0.006312      -0.921591   0.642595
# 2995    -1.191196 -0.943129 -1.031415  0.579935      -0.921591   0.642595
# 5316     0.035566  0.109617  0.006661  0.473128      -0.921591   0.642595
# 356      2.056114  1.736588  1.044737  0.810193       0.809503   0.642595
#
#       IsActiveMember  EstimatedSalary  Geography_France  Geography_Germany  \
# 7389       -1.032270         1.106432         -1.014607          -0.569844
# 9275        0.968738        -0.748664         -1.014607           1.754865
# 2995       -1.032270         1.485335          0.985604          -0.569844
# 5316       -1.032270         1.276528         -1.014607          -0.569844
# 356         0.968738         0.558378         -1.014607          -0.569844
#
#       Geography_Spain  Gender_Female  Gender_Male
# 7389         1.743090       1.091687    -1.091687
# 9275        -0.573694      -0.916013     0.916013
# 2995        -0.573694       1.091687    -1.091687
# 5316         1.743090      -0.916013     0.916013
# 356          1.743090       1.091687    -1.091687

# %%
knn = KNeighborsClassifier(n_neighbors=10)

knn.fit(X_train_scaled, y_train)

y_pred_knn = knn.predict(X_test_scaled)

# Evaluation
accuracy_knn = accuracy_score(y_test, y_pred_knn)*100
classification_report_knn = classification_report(y_test, y_pred_knn)

print(f"KNN Accuracy: {accuracy_knn}%")
print(f"KNN Classification Report:\n{classification_report_knn}")
# Out:
# KNN Accuracy: 84.0%
# KNN Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.85      0.97      0.91      1595
#            1       0.73      0.33      0.46       405
#
#     accuracy                           0.84      2000
#    macro avg       0.79      0.65      0.68      2000
# weighted avg       0.83      0.84      0.82      2000

# %% [markdown]
# ### Logistic Regression

# %%
log_reg = LogisticRegression(random_state=0)

# %%
log_reg.fit(X_train_scaled, y_train)
# Out:
# LogisticRegression(random_state=0)

# %%
y_pred_log_reg = log_reg.predict(X_test_scaled)

# Evaluation
accuracy_log_reg = accuracy_score(y_test, y_pred_log_reg)* 100
classification_report_log_reg = classification_report(y_test, y_pred_log_reg)

print(f"Logistic Regression Accuracy: {accuracy_log_reg}%")
print(f"Logistic Regression Classification Report:\n{classification_report_log_reg}")
# Out:
# Logistic Regression Accuracy: 81.10000000000001%
# Logistic Regression Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.83      0.96      0.89      1595
#            1       0.58      0.24      0.34       405
#
#     accuracy                           0.81      2000
#    macro avg       0.71      0.60      0.61      2000
# weighted avg       0.78      0.81      0.78      2000

# %% [markdown]
# ### Bagging and Pasting

# %%
bagging_class = BaggingClassifier(DecisionTreeClassifier(max_depth=20),
                               n_estimators=100, # number of models to use
                               max_samples = 1000)

# %%
bagging_class.fit(X_train_scaled, y_train)
# Out:
# BaggingClassifier(estimator=DecisionTreeClassifier(max_depth=20),
#                   max_samples=1000, n_estimators=100)

# %%
y_pred_bagging = bagging_class.predict(X_test_scaled)

# Evaluation
accuracy_bagging = accuracy_score(y_test, y_pred_bagging)*100
classification_report_bagging = classification_report(y_test, y_pred_bagging)

print(f"Bagging Classifier Accuracy: {accuracy_bagging}%")
print(f"Bagging Classifier Classification Report:\n{classification_report_bagging}")
# Out:
# Bagging Classifier Accuracy: 86.56666666666666%
# Bagging Classifier Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.88      0.97      0.92      2416
#            1       0.79      0.43      0.55       584
#
#     accuracy                           0.87      3000
#    macro avg       0.83      0.70      0.74      3000
# weighted avg       0.86      0.87      0.85      3000

# %% [markdown]
# ### Random Forest

# %%
forest = RandomForestClassifier(random_state=0)

# %%
forest.fit(X_train_scaled, y_train)
# Out:
# RandomForestClassifier(random_state=0)

# %%
y_pred_rf = forest.predict(X_test_scaled)

# Evaluation
accuracy_rf = accuracy_score(y_test, y_pred_rf) *100
classification_report_rf = classification_report(y_test, y_pred_rf)

print(f"Random Forest Accuracy: {accuracy_rf}%")
print(f"Random Forest Classification Report:\n{classification_report_rf}")
# Out:
# Random Forest Accuracy: 86.7%
# Random Forest Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.89      0.96      0.92      1595
#            1       0.75      0.51      0.61       405
#
#     accuracy                           0.87      2000
#    macro avg       0.82      0.73      0.76      2000
# weighted avg       0.86      0.87      0.86      2000

# %% [markdown]
# ### AdaBoost

# %%
ada_reg = AdaBoostClassifier(DecisionTreeClassifier(max_depth=20),
                            n_estimators=100)

# %%
ada_reg.fit(X_train_scaled, y_train)
# Out:
# c:\Users\lored\Documents\Ironhack\Project\final_project\.venv\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:527: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# AdaBoostClassifier(estimator=DecisionTreeClassifier(max_depth=20),
#                    n_estimators=100)

# %%
y_pred_ada = ada_reg.predict(X_test_scaled)


# Evaluation
accuracy_ada = accuracy_score(y_test, y_pred_ada)* 100
classification_report_ada = classification_report(y_test, y_pred_ada)

print(f"AdaBoost Classifier Accuracy: {accuracy_ada}%")
print(f"AdaBoost Classifier Classification Report:\n{classification_report_ada}")
# Out:
# AdaBoost Classifier Accuracy: 84.39999999999999%
# AdaBoost Classifier Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.87      0.95      0.91      1595
#            1       0.68      0.43      0.53       405
#
#     accuracy                           0.84      2000
#    macro avg       0.77      0.69      0.72      2000
# weighted avg       0.83      0.84      0.83      2000

# %% [markdown]
# ### Gradient Boosting

# %%
gb_reg = GradientBoostingClassifier(random_state=0)

# %%
gb_reg.fit(X_train_scaled, y_train)
# Out:
# GradientBoostingClassifier(random_state=0)

# %%
y_pred_gb = gb_reg.predict(X_test_scaled)

accuracy_gb = accuracy_score(y_test, y_pred_gb) *100
classification_report_gb = classification_report(y_test, y_pred_gb)

print(f"Gradient Boosting Accuracy: {accuracy_gb}%")
print(f"Gradient Boosting Classification Report:\n{classification_report_gb}")
# Out:
# Gradient Boosting Accuracy: 86.85000000000001%
# Gradient Boosting Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.89      0.96      0.92      1595
#            1       0.76      0.52      0.61       405
#
#     accuracy                           0.87      2000
#    macro avg       0.82      0.74      0.77      2000
# weighted avg       0.86      0.87      0.86      2000

# %% [markdown]
# ### Hyperparamenter Tuning

# %% [markdown]
# ### Random Search

# %%
#param_dist = {
#    'n_estimators': [100, 200, 300, 400, 500],
#    'learning_rate': [0.01, 0.05, 0.1, 0.2, 0.3],
#    'max_depth': [3, 4, 5, 6, 7],
#    'min_samples_split': [2, 5, 10],
#    'min_samples_leaf': [1, 2, 4]
#}

#gb = GradientBoostingClassifier(n_iter_no_change=10, validation_fraction=0.1)

#random_search = RandomizedSearchCV(estimator=gb, param_distributions=param_dist, n_iter=20, 
#                                   cv=3, n_jobs=-1, verbose=1, random_state=42, scoring='accuracy')

#random_search.fit(X_train_scaled, y_train)

# Get the best parameters and best estimator
#best_random_params = random_search.best_params_
#best_random_gb_model = random_search.best_estimator_

# Evaluation
#y_pred_best_random_gb = best_random_gb_model.predict(X_test_scaled)
#best_random_gb_test_accuracy = accuracy_score(y_test, y_pred_best_random_gb)

#print("Best Parameters:", best_random_params)
#print("Test Accuracy of Best Model:", best_random_gb_test_accuracy)
# Out:
# Fitting 3 folds for each of 20 candidates, totalling 60 fits
# Best Parameters: {'n_estimators': 300, 'min_samples_split': 10, 'min_samples_leaf': 1, 'max_depth': 7, 'learning_rate': 0.01}
# Test Accuracy of Best Model: 0.869

# %%
# OUtput
#Fitting 3 folds for each of 20 candidates, totalling 60 fits
#Best Parameters: {'n_estimators': 300, 'min_samples_split': 10, 'min_samples_leaf': 1, 'max_depth': 7, 'learning_rate': 0.01}
#Test Accuracy of Best Model: 0.869

# %%
final_gb = GradientBoostingClassifier (n_estimators= 300, min_samples_split= 10, min_samples_leaf= 1, max_depth= 7, learning_rate= 0.01, random_state=0)
final_gb.fit(X_train_scaled, y_train)
# Out:
# GradientBoostingClassifier(learning_rate=0.01, max_depth=7,
#                            min_samples_split=10, n_estimators=300,
#                            random_state=0)

# %%
y_pred_final_gb = final_gb.predict(X_test_scaled)

accuracy_final = accuracy_score(y_test, y_pred_final_gb)*100
classification_report_final = classification_report(y_test, y_pred_final_gb)

print(f"Gradient Boosting Tuning Classifier Accuracy: {accuracy_final}%")
print(f"Gradient Boosting Tuning Classification Report:\n{classification_report_final}")
# Out:
# Gradient Boosting Tuning Classifier Accuracy: 87.2%
# Gradient Boosting Tuning Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.88      0.97      0.92      2416
#            1       0.78      0.47      0.59       584
#
#     accuracy                           0.87      3000
#    macro avg       0.83      0.72      0.76      3000
# weighted avg       0.86      0.87      0.86      3000

# %% [markdown]
# ### Grid Search

# %%
param_grid = {
    'n_estimators': [100, 200],
    'learning_rate': [0.01, 0.1],
    'max_depth': [3, 5],
    'min_samples_split': [2, 5],
    'min_samples_leaf': [1, 2]
}

# %%
#grid = {"max_leaf_nodes": [100, 200, 300],
#        "max_depth":[3, 5, 7]}

# %%
gb_reg1 = GradientBoostingClassifier(random_state=0)

# %%
model1 = GridSearchCV(estimator = gb_reg1, param_grid = param_grid, cv=5, verbose=10)

# %%
#model1.fit(X_train_scaled, y_train)
# Out:
# Fitting 5 folds for each of 32 candidates, totalling 160 fits
# [CV 1/5; 1/32] START learning_rate=0.01, max_depth=3, min_samples_leaf=1, min_samples_split=2, n_estimators=100
# [CV 1/5; 1/32] END learning_rate=0.01, max_depth=3, min_samples_leaf=1, min_samples_split=2, n_estimators=100;, score=0.837 total time= 1.3min
# [CV 2/5; 1/32] START learning_rate=0.01, max_depth=3, min_samples_leaf=1, min_samples_split=2, n_estimators=100
# [CV 2/5; 1/32] END learning_rate=0.01, max_depth=3, min_samples_leaf=1, min_samples_split=2, n_estimators=100;, score=0.834 total time= 1.2min
# [CV 3/5; 1/32] START learning_rate=0.01, max_depth=3, min_samples_leaf=1, min_samples_split=2, n_estimators=100
# [CV 3/5; 1/32] END learning_rate=0.01, max_depth=3, min_samples_leaf=1, min_samples_split=2, n_estimators=100;, score=0.839 total time=  59.9s
# [CV 4/5; 1/32] START learning_rate=0.01, max_depth=3, min_samples_leaf=1, min_samples_split=2, n_estimators=100
# [CV 4/5; 1/32] END learning_rate=0.01, max_depth=3, min_samples_leaf=1, min_samples_split=2, n_estimators=100;, score=0.845 total time= 1.0min
# [CV 5/5; 1/32] START learning_rate=0.01, max_depth=3, min_samples_leaf=1, min_samples_split=2, n_estimators=100
# [CV 5/5; 1/32] END learning_rate=0.01, max_depth=3, min_samples_leaf=1, min_samples_split=2, n_estimators=100;, score=0.836 total time= 1.0min
# [CV 1/5; 2/32] START learning_rate=0.01, max_depth=3, min_samples_leaf=1, min_samples_split=2, n_estimators=200
# [CV 1/5; 2/32] END learning_rate=0.01, max_depth=3, min_samples_leaf=1, min_samples_split=2, n_estimators=200;, score=0.853 total time= 2.0min
# [CV 2/5; 2/32] START learning_rate=0.01, max_depth=3, min_samples_leaf=1, min_samples_split=2, n_estimators=200
# [CV 2/5; 2/32] END learning_rate=0.01, max_depth=3, min_samples_leaf=1, min_samples_split=2, n_estimators=200;, score=0.850 total time= 2.5min
# [CV 3/5; 2/32] START learning_rate=0.01, max_depth=3, min_samples_leaf=1, min_samples_split=2, n_estimators=200
# [CV 3/5; 2/32] END learning_rate=0.01, max_depth=3, min_samples_leaf=1, min_samples_split=2, n_estimators=200;, score=0.852 total time= 2.5min
# [CV 4/5; 2/32] START learning_rate=0.01, max_depth=3, min_samples_leaf=1, min_samples_split=2, n_estimators=200
# [CV 4/5; 2/32] END learning_rate=0.01, max_depth=3, min_samples_leaf=1, min_samples_split=2, n_estimators=200;, score=0.854 total time= 2.5min
# [CV 5/5; 2/32] START learning_rate=0.01, max_depth=3, min_samples_leaf=1, min_samples_split=2, n_estimators=200
# [CV 5/5; 2/32] END learning_rate=0.01, max_depth=3, min_samples_leaf=1, min_samples_split=2, n_estimators=200;, score=0.847 total time= 2.4min
# [CV 1/5; 3/32] START learning_rate=0.01, max_depth=3, min_samples_leaf=1, min_samples_split=5, n_estimators=100
# [CV 1/5; 3/32] END learning_rate=0.01, max_depth=3, min_samples_leaf=1, min_samples_split=5, n_estimators=100;, score=0.837 total time= 1.2min
# [CV 2/5; 3/32] START learning_rate=0.01, max_depth=3, min_samples_leaf=1, min_samples_split=5, n_estimators=100
# [CV 2/5; 3/32] END learning_rate=0.01, max_depth=3, min_samples_leaf=1, min_samples_split=5, n_estimators=100;, score=0.834 total time= 1.1min
# [CV 3/5; 3/32] START learning_rate=0.01, max_depth=3, min_samples_leaf=1, min_samples_split=5, n_estimators=100
# [CV 3/5; 3/32] END learning_rate=0.01, max_depth=3, min_samples_leaf=1, min_samples_split=5, n_estimators=100;, score=0.839 total time= 1.1min
# [CV 4/5; 3/32] START learning_rate=0.01, max_depth=3, min_samples_leaf=1, min_samples_split=5, n_estimators=100
# [CV 4/5; 3/32] END learning_rate=0.01, max_depth=3, min_samples_leaf=1, min_samples_split=5, n_estimators=100;, score=0.845 total time= 1.2min
# [CV 5/5; 3/32] START learning_rate=0.01, max_depth=3, min_samples_leaf=1, min_samples_split=5, n_estimators=100
# [CV 5/5; 3/32] END learning_rate=0.01, max_depth=3, min_samples_leaf=1, min_samples_split=5, n_estimators=100;, score=0.836 total time= 1.2min
# [CV 1/5; 4/32] START learning_rate=0.01, max_depth=3, min_samples_leaf=1, min_samples_split=5, n_estimators=200
# [CV 1/5; 4/32] END learning_rate=0.01, max_depth=3, min_samples_leaf=1, min_samples_split=5, n_estimators=200;, score=0.853 total time= 2.3min
# [CV 2/5; 4/32] START learning_rate=0.01, max_depth=3, min_samples_leaf=1, min_samples_split=5, n_estimators=200
# [CV 2/5; 4/32] END learning_rate=0.01, max_depth=3, min_samples_leaf=1, min_samples_split=5, n_estimators=200;, score=0.850 total time= 2.2min
# [CV 3/5; 4/32] START learning_rate=0.01, max_depth=3, min_samples_leaf=1, min_samples_split=5, n_estimators=200
# [CV 3/5; 4/32] END learning_rate=0.01, max_depth=3, min_samples_leaf=1, min_samples_split=5, n_estimators=200;, score=0.852 total time= 2.3min
# [CV 4/5; 4/32] START learning_rate=0.01, max_depth=3, min_samples_leaf=1, min_samples_split=5, n_estimators=200
# [CV 4/5; 4/32] END learning_rate=0.01, max_depth=3, min_samples_leaf=1, min_samples_split=5, n_estimators=200;, score=0.854 total time= 2.3min
# [CV 5/5; 4/32] START learning_rate=0.01, max_depth=3, min_samples_leaf=1, min_samples_split=5, n_estimators=200
# [CV 5/5; 4/32] END learning_rate=0.01, max_depth=3, min_samples_leaf=1, min_samples_split=5, n_estimators=200;, score=0.847 total time= 2.3min
# [CV 1/5; 5/32] START learning_rate=0.01, max_depth=3, min_samples_leaf=2, min_samples_split=2, n_estimators=100
# [CV 1/5; 5/32] END learning_rate=0.01, max_depth=3, min_samples_leaf=2, min_samples_split=2, n_estimators=100;, score=0.837 total time= 1.1min
# [CV 2/5; 5/32] START learning_rate=0.01, max_depth=3, min_samples_leaf=2, min_samples_split=2, n_estimators=100
# [CV 2/5; 5/32] END learning_rate=0.01, max_depth=3, min_samples_leaf=2, min_samples_split=2, n_estimators=100;, score=0.834 total time= 1.4min
# [CV 3/5; 5/32] START learning_rate=0.01, max_depth=3, min_samples_leaf=2, min_samples_split=2, n_estimators=100
# [CV 3/5; 5/32] END learning_rate=0.01, max_depth=3, min_samples_leaf=2, min_samples_split=2, n_estimators=100;, score=0.838 total time= 1.1min
# [CV 4/5; 5/32] START learning_rate=0.01, max_depth=3, min_samples_leaf=2, min_samples_split=2, n_estimators=100
# [CV 4/5; 5/32] END learning_rate=0.01, max_depth=3, min_samples_leaf=2, min_samples_split=2, n_estimators=100;, score=0.845 total time= 1.2min
# [CV 5/5; 5/32] START learning_rate=0.01, max_depth=3, min_samples_leaf=2, min_samples_split=2, n_estimators=100
# [CV 5/5; 5/32] END learning_rate=0.01, max_depth=3, min_samples_leaf=2, min_samples_split=2, n_estimators=100;, score=0.836 total time= 1.1min
# [CV 1/5; 6/32] START learning_rate=0.01, max_depth=3, min_samples_leaf=2, min_samples_split=2, n_estimators=200
# [CV 1/5; 6/32] END learning_rate=0.01, max_depth=3, min_samples_leaf=2, min_samples_split=2, n_estimators=200;, score=0.852 total time= 2.3min
# [CV 2/5; 6/32] START learning_rate=0.01, max_depth=3, min_samples_leaf=2, min_samples_split=2, n_estimators=200
# [CV 2/5; 6/32] END learning_rate=0.01, max_depth=3, min_samples_leaf=2, min_samples_split=2, n_estimators=200;, score=0.851 total time= 2.2min
# [CV 3/5; 6/32] START learning_rate=0.01, max_depth=3, min_samples_leaf=2, min_samples_split=2, n_estimators=200
# [CV 3/5; 6/32] END learning_rate=0.01, max_depth=3, min_samples_leaf=2, min_samples_split=2, n_estimators=200;, score=0.852 total time= 2.3min
# [CV 4/5; 6/32] START learning_rate=0.01, max_depth=3, min_samples_leaf=2, min_samples_split=2, n_estimators=200
# [CV 4/5; 6/32] END learning_rate=0.01, max_depth=3, min_samples_leaf=2, min_samples_split=2, n_estimators=200;, score=0.854 total time= 2.2min
# [CV 5/5; 6/32] START learning_rate=0.01, max_depth=3, min_samples_leaf=2, min_samples_split=2, n_estimators=200
# [CV 5/5; 6/32] END learning_rate=0.01, max_depth=3, min_samples_leaf=2, min_samples_split=2, n_estimators=200;, score=0.847 total time= 2.2min
# [CV 1/5; 7/32] START learning_rate=0.01, max_depth=3, min_samples_leaf=2, min_samples_split=5, n_estimators=100
# [CV 1/5; 7/32] END learning_rate=0.01, max_depth=3, min_samples_leaf=2, min_samples_split=5, n_estimators=100;, score=0.837 total time= 1.1min
# [CV 2/5; 7/32] START learning_rate=0.01, max_depth=3, min_samples_leaf=2, min_samples_split=5, n_estimators=100
# [CV 2/5; 7/32] END learning_rate=0.01, max_depth=3, min_samples_leaf=2, min_samples_split=5, n_estimators=100;, score=0.834 total time= 1.1min
# [CV 3/5; 7/32] START learning_rate=0.01, max_depth=3, min_samples_leaf=2, min_samples_split=5, n_estimators=100
# [CV 3/5; 7/32] END learning_rate=0.01, max_depth=3, min_samples_leaf=2, min_samples_split=5, n_estimators=100;, score=0.838 total time= 1.1min
# [CV 4/5; 7/32] START learning_rate=0.01, max_depth=3, min_samples_leaf=2, min_samples_split=5, n_estimators=100
# [CV 4/5; 7/32] END learning_rate=0.01, max_depth=3, min_samples_leaf=2, min_samples_split=5, n_estimators=100;, score=0.845 total time= 1.2min
# [CV 5/5; 7/32] START learning_rate=0.01, max_depth=3, min_samples_leaf=2, min_samples_split=5, n_estimators=100
# [CV 5/5; 7/32] END learning_rate=0.01, max_depth=3, min_samples_leaf=2, min_samples_split=5, n_estimators=100;, score=0.836 total time= 1.3min
# [CV 1/5; 8/32] START learning_rate=0.01, max_depth=3, min_samples_leaf=2, min_samples_split=5, n_estimators=200
# [CV 1/5; 8/32] END learning_rate=0.01, max_depth=3, min_samples_leaf=2, min_samples_split=5, n_estimators=200;, score=0.852 total time= 2.3min
# [CV 2/5; 8/32] START learning_rate=0.01, max_depth=3, min_samples_leaf=2, min_samples_split=5, n_estimators=200
# [CV 2/5; 8/32] END learning_rate=0.01, max_depth=3, min_samples_leaf=2, min_samples_split=5, n_estimators=200;, score=0.851 total time= 2.2min
# [CV 3/5; 8/32] START learning_rate=0.01, max_depth=3, min_samples_leaf=2, min_samples_split=5, n_estimators=200
# [CV 3/5; 8/32] END learning_rate=0.01, max_depth=3, min_samples_leaf=2, min_samples_split=5, n_estimators=200;, score=0.852 total time= 2.0min
# [CV 4/5; 8/32] START learning_rate=0.01, max_depth=3, min_samples_leaf=2, min_samples_split=5, n_estimators=200
# [CV 4/5; 8/32] END learning_rate=0.01, max_depth=3, min_samples_leaf=2, min_samples_split=5, n_estimators=200;, score=0.854 total time= 2.0min
# [CV 5/5; 8/32] START learning_rate=0.01, max_depth=3, min_samples_leaf=2, min_samples_split=5, n_estimators=200
# [CV 5/5; 8/32] END learning_rate=0.01, max_depth=3, min_samples_leaf=2, min_samples_split=5, n_estimators=200;, score=0.847 total time= 2.2min
# [CV 1/5; 9/32] START learning_rate=0.01, max_depth=5, min_samples_leaf=1, min_samples_split=2, n_estimators=100
# [CV 1/5; 9/32] END learning_rate=0.01, max_depth=5, min_samples_leaf=1, min_samples_split=2, n_estimators=100;, score=0.844 total time= 1.5min
# [CV 2/5; 9/32] START learning_rate=0.01, max_depth=5, min_samples_leaf=1, min_samples_split=2, n_estimators=100
# [CV 2/5; 9/32] END learning_rate=0.01, max_depth=5, min_samples_leaf=1, min_samples_split=2, n_estimators=100;, score=0.845 total time= 1.4min
# [CV 3/5; 9/32] START learning_rate=0.01, max_depth=5, min_samples_leaf=1, min_samples_split=2, n_estimators=100
# [CV 3/5; 9/32] END learning_rate=0.01, max_depth=5, min_samples_leaf=1, min_samples_split=2, n_estimators=100;, score=0.851 total time= 1.4min
# [CV 4/5; 9/32] START learning_rate=0.01, max_depth=5, min_samples_leaf=1, min_samples_split=2, n_estimators=100
# [CV 4/5; 9/32] END learning_rate=0.01, max_depth=5, min_samples_leaf=1, min_samples_split=2, n_estimators=100;, score=0.850 total time= 1.4min
# [CV 5/5; 9/32] START learning_rate=0.01, max_depth=5, min_samples_leaf=1, min_samples_split=2, n_estimators=100
# [CV 5/5; 9/32] END learning_rate=0.01, max_depth=5, min_samples_leaf=1, min_samples_split=2, n_estimators=100;, score=0.845 total time= 1.4min
# [CV 1/5; 10/32] START learning_rate=0.01, max_depth=5, min_samples_leaf=1, min_samples_split=2, n_estimators=200
# [CV 1/5; 10/32] END learning_rate=0.01, max_depth=5, min_samples_leaf=1, min_samples_split=2, n_estimators=200;, score=0.851 total time= 3.0min
# [CV 2/5; 10/32] START learning_rate=0.01, max_depth=5, min_samples_leaf=1, min_samples_split=2, n_estimators=200
# [CV 2/5; 10/32] END learning_rate=0.01, max_depth=5, min_samples_leaf=1, min_samples_split=2, n_estimators=200;, score=0.855 total time= 2.8min
# [CV 3/5; 10/32] START learning_rate=0.01, max_depth=5, min_samples_leaf=1, min_samples_split=2, n_estimators=200
# [CV 3/5; 10/32] END learning_rate=0.01, max_depth=5, min_samples_leaf=1, min_samples_split=2, n_estimators=200;, score=0.857 total time= 2.6min
# [CV 4/5; 10/32] START learning_rate=0.01, max_depth=5, min_samples_leaf=1, min_samples_split=2, n_estimators=200
# [CV 4/5; 10/32] END learning_rate=0.01, max_depth=5, min_samples_leaf=1, min_samples_split=2, n_estimators=200;, score=0.856 total time= 3.1min
# [CV 5/5; 10/32] START learning_rate=0.01, max_depth=5, min_samples_leaf=1, min_samples_split=2, n_estimators=200
# [CV 5/5; 10/32] END learning_rate=0.01, max_depth=5, min_samples_leaf=1, min_samples_split=2, n_estimators=200;, score=0.852 total time= 3.6min
# [CV 1/5; 11/32] START learning_rate=0.01, max_depth=5, min_samples_leaf=1, min_samples_split=5, n_estimators=100
# [CV 1/5; 11/32] END learning_rate=0.01, max_depth=5, min_samples_leaf=1, min_samples_split=5, n_estimators=100;, score=0.843 total time= 1.5min
# [CV 2/5; 11/32] START learning_rate=0.01, max_depth=5, min_samples_leaf=1, min_samples_split=5, n_estimators=100
# [CV 2/5; 11/32] END learning_rate=0.01, max_depth=5, min_samples_leaf=1, min_samples_split=5, n_estimators=100;, score=0.844 total time= 1.5min
# [CV 3/5; 11/32] START learning_rate=0.01, max_depth=5, min_samples_leaf=1, min_samples_split=5, n_estimators=100
# [CV 3/5; 11/32] END learning_rate=0.01, max_depth=5, min_samples_leaf=1, min_samples_split=5, n_estimators=100;, score=0.851 total time= 1.4min
# [CV 4/5; 11/32] START learning_rate=0.01, max_depth=5, min_samples_leaf=1, min_samples_split=5, n_estimators=100
# [CV 4/5; 11/32] END learning_rate=0.01, max_depth=5, min_samples_leaf=1, min_samples_split=5, n_estimators=100;, score=0.850 total time= 1.4min
# [CV 5/5; 11/32] START learning_rate=0.01, max_depth=5, min_samples_leaf=1, min_samples_split=5, n_estimators=100
# [CV 5/5; 11/32] END learning_rate=0.01, max_depth=5, min_samples_leaf=1, min_samples_split=5, n_estimators=100;, score=0.845 total time= 1.4min
# [CV 1/5; 12/32] START learning_rate=0.01, max_depth=5, min_samples_leaf=1, min_samples_split=5, n_estimators=200
# [CV 1/5; 12/32] END learning_rate=0.01, max_depth=5, min_samples_leaf=1, min_samples_split=5, n_estimators=200;, score=0.853 total time= 2.6min
# [CV 2/5; 12/32] START learning_rate=0.01, max_depth=5, min_samples_leaf=1, min_samples_split=5, n_estimators=200
# [CV 2/5; 12/32] END learning_rate=0.01, max_depth=5, min_samples_leaf=1, min_samples_split=5, n_estimators=200;, score=0.855 total time= 2.8min
# [CV 3/5; 12/32] START learning_rate=0.01, max_depth=5, min_samples_leaf=1, min_samples_split=5, n_estimators=200
# [CV 3/5; 12/32] END learning_rate=0.01, max_depth=5, min_samples_leaf=1, min_samples_split=5, n_estimators=200;, score=0.859 total time= 2.8min
# [CV 4/5; 12/32] START learning_rate=0.01, max_depth=5, min_samples_leaf=1, min_samples_split=5, n_estimators=200
# [CV 4/5; 12/32] END learning_rate=0.01, max_depth=5, min_samples_leaf=1, min_samples_split=5, n_estimators=200;, score=0.856 total time= 2.8min
# [CV 5/5; 12/32] START learning_rate=0.01, max_depth=5, min_samples_leaf=1, min_samples_split=5, n_estimators=200
# [CV 5/5; 12/32] END learning_rate=0.01, max_depth=5, min_samples_leaf=1, min_samples_split=5, n_estimators=200;, score=0.851 total time= 2.8min
# [CV 1/5; 13/32] START learning_rate=0.01, max_depth=5, min_samples_leaf=2, min_samples_split=2, n_estimators=100
# [CV 1/5; 13/32] END learning_rate=0.01, max_depth=5, min_samples_leaf=2, min_samples_split=2, n_estimators=100;, score=0.844 total time= 1.4min
# [CV 2/5; 13/32] START learning_rate=0.01, max_depth=5, min_samples_leaf=2, min_samples_split=2, n_estimators=100
# [CV 2/5; 13/32] END learning_rate=0.01, max_depth=5, min_samples_leaf=2, min_samples_split=2, n_estimators=100;, score=0.844 total time= 1.2min
# [CV 3/5; 13/32] START learning_rate=0.01, max_depth=5, min_samples_leaf=2, min_samples_split=2, n_estimators=100
# [CV 3/5; 13/32] END learning_rate=0.01, max_depth=5, min_samples_leaf=2, min_samples_split=2, n_estimators=100;, score=0.852 total time= 1.4min
# [CV 4/5; 13/32] START learning_rate=0.01, max_depth=5, min_samples_leaf=2, min_samples_split=2, n_estimators=100
# [CV 4/5; 13/32] END learning_rate=0.01, max_depth=5, min_samples_leaf=2, min_samples_split=2, n_estimators=100;, score=0.851 total time= 1.4min
# [CV 5/5; 13/32] START learning_rate=0.01, max_depth=5, min_samples_leaf=2, min_samples_split=2, n_estimators=100
# [CV 5/5; 13/32] END learning_rate=0.01, max_depth=5, min_samples_leaf=2, min_samples_split=2, n_estimators=100;, score=0.845 total time= 1.4min
# [CV 1/5; 14/32] START learning_rate=0.01, max_depth=5, min_samples_leaf=2, min_samples_split=2, n_estimators=200
# [CV 1/5; 14/32] END learning_rate=0.01, max_depth=5, min_samples_leaf=2, min_samples_split=2, n_estimators=200;, score=0.854 total time= 2.8min
# [CV 2/5; 14/32] START learning_rate=0.01, max_depth=5, min_samples_leaf=2, min_samples_split=2, n_estimators=200
# [CV 2/5; 14/32] END learning_rate=0.01, max_depth=5, min_samples_leaf=2, min_samples_split=2, n_estimators=200;, score=0.854 total time= 2.8min
# [CV 3/5; 14/32] START learning_rate=0.01, max_depth=5, min_samples_leaf=2, min_samples_split=2, n_estimators=200
# [CV 3/5; 14/32] END learning_rate=0.01, max_depth=5, min_samples_leaf=2, min_samples_split=2, n_estimators=200;, score=0.859 total time= 2.8min
# [CV 4/5; 14/32] START learning_rate=0.01, max_depth=5, min_samples_leaf=2, min_samples_split=2, n_estimators=200
# [CV 4/5; 14/32] END learning_rate=0.01, max_depth=5, min_samples_leaf=2, min_samples_split=2, n_estimators=200;, score=0.856 total time= 2.7min
# [CV 5/5; 14/32] START learning_rate=0.01, max_depth=5, min_samples_leaf=2, min_samples_split=2, n_estimators=200
# [CV 5/5; 14/32] END learning_rate=0.01, max_depth=5, min_samples_leaf=2, min_samples_split=2, n_estimators=200;, score=0.850 total time= 2.9min
# [CV 1/5; 15/32] START learning_rate=0.01, max_depth=5, min_samples_leaf=2, min_samples_split=5, n_estimators=100
# [CV 1/5; 15/32] END learning_rate=0.01, max_depth=5, min_samples_leaf=2, min_samples_split=5, n_estimators=100;, score=0.844 total time= 1.4min
# [CV 2/5; 15/32] START learning_rate=0.01, max_depth=5, min_samples_leaf=2, min_samples_split=5, n_estimators=100
# [CV 2/5; 15/32] END learning_rate=0.01, max_depth=5, min_samples_leaf=2, min_samples_split=5, n_estimators=100;, score=0.844 total time= 1.4min
# [CV 3/5; 15/32] START learning_rate=0.01, max_depth=5, min_samples_leaf=2, min_samples_split=5, n_estimators=100
# [CV 3/5; 15/32] END learning_rate=0.01, max_depth=5, min_samples_leaf=2, min_samples_split=5, n_estimators=100;, score=0.852 total time= 1.4min
# [CV 4/5; 15/32] START learning_rate=0.01, max_depth=5, min_samples_leaf=2, min_samples_split=5, n_estimators=100
# [CV 4/5; 15/32] END learning_rate=0.01, max_depth=5, min_samples_leaf=2, min_samples_split=5, n_estimators=100;, score=0.851 total time= 1.4min
# [CV 5/5; 15/32] START learning_rate=0.01, max_depth=5, min_samples_leaf=2, min_samples_split=5, n_estimators=100
# [CV 5/5; 15/32] END learning_rate=0.01, max_depth=5, min_samples_leaf=2, min_samples_split=5, n_estimators=100;, score=0.845 total time= 1.4min
# [CV 1/5; 16/32] START learning_rate=0.01, max_depth=5, min_samples_leaf=2, min_samples_split=5, n_estimators=200
# [CV 1/5; 16/32] END learning_rate=0.01, max_depth=5, min_samples_leaf=2, min_samples_split=5, n_estimators=200;, score=0.856 total time= 2.8min
# [CV 2/5; 16/32] START learning_rate=0.01, max_depth=5, min_samples_leaf=2, min_samples_split=5, n_estimators=200
# [CV 2/5; 16/32] END learning_rate=0.01, max_depth=5, min_samples_leaf=2, min_samples_split=5, n_estimators=200;, score=0.854 total time= 2.6min
# [CV 3/5; 16/32] START learning_rate=0.01, max_depth=5, min_samples_leaf=2, min_samples_split=5, n_estimators=200
# [CV 3/5; 16/32] END learning_rate=0.01, max_depth=5, min_samples_leaf=2, min_samples_split=5, n_estimators=200;, score=0.861 total time= 2.8min
# [CV 4/5; 16/32] START learning_rate=0.01, max_depth=5, min_samples_leaf=2, min_samples_split=5, n_estimators=200
# [CV 4/5; 16/32] END learning_rate=0.01, max_depth=5, min_samples_leaf=2, min_samples_split=5, n_estimators=200;, score=0.856 total time= 2.8min
# [CV 5/5; 16/32] START learning_rate=0.01, max_depth=5, min_samples_leaf=2, min_samples_split=5, n_estimators=200
# [CV 5/5; 16/32] END learning_rate=0.01, max_depth=5, min_samples_leaf=2, min_samples_split=5, n_estimators=200;, score=0.850 total time= 2.8min
# [CV 1/5; 17/32] START learning_rate=0.1, max_depth=3, min_samples_leaf=1, min_samples_split=2, n_estimators=100
# [CV 1/5; 17/32] END learning_rate=0.1, max_depth=3, min_samples_leaf=1, min_samples_split=2, n_estimators=100;, score=0.853 total time= 6.2min
# [CV 2/5; 17/32] START learning_rate=0.1, max_depth=3, min_samples_leaf=1, min_samples_split=2, n_estimators=100
# [CV 2/5; 17/32] END learning_rate=0.1, max_depth=3, min_samples_leaf=1, min_samples_split=2, n_estimators=100;, score=0.859 total time=  53.5s
# [CV 3/5; 17/32] START learning_rate=0.1, max_depth=3, min_samples_leaf=1, min_samples_split=2, n_estimators=100
# [CV 3/5; 17/32] END learning_rate=0.1, max_depth=3, min_samples_leaf=1, min_samples_split=2, n_estimators=100;, score=0.856 total time=  51.0s
# [CV 4/5; 17/32] START learning_rate=0.1, max_depth=3, min_samples_leaf=1, min_samples_split=2, n_estimators=100
# [CV 4/5; 17/32] END learning_rate=0.1, max_depth=3, min_samples_leaf=1, min_samples_split=2, n_estimators=100;, score=0.858 total time=  50.7s
# [CV 5/5; 17/32] START learning_rate=0.1, max_depth=3, min_samples_leaf=1, min_samples_split=2, n_estimators=100
# [CV 5/5; 17/32] END learning_rate=0.1, max_depth=3, min_samples_leaf=1, min_samples_split=2, n_estimators=100;, score=0.851 total time=  59.3s
# [CV 1/5; 18/32] START learning_rate=0.1, max_depth=3, min_samples_leaf=1, min_samples_split=2, n_estimators=200
# [CV 1/5; 18/32] END learning_rate=0.1, max_depth=3, min_samples_leaf=1, min_samples_split=2, n_estimators=200;, score=0.852 total time= 1.6min
# [CV 2/5; 18/32] START learning_rate=0.1, max_depth=3, min_samples_leaf=1, min_samples_split=2, n_estimators=200
# [CV 2/5; 18/32] END learning_rate=0.1, max_depth=3, min_samples_leaf=1, min_samples_split=2, n_estimators=200;, score=0.856 total time= 2.1min
# [CV 3/5; 18/32] START learning_rate=0.1, max_depth=3, min_samples_leaf=1, min_samples_split=2, n_estimators=200
# [CV 3/5; 18/32] END learning_rate=0.1, max_depth=3, min_samples_leaf=1, min_samples_split=2, n_estimators=200;, score=0.855 total time= 2.1min
# [CV 4/5; 18/32] START learning_rate=0.1, max_depth=3, min_samples_leaf=1, min_samples_split=2, n_estimators=200
# [CV 4/5; 18/32] END learning_rate=0.1, max_depth=3, min_samples_leaf=1, min_samples_split=2, n_estimators=200;, score=0.856 total time= 1.7min
# [CV 5/5; 18/32] START learning_rate=0.1, max_depth=3, min_samples_leaf=1, min_samples_split=2, n_estimators=200
# [CV 5/5; 18/32] END learning_rate=0.1, max_depth=3, min_samples_leaf=1, min_samples_split=2, n_estimators=200;, score=0.851 total time= 1.7min
# [CV 1/5; 19/32] START learning_rate=0.1, max_depth=3, min_samples_leaf=1, min_samples_split=5, n_estimators=100
# [CV 1/5; 19/32] END learning_rate=0.1, max_depth=3, min_samples_leaf=1, min_samples_split=5, n_estimators=100;, score=0.851 total time=  50.9s
# [CV 2/5; 19/32] START learning_rate=0.1, max_depth=3, min_samples_leaf=1, min_samples_split=5, n_estimators=100
# [CV 2/5; 19/32] END learning_rate=0.1, max_depth=3, min_samples_leaf=1, min_samples_split=5, n_estimators=100;, score=0.859 total time=  50.6s
# [CV 3/5; 19/32] START learning_rate=0.1, max_depth=3, min_samples_leaf=1, min_samples_split=5, n_estimators=100
# [CV 3/5; 19/32] END learning_rate=0.1, max_depth=3, min_samples_leaf=1, min_samples_split=5, n_estimators=100;, score=0.852 total time=  51.7s
# [CV 4/5; 19/32] START learning_rate=0.1, max_depth=3, min_samples_leaf=1, min_samples_split=5, n_estimators=100
# [CV 4/5; 19/32] END learning_rate=0.1, max_depth=3, min_samples_leaf=1, min_samples_split=5, n_estimators=100;, score=0.857 total time=  50.5s
# [CV 5/5; 19/32] START learning_rate=0.1, max_depth=3, min_samples_leaf=1, min_samples_split=5, n_estimators=100
# [CV 5/5; 19/32] END learning_rate=0.1, max_depth=3, min_samples_leaf=1, min_samples_split=5, n_estimators=100;, score=0.852 total time=  51.5s
# [CV 1/5; 20/32] START learning_rate=0.1, max_depth=3, min_samples_leaf=1, min_samples_split=5, n_estimators=200
# [CV 1/5; 20/32] END learning_rate=0.1, max_depth=3, min_samples_leaf=1, min_samples_split=5, n_estimators=200;, score=0.854 total time= 1.7min
# [CV 2/5; 20/32] START learning_rate=0.1, max_depth=3, min_samples_leaf=1, min_samples_split=5, n_estimators=200
# [CV 2/5; 20/32] END learning_rate=0.1, max_depth=3, min_samples_leaf=1, min_samples_split=5, n_estimators=200;, score=0.859 total time= 1.6min
# [CV 3/5; 20/32] START learning_rate=0.1, max_depth=3, min_samples_leaf=1, min_samples_split=5, n_estimators=200
# [CV 3/5; 20/32] END learning_rate=0.1, max_depth=3, min_samples_leaf=1, min_samples_split=5, n_estimators=200;, score=0.853 total time= 1.7min
# [CV 4/5; 20/32] START learning_rate=0.1, max_depth=3, min_samples_leaf=1, min_samples_split=5, n_estimators=200
# [CV 4/5; 20/32] END learning_rate=0.1, max_depth=3, min_samples_leaf=1, min_samples_split=5, n_estimators=200;, score=0.858 total time= 1.7min
# [CV 5/5; 20/32] START learning_rate=0.1, max_depth=3, min_samples_leaf=1, min_samples_split=5, n_estimators=200
# [CV 5/5; 20/32] END learning_rate=0.1, max_depth=3, min_samples_leaf=1, min_samples_split=5, n_estimators=200;, score=0.849 total time= 1.8min
# [CV 1/5; 21/32] START learning_rate=0.1, max_depth=3, min_samples_leaf=2, min_samples_split=2, n_estimators=100
# [CV 1/5; 21/32] END learning_rate=0.1, max_depth=3, min_samples_leaf=2, min_samples_split=2, n_estimators=100;, score=0.855 total time=  50.3s
# [CV 2/5; 21/32] START learning_rate=0.1, max_depth=3, min_samples_leaf=2, min_samples_split=2, n_estimators=100
# [CV 2/5; 21/32] END learning_rate=0.1, max_depth=3, min_samples_leaf=2, min_samples_split=2, n_estimators=100;, score=0.858 total time=  50.4s
# [CV 3/5; 21/32] START learning_rate=0.1, max_depth=3, min_samples_leaf=2, min_samples_split=2, n_estimators=100
# [CV 3/5; 21/32] END learning_rate=0.1, max_depth=3, min_samples_leaf=2, min_samples_split=2, n_estimators=100;, score=0.861 total time=  50.3s
# [CV 4/5; 21/32] START learning_rate=0.1, max_depth=3, min_samples_leaf=2, min_samples_split=2, n_estimators=100
# [CV 4/5; 21/32] END learning_rate=0.1, max_depth=3, min_samples_leaf=2, min_samples_split=2, n_estimators=100;, score=0.861 total time=  50.6s
# [CV 5/5; 21/32] START learning_rate=0.1, max_depth=3, min_samples_leaf=2, min_samples_split=2, n_estimators=100
# [CV 5/5; 21/32] END learning_rate=0.1, max_depth=3, min_samples_leaf=2, min_samples_split=2, n_estimators=100;, score=0.849 total time=  51.0s
# [CV 1/5; 22/32] START learning_rate=0.1, max_depth=3, min_samples_leaf=2, min_samples_split=2, n_estimators=200
# [CV 1/5; 22/32] END learning_rate=0.1, max_depth=3, min_samples_leaf=2, min_samples_split=2, n_estimators=200;, score=0.850 total time= 1.7min
# [CV 2/5; 22/32] START learning_rate=0.1, max_depth=3, min_samples_leaf=2, min_samples_split=2, n_estimators=200
# [CV 2/5; 22/32] END learning_rate=0.1, max_depth=3, min_samples_leaf=2, min_samples_split=2, n_estimators=200;, score=0.857 total time= 1.7min
# [CV 3/5; 22/32] START learning_rate=0.1, max_depth=3, min_samples_leaf=2, min_samples_split=2, n_estimators=200
# [CV 3/5; 22/32] END learning_rate=0.1, max_depth=3, min_samples_leaf=2, min_samples_split=2, n_estimators=200;, score=0.859 total time= 1.6min
# [CV 4/5; 22/32] START learning_rate=0.1, max_depth=3, min_samples_leaf=2, min_samples_split=2, n_estimators=200
# [CV 4/5; 22/32] END learning_rate=0.1, max_depth=3, min_samples_leaf=2, min_samples_split=2, n_estimators=200;, score=0.859 total time= 1.8min
# [CV 5/5; 22/32] START learning_rate=0.1, max_depth=3, min_samples_leaf=2, min_samples_split=2, n_estimators=200
# [CV 5/5; 22/32] END learning_rate=0.1, max_depth=3, min_samples_leaf=2, min_samples_split=2, n_estimators=200;, score=0.850 total time= 1.7min
# [CV 1/5; 23/32] START learning_rate=0.1, max_depth=3, min_samples_leaf=2, min_samples_split=5, n_estimators=100
# [CV 1/5; 23/32] END learning_rate=0.1, max_depth=3, min_samples_leaf=2, min_samples_split=5, n_estimators=100;, score=0.856 total time=  51.2s
# [CV 2/5; 23/32] START learning_rate=0.1, max_depth=3, min_samples_leaf=2, min_samples_split=5, n_estimators=100
# [CV 2/5; 23/32] END learning_rate=0.1, max_depth=3, min_samples_leaf=2, min_samples_split=5, n_estimators=100;, score=0.859 total time=  49.8s
# [CV 3/5; 23/32] START learning_rate=0.1, max_depth=3, min_samples_leaf=2, min_samples_split=5, n_estimators=100
# [CV 3/5; 23/32] END learning_rate=0.1, max_depth=3, min_samples_leaf=2, min_samples_split=5, n_estimators=100;, score=0.861 total time=  50.1s
# [CV 4/5; 23/32] START learning_rate=0.1, max_depth=3, min_samples_leaf=2, min_samples_split=5, n_estimators=100
# [CV 4/5; 23/32] END learning_rate=0.1, max_depth=3, min_samples_leaf=2, min_samples_split=5, n_estimators=100;, score=0.861 total time=  51.1s
# [CV 5/5; 23/32] START learning_rate=0.1, max_depth=3, min_samples_leaf=2, min_samples_split=5, n_estimators=100
# [CV 5/5; 23/32] END learning_rate=0.1, max_depth=3, min_samples_leaf=2, min_samples_split=5, n_estimators=100;, score=0.849 total time=  51.6s
# [CV 1/5; 24/32] START learning_rate=0.1, max_depth=3, min_samples_leaf=2, min_samples_split=5, n_estimators=200
# [CV 1/5; 24/32] END learning_rate=0.1, max_depth=3, min_samples_leaf=2, min_samples_split=5, n_estimators=200;, score=0.854 total time= 1.7min
# [CV 2/5; 24/32] START learning_rate=0.1, max_depth=3, min_samples_leaf=2, min_samples_split=5, n_estimators=200
# [CV 2/5; 24/32] END learning_rate=0.1, max_depth=3, min_samples_leaf=2, min_samples_split=5, n_estimators=200;, score=0.856 total time= 1.7min
# [CV 3/5; 24/32] START learning_rate=0.1, max_depth=3, min_samples_leaf=2, min_samples_split=5, n_estimators=200
# [CV 3/5; 24/32] END learning_rate=0.1, max_depth=3, min_samples_leaf=2, min_samples_split=5, n_estimators=200;, score=0.857 total time= 1.7min
# [CV 4/5; 24/32] START learning_rate=0.1, max_depth=3, min_samples_leaf=2, min_samples_split=5, n_estimators=200
# [CV 4/5; 24/32] END learning_rate=0.1, max_depth=3, min_samples_leaf=2, min_samples_split=5, n_estimators=200;, score=0.859 total time= 1.7min
# [CV 5/5; 24/32] START learning_rate=0.1, max_depth=3, min_samples_leaf=2, min_samples_split=5, n_estimators=200
# [CV 5/5; 24/32] END learning_rate=0.1, max_depth=3, min_samples_leaf=2, min_samples_split=5, n_estimators=200;, score=0.851 total time= 1.8min
# [CV 1/5; 25/32] START learning_rate=0.1, max_depth=5, min_samples_leaf=1, min_samples_split=2, n_estimators=100
# [CV 1/5; 25/32] END learning_rate=0.1, max_depth=5, min_samples_leaf=1, min_samples_split=2, n_estimators=100;, score=0.854 total time= 1.3min
# [CV 2/5; 25/32] START learning_rate=0.1, max_depth=5, min_samples_leaf=1, min_samples_split=2, n_estimators=100
# [CV 2/5; 25/32] END learning_rate=0.1, max_depth=5, min_samples_leaf=1, min_samples_split=2, n_estimators=100;, score=0.862 total time= 1.3min
# [CV 3/5; 25/32] START learning_rate=0.1, max_depth=5, min_samples_leaf=1, min_samples_split=2, n_estimators=100
# [CV 3/5; 25/32] END learning_rate=0.1, max_depth=5, min_samples_leaf=1, min_samples_split=2, n_estimators=100;, score=0.859 total time= 1.3min
# [CV 4/5; 25/32] START learning_rate=0.1, max_depth=5, min_samples_leaf=1, min_samples_split=2, n_estimators=100
# [CV 4/5; 25/32] END learning_rate=0.1, max_depth=5, min_samples_leaf=1, min_samples_split=2, n_estimators=100;, score=0.856 total time= 1.4min
# [CV 5/5; 25/32] START learning_rate=0.1, max_depth=5, min_samples_leaf=1, min_samples_split=2, n_estimators=100
# [CV 5/5; 25/32] END learning_rate=0.1, max_depth=5, min_samples_leaf=1, min_samples_split=2, n_estimators=100;, score=0.849 total time= 1.5min
# [CV 1/5; 26/32] START learning_rate=0.1, max_depth=5, min_samples_leaf=1, min_samples_split=2, n_estimators=200
# [CV 1/5; 26/32] END learning_rate=0.1, max_depth=5, min_samples_leaf=1, min_samples_split=2, n_estimators=200;, score=0.850 total time= 2.9min
# [CV 2/5; 26/32] START learning_rate=0.1, max_depth=5, min_samples_leaf=1, min_samples_split=2, n_estimators=200
# [CV 2/5; 26/32] END learning_rate=0.1, max_depth=5, min_samples_leaf=1, min_samples_split=2, n_estimators=200;, score=0.858 total time= 2.7min
# [CV 3/5; 26/32] START learning_rate=0.1, max_depth=5, min_samples_leaf=1, min_samples_split=2, n_estimators=200
# [CV 3/5; 26/32] END learning_rate=0.1, max_depth=5, min_samples_leaf=1, min_samples_split=2, n_estimators=200;, score=0.861 total time= 2.5min
# [CV 4/5; 26/32] START learning_rate=0.1, max_depth=5, min_samples_leaf=1, min_samples_split=2, n_estimators=200
# [CV 4/5; 26/32] END learning_rate=0.1, max_depth=5, min_samples_leaf=1, min_samples_split=2, n_estimators=200;, score=0.855 total time= 2.7min
# [CV 5/5; 26/32] START learning_rate=0.1, max_depth=5, min_samples_leaf=1, min_samples_split=2, n_estimators=200
# [CV 5/5; 26/32] END learning_rate=0.1, max_depth=5, min_samples_leaf=1, min_samples_split=2, n_estimators=200;, score=0.849 total time= 2.7min
# [CV 1/5; 27/32] START learning_rate=0.1, max_depth=5, min_samples_leaf=1, min_samples_split=5, n_estimators=100
# [CV 1/5; 27/32] END learning_rate=0.1, max_depth=5, min_samples_leaf=1, min_samples_split=5, n_estimators=100;, score=0.854 total time= 1.3min
# [CV 2/5; 27/32] START learning_rate=0.1, max_depth=5, min_samples_leaf=1, min_samples_split=5, n_estimators=100
# [CV 2/5; 27/32] END learning_rate=0.1, max_depth=5, min_samples_leaf=1, min_samples_split=5, n_estimators=100;, score=0.861 total time= 1.3min
# [CV 3/5; 27/32] START learning_rate=0.1, max_depth=5, min_samples_leaf=1, min_samples_split=5, n_estimators=100
# [CV 3/5; 27/32] END learning_rate=0.1, max_depth=5, min_samples_leaf=1, min_samples_split=5, n_estimators=100;, score=0.859 total time= 1.3min
# [CV 4/5; 27/32] START learning_rate=0.1, max_depth=5, min_samples_leaf=1, min_samples_split=5, n_estimators=100
# [CV 4/5; 27/32] END learning_rate=0.1, max_depth=5, min_samples_leaf=1, min_samples_split=5, n_estimators=100;, score=0.859 total time= 1.3min
# [CV 5/5; 27/32] START learning_rate=0.1, max_depth=5, min_samples_leaf=1, min_samples_split=5, n_estimators=100
# [CV 5/5; 27/32] END learning_rate=0.1, max_depth=5, min_samples_leaf=1, min_samples_split=5, n_estimators=100;, score=0.849 total time= 1.3min
# [CV 1/5; 28/32] START learning_rate=0.1, max_depth=5, min_samples_leaf=1, min_samples_split=5, n_estimators=200
# [CV 1/5; 28/32] END learning_rate=0.1, max_depth=5, min_samples_leaf=1, min_samples_split=5, n_estimators=200;, score=0.851 total time= 2.6min
# [CV 2/5; 28/32] START learning_rate=0.1, max_depth=5, min_samples_leaf=1, min_samples_split=5, n_estimators=200
# [CV 2/5; 28/32] END learning_rate=0.1, max_depth=5, min_samples_leaf=1, min_samples_split=5, n_estimators=200;, score=0.859 total time= 2.7min
# [CV 3/5; 28/32] START learning_rate=0.1, max_depth=5, min_samples_leaf=1, min_samples_split=5, n_estimators=200
# [CV 3/5; 28/32] END learning_rate=0.1, max_depth=5, min_samples_leaf=1, min_samples_split=5, n_estimators=200;, score=0.857 total time= 2.7min
# [CV 4/5; 28/32] START learning_rate=0.1, max_depth=5, min_samples_leaf=1, min_samples_split=5, n_estimators=200
# [CV 4/5; 28/32] END learning_rate=0.1, max_depth=5, min_samples_leaf=1, min_samples_split=5, n_estimators=200;, score=0.856 total time= 2.7min
# [CV 5/5; 28/32] START learning_rate=0.1, max_depth=5, min_samples_leaf=1, min_samples_split=5, n_estimators=200
# [CV 5/5; 28/32] END learning_rate=0.1, max_depth=5, min_samples_leaf=1, min_samples_split=5, n_estimators=200;, score=0.851 total time= 2.7min
# [CV 1/5; 29/32] START learning_rate=0.1, max_depth=5, min_samples_leaf=2, min_samples_split=2, n_estimators=100
# [CV 1/5; 29/32] END learning_rate=0.1, max_depth=5, min_samples_leaf=2, min_samples_split=2, n_estimators=100;, score=0.854 total time= 1.3min
# [CV 2/5; 29/32] START learning_rate=0.1, max_depth=5, min_samples_leaf=2, min_samples_split=2, n_estimators=100
# [CV 2/5; 29/32] END learning_rate=0.1, max_depth=5, min_samples_leaf=2, min_samples_split=2, n_estimators=100;, score=0.862 total time= 1.2min
# [CV 3/5; 29/32] START learning_rate=0.1, max_depth=5, min_samples_leaf=2, min_samples_split=2, n_estimators=100
# [CV 3/5; 29/32] END learning_rate=0.1, max_depth=5, min_samples_leaf=2, min_samples_split=2, n_estimators=100;, score=0.868 total time= 1.2min
# [CV 4/5; 29/32] START learning_rate=0.1, max_depth=5, min_samples_leaf=2, min_samples_split=2, n_estimators=100
# [CV 4/5; 29/32] END learning_rate=0.1, max_depth=5, min_samples_leaf=2, min_samples_split=2, n_estimators=100;, score=0.858 total time= 1.3min
# [CV 5/5; 29/32] START learning_rate=0.1, max_depth=5, min_samples_leaf=2, min_samples_split=2, n_estimators=100
# [CV 5/5; 29/32] END learning_rate=0.1, max_depth=5, min_samples_leaf=2, min_samples_split=2, n_estimators=100;, score=0.849 total time= 1.3min
# [CV 1/5; 30/32] START learning_rate=0.1, max_depth=5, min_samples_leaf=2, min_samples_split=2, n_estimators=200
# [CV 1/5; 30/32] END learning_rate=0.1, max_depth=5, min_samples_leaf=2, min_samples_split=2, n_estimators=200;, score=0.854 total time= 2.7min
# [CV 2/5; 30/32] START learning_rate=0.1, max_depth=5, min_samples_leaf=2, min_samples_split=2, n_estimators=200
# [CV 2/5; 30/32] END learning_rate=0.1, max_depth=5, min_samples_leaf=2, min_samples_split=2, n_estimators=200;, score=0.861 total time= 2.6min
# [CV 3/5; 30/32] START learning_rate=0.1, max_depth=5, min_samples_leaf=2, min_samples_split=2, n_estimators=200
# [CV 3/5; 30/32] END learning_rate=0.1, max_depth=5, min_samples_leaf=2, min_samples_split=2, n_estimators=200;, score=0.870 total time= 2.6min
# [CV 4/5; 30/32] START learning_rate=0.1, max_depth=5, min_samples_leaf=2, min_samples_split=2, n_estimators=200
# [CV 4/5; 30/32] END learning_rate=0.1, max_depth=5, min_samples_leaf=2, min_samples_split=2, n_estimators=200;, score=0.858 total time= 2.7min
# [CV 5/5; 30/32] START learning_rate=0.1, max_depth=5, min_samples_leaf=2, min_samples_split=2, n_estimators=200
# [CV 5/5; 30/32] END learning_rate=0.1, max_depth=5, min_samples_leaf=2, min_samples_split=2, n_estimators=200;, score=0.852 total time= 2.8min
# [CV 1/5; 31/32] START learning_rate=0.1, max_depth=5, min_samples_leaf=2, min_samples_split=5, n_estimators=100
# [CV 1/5; 31/32] END learning_rate=0.1, max_depth=5, min_samples_leaf=2, min_samples_split=5, n_estimators=100;, score=0.855 total time= 1.3min
# [CV 2/5; 31/32] START learning_rate=0.1, max_depth=5, min_samples_leaf=2, min_samples_split=5, n_estimators=100
# [CV 2/5; 31/32] END learning_rate=0.1, max_depth=5, min_samples_leaf=2, min_samples_split=5, n_estimators=100;, score=0.862 total time= 1.3min
# [CV 3/5; 31/32] START learning_rate=0.1, max_depth=5, min_samples_leaf=2, min_samples_split=5, n_estimators=100
# [CV 3/5; 31/32] END learning_rate=0.1, max_depth=5, min_samples_leaf=2, min_samples_split=5, n_estimators=100;, score=0.865 total time= 1.3min
# [CV 4/5; 31/32] START learning_rate=0.1, max_depth=5, min_samples_leaf=2, min_samples_split=5, n_estimators=100
# [CV 4/5; 31/32] END learning_rate=0.1, max_depth=5, min_samples_leaf=2, min_samples_split=5, n_estimators=100;, score=0.860 total time= 1.3min
# [CV 5/5; 31/32] START learning_rate=0.1, max_depth=5, min_samples_leaf=2, min_samples_split=5, n_estimators=100
# [CV 5/5; 31/32] END learning_rate=0.1, max_depth=5, min_samples_leaf=2, min_samples_split=5, n_estimators=100;, score=0.847 total time= 1.5min
# [CV 1/5; 32/32] START learning_rate=0.1, max_depth=5, min_samples_leaf=2, min_samples_split=5, n_estimators=200
# [CV 1/5; 32/32] END learning_rate=0.1, max_depth=5, min_samples_leaf=2, min_samples_split=5, n_estimators=200;, score=0.856 total time= 2.9min
# [CV 2/5; 32/32] START learning_rate=0.1, max_depth=5, min_samples_leaf=2, min_samples_split=5, n_estimators=200
# [CV 2/5; 32/32] END learning_rate=0.1, max_depth=5, min_samples_leaf=2, min_samples_split=5, n_estimators=200;, score=0.861 total time= 2.7min
# [CV 3/5; 32/32] START learning_rate=0.1, max_depth=5, min_samples_leaf=2, min_samples_split=5, n_estimators=200
# [CV 3/5; 32/32] END learning_rate=0.1, max_depth=5, min_samples_leaf=2, min_samples_split=5, n_estimators=200;, score=0.862 total time= 2.6min
# [CV 4/5; 32/32] START learning_rate=0.1, max_depth=5, min_samples_leaf=2, min_samples_split=5, n_estimators=200
# [CV 4/5; 32/32] END learning_rate=0.1, max_depth=5, min_samples_leaf=2, min_samples_split=5, n_estimators=200;, score=0.859 total time= 2.9min
# [CV 5/5; 32/32] START learning_rate=0.1, max_depth=5, min_samples_leaf=2, min_samples_split=5, n_estimators=200
# [CV 5/5; 32/32] END learning_rate=0.1, max_depth=5, min_samples_leaf=2, min_samples_split=5, n_estimators=200;, score=0.851 total time= 2.7min
# GridSearchCV(cv=5, estimator=GradientBoostingClassifier(random_state=0),
#              param_grid={'learning_rate': [0.01, 0.1], 'max_depth': [3, 5],
#                          'min_samples_leaf': [1, 2],
#                          'min_samples_split': [2, 5],
#                          'n_estimators': [100, 200]},
#              verbose=10)

# %%
best_params= model1.best_params_
best_params
# Out:
# {'learning_rate': 0.1,
#  'max_depth': 5,
#  'min_samples_leaf': 2,
#  'min_samples_split': 2,
#  'n_estimators': 200}

# %%
#final_gb = GradientBoostingClassifier(max_depth= 3, max_leaf_nodes = 100, random_state=0)
#final_gb.fit(X_train_scaled, y_train)
# Out:
# GradientBoostingClassifier(max_leaf_nodes=100, random_state=0)

# %%
final_gb_grid = GradientBoostingClassifier(learning_rate = 0.1, max_depth = 5, min_samples_leaf = 2, min_samples_split = 2, n_estimators = 200, random_state=0)
final_gb_grid.fit(X_train_scaled, y_train)
# Out:
# GradientBoostingClassifier(max_depth=5, min_samples_leaf=2, n_estimators=200,
#                            random_state=0)

# %%
#best_model = model.best_score_

# %%
y_pred_final_gb_grid = final_gb_grid.predict(X_test_scaled)

accuracy_final_grid = accuracy_score(y_test, y_pred_final_gb_grid)*100
classification_report_final_grid = classification_report(y_test, y_pred_final_gb_grid)

print(f"Gradient Boosting Tuning Classifier Accuracy: {accuracy_final_grid}%")
print(f"Gradient Boosting Tuning Classification Report:\n{classification_report_final_grid}")
# Out:
# Gradient Boosting Tuning Classifier Accuracy: 87.06666666666666%
# Gradient Boosting Tuning Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.89      0.96      0.92      2416
#            1       0.76      0.49      0.59       584
#
#     accuracy                           0.87      3000
#    macro avg       0.82      0.73      0.76      3000
# weighted avg       0.86      0.87      0.86      3000

# %%
cv_scores = cross_val_score(final_gb, X_train_scaled, y_train, cv=5, scoring="accuracy")
print("Cross-Validation Accuracy Scores:", cv_scores)
print("Mean Cross-Validation Accuracy:", cv_scores.mean())
# Out:
# Cross-Validation Accuracy Scores: [0.85571429 0.86214286 0.86571429 0.85928571 0.84857143]
# Mean Cross-Validation Accuracy: 0.8582857142857143

# %%
feature_importances = final_gb_grid.feature_importances_
indices = np.argsort(feature_importances)[::-1]

plt.figure(figsize=(10, 6))
plt.title("Feature Importances")
plt.bar(range(X_train.shape[1]), feature_importances[indices], align="center")
plt.xticks(range(X_train.shape[1]), X_train.columns[indices], rotation=90)
plt.tight_layout()
plt.show()

# %%
# Confusion Matrix
cm = confusion_matrix(y_test, y_pred_final_gb)
print("Confusion Matrix:\n", cm)
# Out:
# Confusion Matrix:
#  [[2340   76]
#  [ 308  276]]

# %% [markdown]
# ### Imbalanced

# %%
df_churn["Exited"].value_counts()
# Out:
# Exited
# 0    7963
# 1    2037
# Name: count, dtype: int64

# %% [markdown]
# ### Oversampling

# %%
train = pd.DataFrame(X_train_scaled, columns = X_train.columns)

# %%
train["Exited"] = y_train.values

# %%
churned = train[train["Exited"] == 1]
no_churned = train[train["Exited"] == 0]

# %%
len(churned),len(no_churned)
# Out:
# (1453, 5547)

# %%
yes_oversampled = resample(churned,
                                    replace=True,
                                    n_samples = len(no_churned),
                                    random_state=0)

# %%
train_over = pd.concat([yes_oversampled, no_churned])
train_over
# Out:
#       RowNumber  CustomerId  CreditScore       Age    Tenure   Balance  \
# 3261  -0.606508   -0.882537     0.860905  0.390286  1.391718  0.358460
# 2550  -0.846049    1.350329    -1.196759  0.771027  0.351385  0.428136
# 5819   1.153822   -0.183575    -0.988914  1.722878 -1.382503  0.698144
# 4026  -1.243666    0.095013     0.466000  1.627692  0.004607  0.550324
# 3680  -0.010603   -0.912216    -1.560488  1.722878 -0.688948  0.400975
# ...         ...         ...          ...       ...       ...       ...
# 6993  -1.583737   -0.380003     2.056014 -0.656750  1.391718 -1.222055
# 6994   0.426533   -0.920877     2.056014 -0.180824  0.351385 -1.222055
# 6995   0.242457   -1.308934     1.203850  1.437322  1.044940 -0.106936
# 6996   0.054222   -0.131428     0.310116  1.818063 -1.382503 -1.222055
# 6999   0.774924    0.219935     0.466000  1.151767 -1.382503  1.143904
#
#       NumOfProducts  HasCrCard  IsActiveMember  EstimatedSalary  ...  \
# 3261      -0.903352  -1.548034       -1.030169         1.452488  ...
# 2550      -0.903352   0.645981       -1.030169        -1.466743  ...
# 5819      -0.903352   0.645981       -1.030169         0.547127  ...
# 4026      -0.903352   0.645981        0.970714        -0.877544  ...
# 3680      -0.903352   0.645981       -1.030169        -0.993092  ...
# ...             ...        ...             ...              ...  ...
# 6993       0.819663   0.645981        0.970714        -1.420515  ...
# 6994       0.819663   0.645981       -1.030169         0.146828  ...
# 6995      -0.903352   0.645981        0.970714        -0.545387  ...
# 6996      -0.903352   0.645981        0.970714        -1.736501  ...
# 6999      -0.903352   0.645981        0.970714        -0.819426  ...
#
#       Surname_Zox  Surname_Zubarev  Surname_Zubareva  Surname_Zuev  \
# 3261          0.0              0.0         -0.011953     -0.011953
# 2550          0.0              0.0         -0.011953     -0.011953
# 5819          0.0              0.0         -0.011953     -0.011953
# 4026          0.0              0.0         -0.011953     -0.011953
# 3680          0.0              0.0         -0.011953     -0.011953
# ...           ...              ...               ...           ...
# 6993          0.0              0.0         -0.011953     -0.011953
# 6994          0.0              0.0         -0.011953     -0.011953
# 6995          0.0              0.0         -0.011953     -0.011953
# 6996          0.0              0.0         -0.011953     -0.011953
# 6999          0.0              0.0         -0.011953     -0.011953
#
#       Surname_Zuyev  Surname_Zuyeva  Geography_Germany  Geography_Spain  \
# 3261      -0.011953             0.0           1.737346        -0.577790
# 2550      -0.011953             0.0           1.737346        -0.577790
# 5819      -0.011953             0.0           1.737346        -0.577790
# 4026      -0.011953             0.0          -0.575591         1.730732
# 3680      -0.011953             0.0           1.737346        -0.577790
# ...             ...             ...                ...              ...
# 6993      -0.011953             0.0          -0.575591         1.730732
# 6994      -0.011953             0.0          -0.575591        -0.577790
# 6995      -0.011953             0.0          -0.575591        -0.577790
# 6996      -0.011953             0.0          -0.575591        -0.577790
# 6999      -0.011953             0.0           1.737346        -0.577790
#
#       Gender_Male  Exited
# 3261    -1.098232       1
# 2550    -1.098232       1
# 5819     0.910554       1
# 4026     0.910554       1
# 3680    -1.098232       1
# ...           ...     ...
# 6993    -1.098232       0
# 6994     0.910554       0
# 6995     0.910554       0
# 6996    -1.098232       0
# 6999     0.910554       0
#
# [11094 rows x 2945 columns]

# %%
churned_plt = train_over["Exited"].value_counts()
churned_plt.plot(kind="bar")
plt.show()

# %%
X_train_over = train_over.drop(columns = ["Exited"])
y_train_over = train_over["Exited"]

# %%
final_gb_over = GradientBoostingClassifier (n_estimators= 300, min_samples_split= 10, min_samples_leaf= 1, max_depth= 7, learning_rate= 0.01, random_state=0)#(max_depth= 3, max_leaf_nodes = 100, random_state=0)
final_gb_over.fit(X_train_over, y_train_over)
# Out:
# GradientBoostingClassifier(learning_rate=0.01, max_depth=7,
#                            min_samples_split=10, n_estimators=300,
#                            random_state=0)

# %%
y_pred_over = final_gb_over.predict(X_test_scaled)

print("Oversampling Results:")
print(f"Accuracy: {accuracy_score(y_test, y_pred_over)*100 }%")
print(classification_report(y_test, y_pred_over))
# Out:
# c:\Users\lored\Documents\Ironhack\Project\final_project\.venv\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but GradientBoostingClassifier was fitted with feature names
#   warnings.warn(
# Oversampling Results:
# Accuracy: 82.5%
#               precision    recall  f1-score   support
#
#            0       0.92      0.85      0.89      2416
#            1       0.54      0.70      0.61       584
#
#     accuracy                           0.82      3000
#    macro avg       0.73      0.78      0.75      3000
# weighted avg       0.85      0.82      0.83      3000

# %% [markdown]
# ### Undersampling

# %%
no_undersampled = resample(no_churned,
                                    replace=False,
                                    n_samples = len(churned),
                                    random_state=0)
no_undersampled
# Out:
#       RowNumber  CustomerId  CreditScore       Age    Tenure   Balance  \
# 18    -1.129269    0.159657     0.653061 -0.466380 -0.342170  0.766467
# 446    0.996785   -1.050499    -0.947345 -1.037490  0.351385  0.756511
# 4350   0.256324   -1.007710     0.559530 -0.751935 -1.382503  0.649787
# 6233   1.276539   -0.767029    -2.173630  0.485471 -1.035726 -1.222055
# 5244  -0.691439   -1.023205     0.663453 -0.085639 -0.342170 -1.222055
# ...         ...         ...          ...       ...       ...       ...
# 2581   1.321951    0.616668    -0.968130 -0.942305 -0.688948  0.053065
# 1878   1.591651   -0.353420     1.671501 -1.132675 -1.382503  0.973789
# 2168   0.039316    1.705263     0.819336  2.960284 -0.688948 -1.222055
# 5162   0.524984    1.416033    -0.334203 -0.656750  0.351385 -1.222055
# 6568  -0.882448    1.203971     0.642668 -1.037490  0.351385  0.741033
#
#       NumOfProducts  HasCrCard  IsActiveMember  EstimatedSalary  ...  \
# 18        -0.903352  -1.548034       -1.030169        -0.052776  ...
# 446       -0.903352   0.645981        0.970714        -0.525131  ...
# 4350       0.819663   0.645981       -1.030169        -0.804538  ...
# 6233      -0.903352   0.645981       -1.030169         1.011867  ...
# 5244       0.819663   0.645981       -1.030169         1.541095  ...
# ...             ...        ...             ...              ...  ...
# 2581      -0.903352   0.645981       -1.030169        -0.322144  ...
# 1878      -0.903352  -1.548034        0.970714         0.258559  ...
# 2168       0.819663   0.645981        0.970714         0.699929  ...
# 5162       0.819663   0.645981       -1.030169        -0.775060  ...
# 6568      -0.903352   0.645981        0.970714        -0.585692  ...
#
#       Surname_Zox  Surname_Zubarev  Surname_Zubareva  Surname_Zuev  \
# 18            0.0              0.0         -0.011953     -0.011953
# 446           0.0              0.0         -0.011953     -0.011953
# 4350          0.0              0.0         -0.011953     -0.011953
# 6233          0.0              0.0         -0.011953     -0.011953
# 5244          0.0              0.0         -0.011953     -0.011953
# ...           ...              ...               ...           ...
# 2581          0.0              0.0         -0.011953     -0.011953
# 1878          0.0              0.0         -0.011953     -0.011953
# 2168          0.0              0.0         -0.011953     -0.011953
# 5162          0.0              0.0         -0.011953     -0.011953
# 6568          0.0              0.0         -0.011953     -0.011953
#
#       Surname_Zuyev  Surname_Zuyeva  Geography_Germany  Geography_Spain  \
# 18        -0.011953             0.0          -0.575591        -0.577790
# 446       -0.011953             0.0          -0.575591         1.730732
# 4350      -0.011953             0.0           1.737346        -0.577790
# 6233      -0.011953             0.0          -0.575591        -0.577790
# 5244      -0.011953             0.0          -0.575591        -0.577790
# ...             ...             ...                ...              ...
# 2581      -0.011953             0.0          -0.575591        -0.577790
# 1878      -0.011953             0.0          -0.575591         1.730732
# 2168      -0.011953             0.0          -0.575591         1.730732
# 5162      -0.011953             0.0          -0.575591        -0.577790
# 6568      -0.011953             0.0          -0.575591        -0.577790
#
#       Gender_Male  Exited
# 18       0.910554       0
# 446      0.910554       0
# 4350     0.910554       0
# 6233     0.910554       0
# 5244     0.910554       0
# ...           ...     ...
# 2581    -1.098232       0
# 1878     0.910554       0
# 2168     0.910554       0
# 5162     0.910554       0
# 6568     0.910554       0
#
# [1453 rows x 2945 columns]

# %%
train_under = pd.concat([no_undersampled, churned])
train_under
# Out:
#       RowNumber  CustomerId  CreditScore       Age    Tenure   Balance  \
# 18    -1.129269    0.159657     0.653061 -0.466380 -0.342170  0.766467
# 446    0.996785   -1.050499    -0.947345 -1.037490  0.351385  0.756511
# 4350   0.256324   -1.007710     0.559530 -0.751935 -1.382503  0.649787
# 6233   1.276539   -0.767029    -2.173630  0.485471 -1.035726 -1.222055
# 5244  -0.691439   -1.023205     0.663453 -0.085639 -0.342170 -1.222055
# ...         ...         ...          ...       ...       ...       ...
# 6981  -0.166252    0.596403     0.372470 -0.371195  0.351385 -1.222055
# 6988  -1.478700   -0.072098    -1.259113  2.293988 -1.382503  0.612927
# 6989  -1.161161    0.325346    -0.406948 -1.798971 -1.729281  0.655164
# 6997   0.123207   -1.626867     0.860905 -0.085639 -1.382503 -1.222055
# 6998  -1.447154    1.634078     0.154233  0.390286  1.044940  1.820806
#
#       NumOfProducts  HasCrCard  IsActiveMember  EstimatedSalary  ...  \
# 18        -0.903352  -1.548034       -1.030169        -0.052776  ...
# 446       -0.903352   0.645981        0.970714        -0.525131  ...
# 4350       0.819663   0.645981       -1.030169        -0.804538  ...
# 6233      -0.903352   0.645981       -1.030169         1.011867  ...
# 5244       0.819663   0.645981       -1.030169         1.541095  ...
# ...             ...        ...             ...              ...  ...
# 6981      -0.903352   0.645981       -1.030169        -1.306675  ...
# 6988      -0.903352  -1.548034        0.970714        -1.323698  ...
# 6989      -0.903352  -1.548034       -1.030169         0.220827  ...
# 6997       2.542677  -1.548034       -1.030169        -0.149259  ...
# 6998      -0.903352   0.645981       -1.030169        -0.057544  ...
#
#       Surname_Zox  Surname_Zubarev  Surname_Zubareva  Surname_Zuev  \
# 18            0.0              0.0         -0.011953     -0.011953
# 446           0.0              0.0         -0.011953     -0.011953
# 4350          0.0              0.0         -0.011953     -0.011953
# 6233          0.0              0.0         -0.011953     -0.011953
# 5244          0.0              0.0         -0.011953     -0.011953
# ...           ...              ...               ...           ...
# 6981          0.0              0.0         -0.011953     -0.011953
# 6988          0.0              0.0         -0.011953     -0.011953
# 6989          0.0              0.0         -0.011953     -0.011953
# 6997          0.0              0.0         -0.011953     -0.011953
# 6998          0.0              0.0         -0.011953     -0.011953
#
#       Surname_Zuyev  Surname_Zuyeva  Geography_Germany  Geography_Spain  \
# 18        -0.011953             0.0          -0.575591        -0.577790
# 446       -0.011953             0.0          -0.575591         1.730732
# 4350      -0.011953             0.0           1.737346        -0.577790
# 6233      -0.011953             0.0          -0.575591        -0.577790
# 5244      -0.011953             0.0          -0.575591        -0.577790
# ...             ...             ...                ...              ...
# 6981      -0.011953             0.0          -0.575591         1.730732
# 6988      -0.011953             0.0          -0.575591        -0.577790
# 6989      -0.011953             0.0           1.737346        -0.577790
# 6997      -0.011953             0.0          -0.575591        -0.577790
# 6998      -0.011953             0.0          -0.575591        -0.577790
#
#       Gender_Male  Exited
# 18       0.910554       0
# 446      0.910554       0
# 4350     0.910554       0
# 6233     0.910554       0
# 5244     0.910554       0
# ...           ...     ...
# 6981    -1.098232       1
# 6988    -1.098232       1
# 6989    -1.098232       1
# 6997    -1.098232       1
# 6998     0.910554       1
#
# [2906 rows x 2945 columns]

# %%
churned_under_plt = train_under["Exited"].value_counts()
churned_under_plt.plot(kind="bar")
plt.show()

# %%
X_train_under = train_under.drop(columns = ["Exited"])
y_train_under = train_under["Exited"]

# %%
final_gb_under = GradientBoostingClassifier (n_estimators= 300, min_samples_split= 10, min_samples_leaf= 1, max_depth= 7, learning_rate= 0.01, random_state=0)#(max_depth= 3, max_leaf_nodes = 100, random_state=0)
final_gb_under.fit(X_train_under, y_train_under)
# Out:
# GradientBoostingClassifier(learning_rate=0.01, max_depth=7,
#                            min_samples_split=10, n_estimators=300,
#                            random_state=0)

# %%
y_pred_gb_under = final_gb_under.predict(X_test_scaled)
print("Undersampling Results:")
print(f"Accuracy: {accuracy_score(y_test, y_pred_gb_under)* 100}%")
print(classification_report(y_test, y_pred_gb_under))
# Out:
# c:\Users\lored\Documents\Ironhack\Project\final_project\.venv\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but GradientBoostingClassifier was fitted with feature names
#   warnings.warn(
# Undersampling Results:
# Accuracy: 79.5%
#               precision    recall  f1-score   support
#
#            0       0.94      0.80      0.86      2416
#            1       0.48      0.77      0.59       584
#
#     accuracy                           0.80      3000
#    macro avg       0.71      0.79      0.73      3000
# weighted avg       0.85      0.80      0.81      3000

# %% [markdown]
# ### SMOTE

# %%
sm = SMOTE(random_state = 1,sampling_strategy=1.0)

# %%
X_train_smote,y_train_smote = sm.fit_resample(X_train_scaled,y_train)

# %%
smote_gbc = GradientBoostingClassifier (n_estimators= 300, min_samples_split= 10, min_samples_leaf= 1, max_depth= 7, learning_rate= 0.01, random_state=0)#(max_depth=30, max_leaf_nodes=250, random_state=42)
smote_gbc.fit(X_train_smote, y_train_smote)
# Out:
# GradientBoostingClassifier(learning_rate=0.01, max_depth=7,
#                            min_samples_split=10, n_estimators=300,
#                            random_state=0)

# %%
y_pred_smote = smote_gbc.predict(X_test_scaled)
print("SMOTE Results:")
print(f"Accuracy: {accuracy_score(y_test, y_pred_smote)*100}%")
print(classification_report(y_test, y_pred_smote))
# Out:
# SMOTE Results:
# Accuracy: 86.73333333333333%
#               precision    recall  f1-score   support
#
#            0       0.89      0.96      0.92      2416
#            1       0.74      0.49      0.59       584
#
#     accuracy                           0.87      3000
#    macro avg       0.81      0.72      0.75      3000
# weighted avg       0.86      0.87      0.86      3000
